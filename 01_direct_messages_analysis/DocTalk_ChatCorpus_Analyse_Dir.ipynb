# %% [markdown]
# # DocTalk Chat Corpus: Analyses of direct messages
# Author: Sabine Sayegh-Jodehl <br>
#
# Version 3.0
#
# Python 3.11.10 Mac OS
#
#
# ____________________________________________________________

# %% [markdown]
# # Notbook set up

# %%
# Determine which environment is being used in the notebook
import sys
print(sys.executable)
# Out:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/bin/python

# %%
#check if all requirements are present
import sys
print(sys.executable)

# !{sys.executable} -m pip list
# Out:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/bin/python
# Package                   Version
# ------------------------- -----------
# aiohappyeyeballs          2.6.2
# aiohttp                   3.13.5
# aiosignal                 1.4.0
# annotated-doc             0.0.4
# annotated-types           0.7.0
# anyio                     4.13.0
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# blis                      1.3.3
# Bottleneck                1.6.0
# catalogue                 2.0.10
# certifi                   2026.5.20
# cffi                      2.0.0
# charset-normalizer        3.4.7
# clean-text                0.7.1
# click                     8.4.1
# cloudpathlib              0.24.0
# comm                      0.2.3
# confection                1.3.3
# contourpy                 1.3.3
# convokit                  4.1.1
# cycler                    0.12.1
# cymem                     2.0.13
# datasets                  4.8.5
# de_core_news_sm           3.8.0
# debugpy                   1.8.20
# decorator                 5.3.1
# defusedxml                0.7.1
# dill                      0.4.1
# dnspython                 2.8.0
# emoji                     2.15.0
# en_core_web_sm            3.8.0
# et_xmlfile                2.0.0
# evaluate                  0.4.6
# executing                 2.2.1
# fastjsonschema            2.21.2
# filelock                  3.29.0
# fonttools                 4.63.0
# fqdn                      1.5.1
# frozenlist                1.8.0
# fsspec                    2026.2.0
# ftfy                      6.3.1
# h11                       0.16.0
# h5py                      3.12.1
# hf-xet                    1.5.0
# httpcore                  1.0.9
# httpx                     0.28.1
# huggingface_hub           1.16.1
# idna                      3.16
# ipykernel                 7.2.0
# ipython                   9.13.0
# ipython_pygments_lexers   1.1.1
# isoduration               20.11.0
# jedi                      0.20.0
# Jinja2                    3.1.6
# joblib                    1.5.3
# json5                     0.14.0
# jsonpointer               3.1.1
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter_client            8.8.0
# jupyter_core              5.9.1
# jupyter-events            0.12.1
# jupyter-lsp               2.3.1
# jupyter_server            2.18.2
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.8
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# kiwisolver                1.5.0
# lark                      1.3.1
# markdown-it-py            4.2.0
# MarkupSafe                3.0.3
# matplotlib                3.10.9
# matplotlib-inline         0.2.2
# mdurl                     0.1.2
# mistune                   3.2.1
# mpmath                    1.3.0
# msgpack                   1.1.2
# msgpack-numpy             0.4.8
# multidict                 6.7.1
# multiprocess              0.70.19
# murmurhash                1.0.15
# nbclient                  0.10.4
# nbconvert                 7.17.1
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.6.1
# nltk                      3.9.4
# notebook                  7.5.7
# notebook_shim             0.2.4
# numexpr                   2.14.1
# numpy                     2.4.6
# openpyxl                  3.1.5
# overrides                 7.7.0
# packaging                 26.2
# pandas                    3.0.3
# pandocfilters             1.5.1
# parso                     0.8.7
# pexpect                   4.9.0
# pillow                    12.2.0
# pip                       26.1.2
# platformdirs              4.9.6
# preshed                   3.0.13
# prometheus_client         0.25.0
# prompt_toolkit            3.0.52
# propcache                 0.5.2
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pyarrow                   24.0.0
# pycparser                 3.0
# pydantic                  2.13.4
# pydantic_core             2.46.4
# Pygments                  2.20.0
# pymongo                   4.17.0
# pyparsing                 3.3.2
# python-dateutil           2.9.0.post0
# python-json-logger        4.1.0
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# regex                     2026.5.9
# requests                  2.34.2
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rich                      15.0.0
# rpds-py                   0.30.0
# ruff                      0.15.14
# safetensors               0.7.0
# scikit-learn              1.8.0
# scipy                     1.17.1
# Send2Trash                2.1.0
# sentence-transformers     5.5.1
# sentencepiece             0.2.1
# setuptools                74.1.2
# shellingham               1.5.4
# six                       1.17.0
# smart_open                7.6.1
# soupsieve                 2.8.3
# spacy                     3.8.14
# spacy-legacy              3.0.12
# spacy-loggers             1.0.5
# srsly                     2.5.3
# stack-data                0.6.3
# sympy                     1.14.0
# terminado                 0.18.1
# thinc                     8.3.13
# threadpoolctl             3.6.0
# tinycss2                  1.4.0
# tokenizers                0.22.2
# torch                     2.12.0
# tornado                   6.5.5
# tqdm                      4.67.3
# traitlets                 5.15.0
# transformers              5.9.0
# typer                     0.25.1
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# tzdata                    2026.2
# Unidecode                 1.4.0
# uri-template              1.3.0
# urllib3                   2.7.0
# wasabi                    1.1.3
# wcwidth                   0.7.0
# weasel                    1.0.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# wordcloud                 1.9.6
# wrapt                     2.2.1
# xxhash                    3.7.0
# yarl                      1.24.2

# %%
# write requirements to file
import sys

# !{sys.executable} -m pip freeze > requirements.txt

# %%
# Überprüfen, ob alle requirements da sind
import sys
print(sys.executable)

# !{sys.executable} -m pip list
# !{sys.executable} -m pip freeze | wc -l
# Out:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/bin/python
# Package                   Version
# ------------------------- -----------
# aiohappyeyeballs          2.6.2
# aiohttp                   3.13.5
# aiosignal                 1.4.0
# annotated-doc             0.0.4
# annotated-types           0.7.0
# anyio                     4.13.0
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.3.0
# attrs                     26.1.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# blis                      1.3.3
# Bottleneck                1.6.0
# catalogue                 2.0.10
# certifi                   2026.5.20
# cffi                      2.0.0
# charset-normalizer        3.4.7
# clean-text                0.7.1
# click                     8.4.1
# cloudpathlib              0.24.0
# comm                      0.2.3
# confection                1.3.3
# contourpy                 1.3.3
# convokit                  4.1.1
# cycler                    0.12.1
# cymem                     2.0.13
# datasets                  4.8.5
# de_core_news_sm           3.8.0
# debugpy                   1.8.20
# decorator                 5.3.1
# defusedxml                0.7.1
# dill                      0.4.1
# dnspython                 2.8.0
# emoji                     2.15.0
# en_core_web_sm            3.8.0
# et_xmlfile                2.0.0
# evaluate                  0.4.6
# executing                 2.2.1
# fastjsonschema            2.21.2
# filelock                  3.29.0
# fonttools                 4.63.0
# fqdn                      1.5.1
# frozenlist                1.8.0
# fsspec                    2026.2.0
# ftfy                      6.3.1
# h11                       0.16.0
# h5py                      3.12.1
# hf-xet                    1.5.0
# httpcore                  1.0.9
# httpx                     0.28.1
# huggingface_hub           1.16.1
# idna                      3.16
# ipykernel                 7.2.0
# ipython                   9.13.0
# ipython_pygments_lexers   1.1.1
# isoduration               20.11.0
# jedi                      0.20.0
# Jinja2                    3.1.6
# joblib                    1.5.3
# json5                     0.14.0
# jsonpointer               3.1.1
# jsonschema                4.26.0
# jsonschema-specifications 2025.9.1
# jupyter_client            8.8.0
# jupyter_core              5.9.1
# jupyter-events            0.12.1
# jupyter-lsp               2.3.1
# jupyter_server            2.18.2
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.8
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# kiwisolver                1.5.0
# lark                      1.3.1
# markdown-it-py            4.2.0
# MarkupSafe                3.0.3
# matplotlib                3.10.9
# matplotlib-inline         0.2.2
# mdurl                     0.1.2
# mistune                   3.2.1
# mpmath                    1.3.0
# msgpack                   1.1.2
# msgpack-numpy             0.4.8
# multidict                 6.7.1
# multiprocess              0.70.19
# murmurhash                1.0.15
# nbclient                  0.10.4
# nbconvert                 7.17.1
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# networkx                  3.6.1
# nltk                      3.9.4
# notebook                  7.5.7
# notebook_shim             0.2.4
# numexpr                   2.14.1
# numpy                     2.4.6
# openpyxl                  3.1.5
# overrides                 7.7.0
# packaging                 26.2
# pandas                    3.0.3
# pandocfilters             1.5.1
# parso                     0.8.7
# pexpect                   4.9.0
# pillow                    12.2.0
# pip                       26.1.2
# platformdirs              4.9.6
# preshed                   3.0.13
# prometheus_client         0.25.0
# prompt_toolkit            3.0.52
# propcache                 0.5.2
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pyarrow                   24.0.0
# pycparser                 3.0
# pydantic                  2.13.4
# pydantic_core             2.46.4
# Pygments                  2.20.0
# pymongo                   4.17.0
# pyparsing                 3.3.2
# python-dateutil           2.9.0.post0
# python-json-logger        4.1.0
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# regex                     2026.5.9
# requests                  2.34.2
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rich                      15.0.0
# rpds-py                   0.30.0
# ruff                      0.15.14
# safetensors               0.7.0
# scikit-learn              1.8.0
# scipy                     1.17.1
# Send2Trash                2.1.0
# sentence-transformers     5.5.1
# sentencepiece             0.2.1
# setuptools                74.1.2
# shellingham               1.5.4
# six                       1.17.0
# smart_open                7.6.1
# soupsieve                 2.8.3
# spacy                     3.8.14
# spacy-legacy              3.0.12
# spacy-loggers             1.0.5
# srsly                     2.5.3
# stack-data                0.6.3
# sympy                     1.14.0
# terminado                 0.18.1
# thinc                     8.3.13
# threadpoolctl             3.6.0
# tinycss2                  1.4.0
# tokenizers                0.22.2
# torch                     2.12.0
# tornado                   6.5.5
# tqdm                      4.67.3
# traitlets                 5.15.0
# transformers              5.9.0
# typer                     0.25.1
# typing_extensions         4.15.0
# typing-inspection         0.4.2
# tzdata                    2026.2
# Unidecode                 1.4.0
# uri-template              1.3.0
# urllib3                   2.7.0
# wasabi                    1.1.3
# wcwidth                   0.7.0
# weasel                    1.0.0
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# wordcloud                 1.9.6
# wrapt                     2.2.1
# xxhash                    3.7.0
# yarl                      1.24.2
#      180

# %% [markdown]
# ## Working directory

# %%
# Checking the current working directory

import os
os.getcwd()
# Out:
# '/Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis'

# %% [markdown]
# ## Loading modules <br>
# List of modules: convokit, nltk, pandas, spacy, os, datetime, gensim
#
# For working with ConvoKit necessary:
# - Download the toolkit: pip3 install convokit
# - Download Spacy's English model: python3 -m spacy download en (convert for German [spacy_model = "de_core_news_sm"]) <br>
# - Download NLTK's 'punkt' model: import nltk; nltk.download('punkt') (in Python interpreter)

# %%
# %pip install --upgrade pip;
# %pip install notebook --upgrade;
# %pip install nbconvert --upgrade;
# %pip install pandas --upgrade;
# Out:
# Requirement already satisfied: pip in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (26.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: notebook in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (7.5.7)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from notebook) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from notebook) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.8 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from notebook) (4.5.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from notebook) (6.5.5)
# Requirement already satisfied: anyio>=3.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (26.2)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.25.0)
# Requirement already satisfied: pyzmq>=24 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.15.0)
# Requirement already satisfied: websocket-client>=1.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab<4.6,>=4.5.8->notebook) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab<4.6,>=4.5.8->notebook) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab<4.6,>=4.5.8->notebook) (7.2.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab<4.6,>=4.5.8->notebook) (2.3.1)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab<4.6,>=4.5.8->notebook) (74.1.2)
# Requirement already satisfied: certifi in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.8->notebook) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.8->notebook) (1.0.9)
# Requirement already satisfied: idna in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.8->notebook) (3.16)
# Requirement already satisfied: h11>=0.16 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.8->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.34.2)
# Requirement already satisfied: typing_extensions>=4.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (9.13.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (7.2.2)
# Requirement already satisfied: decorator>=5.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.9.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: webencodings in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.8->notebook) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: tzdata in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2026.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nbconvert in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (7.17.1)
# Requirement already satisfied: beautifulsoup4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (5.9.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (26.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (2.20.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbconvert) (5.15.0)
# Requirement already satisfied: webencodings in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-core>=4.7->nbconvert) (4.9.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbclient>=0.5.0->nbconvert) (8.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=25.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.5.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert) (4.26.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.30.0)
# Requirement already satisfied: six>=1.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat>=5.7->nbconvert) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert) (2.8.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch --extra-index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: filelock in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch) (74.1.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
# Out:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/bin/python

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib as mpl

# %%
import matplotlib
import matplotlib.pyplot as plt
print(matplotlib.__version__)
# Out:
# 3.10.9

# %%
# adapt picture resolution

# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import numpy as np

# %%
# %pip install wordcloud
# %pip install nltk
# Out:
# Requirement already satisfied: wordcloud in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from wordcloud) (2.4.6)
# Requirement already satisfied: pillow in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: matplotlib in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from wordcloud) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib->wordcloud) (26.2)
# Requirement already satisfied: pyparsing>=3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nltk in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (3.9.4)
# Requirement already satisfied: click in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nltk) (4.67.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import wordcloud as wc
import os
import nltk

# %%
# %pip install spacy --upgrade
# Out:
# Requirement already satisfied: spacy in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (0.25.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (74.1.2)
# Requirement already satisfied: packaging>=20.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jinja2->spacy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 31.1 MB/s  0:00:00m0:00:010:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/sayegh-
# [nltk_data]     jodehl/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Notwendige Modelle für Spacy und nltk

# %%
import os
import importlib
import nltk
import subprocess

# Liste der Module, die überprüft und gegebenenfalls installiert werden sollen
spacy_model = "de_core_news_sm"
nltk_data = "punkt"

# Überprüfe und installiere das spaCy-Modell
try:
    importlib.import_module(spacy_model)
    print(f"{spacy_model} ist bereits installiert.")
except ImportError:
    print(f"{spacy_model} ist nicht installiert. Installiere es jetzt.")

    # Modell mit spaCy herunterladen
    subprocess.call(["python", "-m", "spacy", "download", spacy_model])

# Überprüft und installiert die NLTK-Daten
if nltk.download(nltk_data):
    print(f"NLTK-Daten ({nltk_data}) wurden heruntergeladen.")
else:
    print(f"NLTK-Daten ({nltk_data}) sind bereits vorhanden.")
# Out:
# de_core_news_sm ist bereits installiert.
# NLTK-Daten (punkt) wurden heruntergeladen.
# [nltk_data] Downloading package punkt to /Users/sayegh-
# [nltk_data]     jodehl/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# %pip install --upgrade convokit
# Out:
# Requirement already satisfied: convokit in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (4.1.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (3.10.9)
# Requirement already satisfied: scipy>1.14 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (1.17.1)
# Requirement already satisfied: pandas>=1.5.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (3.0.3)
# Requirement already satisfied: numpy>=2.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (2.4.6)
# Requirement already satisfied: msgpack-numpy>=0.4.3.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (0.4.8)
# Requirement already satisfied: spacy>=3.8.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (3.8.14)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (1.8.0)
# Requirement already satisfied: nltk>=3.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (3.9.4)
# Requirement already satisfied: dill>=0.2.9 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (0.4.1)
# Requirement already satisfied: joblib>=0.13.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (1.5.3)
# Requirement already satisfied: clean-text>=0.6.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (0.7.1)
# Requirement already satisfied: unidecode>=1.1.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (1.4.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (4.67.3)
# Requirement already satisfied: pymongo>=4.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (4.17.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (6.0.3)
# Requirement already satisfied: dnspython>=1.16.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (2.8.0)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (8.3.13)
# Requirement already satisfied: h5py==3.12.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (3.12.1)
# Requirement already satisfied: numexpr>=2.8.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (2.14.1)
# Requirement already satisfied: ruff>=0.4.8 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (0.15.14)
# Requirement already satisfied: bottleneck in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (1.6.0)
# Requirement already satisfied: evaluate in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (0.4.6)
# Requirement already satisfied: sentence-transformers in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (5.5.1)
# Requirement already satisfied: datasets in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from convokit) (4.8.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (1.3.3)
# Requirement already satisfied: murmurhash<1.1.0,>=1.0.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (3.0.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.8.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (1.1.3)
# Requirement already satisfied: srsly<3.1.0,>=2.4.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (2.0.10)
# Requirement already satisfied: confection<2.0.0,>=1.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (1.3.3)
# Requirement already satisfied: setuptools in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (74.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (2.13.4)
# Requirement already satisfied: packaging>=20.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->convokit) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->thinc<8.4.0,>=8.3.0->convokit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->thinc<8.4.0,>=8.3.0->convokit) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->thinc<8.4.0,>=8.3.0->convokit) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->thinc<8.4.0,>=8.3.0->convokit) (0.4.2)
# Requirement already satisfied: emoji>=2.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from clean-text>=0.6.0->convokit) (2.15.0)
# Requirement already satisfied: ftfy<7.0,>=6.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from clean-text>=0.6.0->convokit) (6.3.1)
# Requirement already satisfied: wcwidth in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from ftfy<7.0,>=6.0->clean-text>=0.6.0->convokit) (0.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->convokit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->convokit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->convokit) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->convokit) (1.5.0)
# Requirement already satisfied: pillow>=8 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->convokit) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->convokit) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->convokit) (2.9.0.post0)
# Requirement already satisfied: msgpack>=0.5.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from msgpack-numpy>=0.4.3.2->convokit) (1.1.2)
# Requirement already satisfied: click in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nltk>=3.4->convokit) (8.4.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from nltk>=3.4->convokit) (2026.5.9)
# Requirement already satisfied: six>=1.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->convokit) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from scikit-learn>=1.0->convokit) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy>=3.8.2->convokit) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy>=3.8.2->convokit) (1.0.5)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy>=3.8.2->convokit) (1.0.0)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy>=3.8.2->convokit) (0.25.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy>=3.8.2->convokit) (2.34.2)
# Requirement already satisfied: jinja2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from spacy>=3.8.2->convokit) (3.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.8.2->convokit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.8.2->convokit) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.8.2->convokit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.8.2->convokit) (2026.5.20)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy>=3.8.2->convokit) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy>=3.8.2->convokit) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy>=3.8.2->convokit) (0.28.1)
# Requirement already satisfied: anyio in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=3.8.2->convokit) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=3.8.2->convokit) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=3.8.2->convokit) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy>=3.8.2->convokit) (0.1.2)
# Requirement already satisfied: wrapt in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy>=3.8.2->convokit) (2.2.1)
# Requirement already satisfied: filelock in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from datasets->convokit) (3.29.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from datasets->convokit) (24.0.0)
# Requirement already satisfied: xxhash in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from datasets->convokit) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from datasets->convokit) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from datasets->convokit) (1.16.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets->convokit) (1.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->convokit) (1.24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from jinja2->spacy>=3.8.2->convokit) (3.0.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from sentence-transformers->convokit) (5.9.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from sentence-transformers->convokit) (2.12.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers->convokit) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers->convokit) (0.7.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers->convokit) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers->convokit) (3.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers->convokit) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import convokit

# %%
# dealing with excel files
# %pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (3.0.3)
# Requirement already satisfied: openpyxl in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: et-xmlfile in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl

# %% [markdown]
# ## Setup: paths

# %%
from pathlib import Path
import pandas as pd
import os

# =========================
# Notebook setup: paths
# =========================

# Current notebook directory
NOTEBOOK_DIR = Path.cwd()

# Project root directory
PROJECT_DIR = NOTEBOOK_DIR.parent

# Input directories
DIRECT_DATA_DIR = PROJECT_DIR / "data" / "direct"
GROUP_DATA_DIR = PROJECT_DIR / "data" / "group"

# Output base directory
OUTPUT_DIR = NOTEBOOK_DIR / "output"

# Separate output directories
DF_OUTPUT_DIR = OUTPUT_DIR / "DF"
CORPUS_OUTPUT_DIR = OUTPUT_DIR / "corpus_objects"

# Create output directories if they do not exist
DF_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
CORPUS_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Shared output directories for comparative result tables and figures
RESULTS_OUTPUT_DIR = PROJECT_DIR / "output" / "results"

RESULT_TABLE_DIR = RESULTS_OUTPUT_DIR / "tables"
FIGURE_OUTPUT_DIR = RESULTS_OUTPUT_DIR / "figures"

# Create result output directories if they do not exist
RESULT_TABLE_DIR.mkdir(parents=True, exist_ok=True)
FIGURE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


# Check paths
print("Notebook directory:", NOTEBOOK_DIR)
print("Project directory:", PROJECT_DIR)

print("\nInput directories:")
print("Direct data:", DIRECT_DATA_DIR, "| exists:", DIRECT_DATA_DIR.exists())
print("Group data:", GROUP_DATA_DIR, "| exists:", GROUP_DATA_DIR.exists())

print("\nOutput directories:")
print("DataFrames:", DF_OUTPUT_DIR)
print("Corpus objects:", CORPUS_OUTPUT_DIR)

print("Result table directory:", RESULT_TABLE_DIR)
print("Figure output directory:", FIGURE_OUTPUT_DIR)
# Out:
# Notebook directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis
# Project directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse
#
# Input directories:
# Direct data: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct | exists: True
# Group data: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/group | exists: True
#
# Output directories:
# DataFrames: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/DF
# Corpus objects: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/corpus_objects
# Result table directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables
# Figure output directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/figures

# %% [markdown]
# ---

# %% [markdown]
# # Creating a corpus object: preparation and data cleaning
#
# Folder with chat logs: "data/direct" <br>
#
# Creating a DataFrame for Conversation ID with metadata <br>
# Reading chat logs into a DataFrame <br>
# Adjusting the DataFrame for the Corpus object for ConvoKit

# %% [markdown]
# ## create pandas DF for Conversation-ID and add metadata for Conversation ID

# %% [markdown]
# 1. Specify the path to the directory
# 2. Create an empty DataFrame for the results with defined columns
# 3. Search through the CSV files, first 6 rows
# 4. Define columns and data
# 5. Combine the individual DataFrames into the final result

# %%
# Create empty result DataFrame
D_Meta_result_df = pd.DataFrame(columns=[
    "conversation_id",
    "Channel Name",
    "Channel Type",
    "Team Name",
    "Anonymized",
    "Format"
])

print("Input directory:", DIRECT_DATA_DIR)
print("Input directory exists:", DIRECT_DATA_DIR.exists())
print("Output directory:", DF_OUTPUT_DIR)

# Browsing the files in the input directory
for file_path in DIRECT_DATA_DIR.glob("*.csv"):

    # Use filename without extension as Channel ID
    channel_id = file_path.stem

    # Read the first 6 rows of the CSV file
    D_metadata_df = pd.read_csv(
        file_path,
        nrows=6,
        header=None,
        sep=";",
        encoding="ISO-8859-1"
    )

    # Transpose DataFrame
    D_metadata_df = D_metadata_df.T

    # Use the first row as column names
    D_metadata_df.columns = D_metadata_df.iloc[0]

    # Use the second row as data
    D_metadata_df = D_metadata_df.iloc[1:2]

    # Add "Team Name" if the column is missing
    if "Team Name" not in D_metadata_df.columns:
        D_metadata_df["Team Name"] = "none"

    # Make sure all required columns exist
    for col in D_Meta_result_df.columns:
        if col not in D_metadata_df.columns:
            D_metadata_df[col] = None

    # If "Format" or "Encoding" is in the column names, use it as format column
    format_column = next(
        (col for col in D_metadata_df.columns if "Format" in col or "Encoding" in col),
        None
    )

    # Add metadata to result DataFrame
    metadata_dict = {
        "conversation_id": channel_id,
        "Channel Name": D_metadata_df["Channel Name"].iloc[0],
        "Channel Type": D_metadata_df["Channel Type"].iloc[0],
        "Team Name": D_metadata_df["Team Name"].iloc[0],
        "Anonymized": D_metadata_df["Anonymized"].iloc[0] if "Anonymized" in D_metadata_df.columns else None,
        "Format": D_metadata_df[format_column].iloc[0] if format_column else None
    }

    D_Meta_result_df = pd.concat(
        [D_Meta_result_df, pd.DataFrame(metadata_dict, index=[0])],
        ignore_index=True
    )

# Show metadata DataFrame as table in Jupyter
display(D_Meta_result_df)

# Save metadata DataFrame as Excel file
D_Meta_result_df.to_excel(
    DF_OUTPUT_DIR / "D_Meta_result_df.xlsx",
    index=False
)

print("Saved DataFrame to:")
print(DF_OUTPUT_DIR / "D_Meta_result_df.xlsx")
# Out:
# Input directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct
# Input directory exists: True
# Output directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/DF
#                           conversation_id Channel Name  \
# 0    D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h         None
# 1        D_oMD_ckqwfkohjbgx3f91keisjh6tuh         None
# 2        D_oMD_w7135snps3d9xdmqz7ktgapw5o         None
# 3    D_oMD_ano_xtf5teqg9i8rtcrt6huuwrhu8w         None
# 4        D_oMD_wh79x5q17pbaz89jw3xrhd31ua         None
# ..                                    ...          ...
# 288      D_mMD_pei6gwagftfeij9egd8wkcajye         None
# 289      D_mMD_fi17kbdm3ibf7x1teyo6sjdwur         None
# 290  D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch         None
# 291      D_mMD_7ygxcq5thibbzbsafxk4z8ckqh         None
# 292      D_mMD_m5gmhf19ajbefq97kemojh98co         None
#
#                Channel Type Team Name Anonymized Format
# 0    Direct Message Channel      none       True    CSV
# 1    Direct Message Channel      none       True    CSV
# 2    Direct Message Channel      none       True    CSV
# 3    Direct Message Channel      none       True    CSV
# 4    Direct Message Channel      none       True    CSV
# ..                      ...       ...        ...    ...
# 288  Direct Message Channel      none       True    CSV
# 289  Direct Message Channel      none       True    CSV
# 290  Direct Message Channel      none       True    CSV
# 291  Direct Message Channel      none       True    CSV
# 292  Direct Message Channel      none       True    CSV
#
# [293 rows x 6 columns]
# Saved DataFrame to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/DF/D_Meta_result_df.xlsx

# %%
# Count conversations per team name
D_conversations_per_team = D_Meta_result_df['Team Name'].value_counts()

# Display the results
print(D_conversations_per_team)

# Display the total number of rows in the DataFrame
print(f"Total number of rows: {D_Meta_result_df.shape[0]}")
# Out:
# Team Name
# none    293
# Name: count, dtype: int64
# Total number of rows: 293

# %% [markdown]
# Evaluate and follow data entry process

# %%
# Browse all CSV files in the input directory
for file_path in DIRECT_DATA_DIR.glob("*.csv"):

    print("Processing file:", file_path)

    # Read the CSV file line by line to extract metadata
    metadata_found = False

    with open(file_path, "r", encoding="ISO-8859-1") as file:
        for line_num, line in enumerate(file):

            # Check whether metadata or structured content is found
            if ";" in line:
                metadata_found = True
                print("Metadata found in line:", line_num + 1)

                # Split metadata line by separator
                metadata = line.strip().split(";")

                print("Metadata:", metadata)

                # Add your logic for extracting and processing metadata here
                break

    if metadata_found:
        # Continue processing metadata here
        pass
    else:
        print("No metadata found in file")
# Out:
# Processing file: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct/D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h.csv
# Metadata found in line: 1
# Metadata: ['Channel ID', 'dq64b8dm7j8zfjrqxj5c7waw1h', '', '', '']
# Processing file: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct/D_oMD_ckqwfkohjbgx3f91keisjh6tuh.csv
# Metadata found in line: 1
# Metadata: ['Channel ID', 'ckqwfkohjbgx3f91keisjh6tuh', '', '', '', '']
# Processing file: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct/D_oMD
'', '', '', '']
# Processing file: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct/D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch.csv
# Metadata found in line: 1
# Metadata: ['Channel ID', 'cea6fr3i13bppnq3hoj8kezwch', '', '', '']
# Processing file: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct/D_mMD_7ygxcq5thibbzbsafxk4z8ckqh.csv
# Metadata found in line: 1
# Metadata: ['Channel ID', '7ygxcq5thibbzbsafxk4z8ckqh', '', '', '', '']
# Processing file: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct/D_mMD_m5gmhf19ajbefq97kemojh98co.csv
# Metadata found in line: 1
# Metadata: ['Channel ID', 'm5gmhf19ajbefq97kemojh98co', '', '', '', '']

# %% [markdown]
# Conversations per team <br>
# Results are expected only under the team name None, since these are direct messages without a team designation.

# %%
# Count conversations per team name
D_conversations_per_team = D_Meta_result_df['Team Name'].value_counts()

# Display the results
print(D_conversations_per_team)
# Out:
# Team Name
# none    293
# Name: count, dtype: int64

# %%
# Anzeigen des aktualisierten DataFrames (optional)
print(D_Meta_result_df)
# Out:
#                           conversation_id Channel Name  \
# 0    D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h         None
# 1        D_oMD_ckqwfkohjbgx3f91keisjh6tuh         None
# 2        D_oMD_w7135snps3d9xdmqz7ktgapw5o         None
# 3    D_oMD_ano_xtf5teqg9i8rtcrt6huuwrhu8w         None
# 4        D_oMD_wh79x5q17pbaz89jw3xrhd31ua         None
# ..                                    ...          ...
# 288      D_mMD_pei6gwagftfeij9egd8wkcajye         None
# 289      D_mMD_fi17kbdm3ibf7x1teyo6sjdwur         None
# 290  D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch         None
# 291      D_mMD_7ygxcq5thibbzbsafxk4z8ckqh         None
# 292      D_mMD_m5gmhf19ajbefq97kemojh98co         None
#
#                Channel Type Team Name Anonymized Format
# 0    Direct Message Channel      none       True    CSV
# 1    Direct Message Channel      none       True    CSV
# 2    Direct Message Channel      none       True    CSV
# 3    Direct Message Channel      none       True    CSV
# 4    Direct Message Channel      none       True    CSV
# ..                      ...       ...        ...    ...
# 288  Direct Message Channel      none       True    CSV
# 289  Direct Message Channel      none       True    CSV
# 290  Direct Message Channel      none       True    CSV
# 291  Direct Message Channel      none       True    CSV
# 292  Direct Message Channel      none       True    CSV
#
# [293 rows x 6 columns]

# %% [markdown]
# ### Convert chat logs to a pandas DataFrame / CSV files to pandas DataFrames
#
# result: Dictionary "D_chat_dataframes"

# %%
def find_header_start(file_path):
    with open(file_path, "r", encoding="ISO-8859-1") as f:
        lines = f.readlines()

        # Check only the first 10 lines
        for i, line in enumerate(lines[:10]):
            if "date" in line.lower():
                return i

    return 7  # Default value if no header marker is found


# Dictionary for generated chat DataFrames
D_chat_dataframes = {}

# Browse all CSV files in the direct data directory
for file_path in DIRECT_DATA_DIR.glob("*.csv"):

    print("Processing file:", file_path)

    header_start = find_header_start(file_path)

    df = pd.read_csv(
        file_path,
        header=header_start,
        skipfooter=5,
        engine="python",
        encoding="ISO-8859-1",
        sep=";",
        usecols=range(4)
    )

    # Use filename without extension as DataFrame name / conversation ID
    D_dataframe_name = file_path.stem

    # Add conversation ID as a new column
    df["conversation_id"] = D_dataframe_name

    # Store DataFrame in dictionary
    D_chat_dataframes[D_dataframe_name] = df

    # Save each DataFrame as an Excel file
    df.to_excel(
        DF_OUTPUT_DIR / f"{D_dataframe_name}.xlsx",
        index=False
    )

# Print column headers for each DataFrame
for D_df_name, df in D_chat_dataframes.items():
    print(f"\nColumn headers for DataFrame '{D_df_name}':")
    for column in df.columns:
        print(column)

print("\nSaved all chat DataFrames to:")
print(DF_OUTPUT_DIR)
# Out:
# Processing file: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct/D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h.csv
# Processing file: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/data/direct/D_oMD_

# date
# sender position
# sender name
# message
# conversation_id
#
# Column headers for DataFrame 'D_mMD_pei6gwagftfeij9egd8wkcajye':
# date
# sender position
# sender name
# message
# conversation_id
#
# Column headers for DataFrame 'D_mMD_fi17kbdm3ibf7x1teyo6sjdwur':
# date
# sender position
# sender name
# message
# conversation_id
#
# Column headers for DataFrame 'D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch':
# date
# sender position
# sender name
# message
# conversation_id
#
# Column headers for DataFrame 'D_mMD_7ygxcq5thibbzbsafxk4z8ckqh':
# date
# sender position
# sender name
# message
# conversation_id
#
# Column headers for DataFrame 'D_mMD_m5gmhf19ajbefq97kemojh98co':
# date
# sender position
# sender name
# message
# conversation_id
#
# Saved all chat DataFrames to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/DF

# %% [markdown]
# #### Validation: all data in column "date" ?

# %%
for D_df_name, df in D_chat_dataframes.items():

    print(f"\nColumn headers for DataFrame '{D_df_name}':")
    for column in df.columns:
        print(column)

    # Clean and standardize column names
    df.columns = df.columns.str.strip().str.lower()

    # Check whether the date column exists
    if "date" not in df.columns:
        print(f"\nWarning: No 'date' column found in DataFrame '{D_df_name}'.")
        print("Available columns:", list(df.columns))
        continue

    # Check the date column
    print(f"\nChecking the 'date' column in DataFrame '{D_df_name}':")

    # Show first entries of the date column
    print("\nFirst entries of the 'date' column:")
    print(df["date"].head())

    # Show last entries of the date column
    print("\nLast entries of the 'date' column:")
    print(df["date"].tail())

    # Check for missing values in the date column
    if df["date"].isnull().any():
        print("Warning: There are missing values in the 'date' column.")
    else:
        print("No missing values found in the 'date' column.")
# Out:
# Column headers for DataFrame 'D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h':
#
# First entries of the 'date' column:
# 0    Thursday 10:51
# 1    Thursday 12:21
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Thursday 10:51
# 1    Thursday 12:21
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ckqwfkohjbgx3f91keisjh6tuh':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ckqwfkohjbgx3f91keisjh6tuh':
#
# First entries of the 'date' column:
# 0    Thursday 07:27
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Thursday 07:27
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_w7135snps3d9xdmqz7ktgapw5o':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_w7135snps3d9xdmqz7ktgapw5o':
#
# First entries of the 'date' column:
# 0    Tuesday 08:05
# 1    Tuesday 13:38
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Tuesday 08:05
# 1    Tuesday 13:38
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ano_xtf5teqg9i8rtcrt6huuwrhu8w':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ano_xtf5teqg9i8rtcrt6huuwrhu8w':
#
# First entries of the 'date' column:
# 0    Wednesday 12:03
# 1    Wednesday 12:08
# 2       Friday 07:55
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 12:03
# 1    Wednesday 12:08
# 2       Friday 07:55
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_wh79x5q17pbaz89jw3xrhd31ua':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_wh79x5q17pbaz89jw3xrhd31ua':
#
# First entries of the 'date' column:
# 0    Wednesday 10:42
# 1    Wednesday 12:40
# 2     Thursday 06:32
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 10:42
# 1    Wednesday 12:40
# 2     Thursday 06:32
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_kheihukp57bzbyyzkhwa95n5iw':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_kheihukp57bzbyyzkhwa95n5iw':
#
# First entries of the 'date' column:
# 0    Monday 14:02
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Monday 14:02
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_6m9xoczsebdx8ks7o897cqgusr':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_6m9xoczsebdx8ks7o897cqgusr':
#
# First entries of the 'date' column:
# 0    Thursday 06:59
# 1    Thursday 08:16
# 2    Thursday 08:16
# 3    Thursday 08:16
# 4    Thursday 12:15
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 3    Thursday 08:16
# 4    Thursday 12:15
# 5    Thursday 12:18
# 6    Thursday 12:36
# 7    Thursday 12:36
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_o4arupbmxpy4jyqiorffyrak7r':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_o4arupbmxpy4jyqiorffyrak7r':
#
# First entries of the 'date' column:
# 0    Wednesday 15:00
# 1    Wednesday 15:02
# 2    Wednesday 15:05
# 3       Monday 11:22
# 4       Monday 11:22
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 2    Wednesday 15:05
# 3       Monday 11:22
# 4       Monday 11:22
# 5      Tuesday 05:50
# 6      Tuesday 06:14
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ano
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 10      Friday 08:16
# 11      Friday 08:18
# 12    Thursday 13:43
# 13    Thursday 14:59
# 14    Thursday 15:26
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_45m6zkumbt8rpnenjd3g7jfknr':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_45m6zkumbt8rpnenjd3g7jfknr':
#
# First entries of the 'date' column:
# 0    Friday 11:59
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Friday 11:59
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ngrsrhn9ubnp8qs3hcsb8fz3kr':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ngrsrhn9ubnp8qs3hcsb8fz3kr':
#
# First entries of the 'date' column:
# 0       Monday 07:57
# 1      Tuesday 09:12
# 2      Tuesday 09:12
# 3     Thursday 14:40
# 4    Wednesday 08:01
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 11    Thursday 14:21
# 12     Tuesday 11:46
# 13    Thursday 07:14
# 14    Thursday 09:55
# 15    Thursday 15:00
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_iefb59pukfyntmw5z4mhok4coo':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_iefb59pukfyntmw5z4mhok4coo':
#
# First entries of the 'date' column:
# 0    Wednesday 10:54
# 1    Wednesday 10:57
# 2     Thursday 09:05
# 3       Friday 09:02
# 4       Monday 07:30
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 1    Wednesday 10:57
# 2     Thursday 09:05
# 3       Friday 09:02
# 4       Monday 07:30
# 5      Tuesday 07:14
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_pwwbbgj54bfbtfceiudr1uxx5r':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_pwwbbgj54bfbtfceiudr1uxx5r':
#
# First entries of the 'date' column:
# 0    Friday 06:18
# 1    Friday 06:25
# 2    Friday 06:25
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Friday 06:18
# 1    Friday 06:25
# 2    Friday 06:25
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_rttptmh1spd73bcctyohur71se':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_rttptmh1spd73bcctyohur71se':
#
# First entries of the 'date' column:
# 0    Wednesday 10:39
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 10:39
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_q9tc5ognwiybjr6zj6imfepayy':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_q9tc5ognwiybjr6zj6imfepayy':
#
# First entries of the 'date' column:
# 0    Monday 11:34
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Monday 11:34
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_qd96t8b1fibqig5z3s7aa4nuth':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_qd96t8b1fibqig5z3s7aa4nuth':
#
# First entries of the 'date' column:
# 0    Wednesday 12:03
# 1    Wednesday 14:33
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 12:03
# 1    Wednesday 14:33
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ano_nanr1jec3pbwmn6czas7wcdp5c':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ano_nanr1jec3pbwmn6czas7wcdp5c':
#
# First entries of the 'date' column:
# 0    Thursday 14:15
# 1      Monday 07:48
# 2      Monday 07:54
# 3      Monday 07:54
# 4      Monday 08:34
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 2    Monday 07:54
# 3    Monday 07:54
# 4    Monday 08:34
# 5    Monday 08:37
# 6    Monday 08:37
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ds4pi693abye3dexmqahtzhgpa':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ds4pi693abye3dexmqahtzhgpa':
#
# First entries of the 'date' column:
# 0      Friday 15:30
# 1      Friday 15:30
# 2    Thursday 11:22
# 3    Thursday 11:23
# 4    Thursday 12:05
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 1      Friday 15:30
# 2    Thursday 11:22
# 3    Thursday 11:23
# 4    Thursday 12:05
# 5     Tuesday 13:48
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ano_c8x6hxdhnpfhpghc1ppm4nsida':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ano_c8x6hxdhnpfhpghc1ppm4nsida':
#
# First entries of the 'date' column:
# 0      Friday 10:37
# 1      Monday 06:41
# 2    Thursday 09:09
# 3    Thursday 09:11
# 4    Thursday 10:50
# Name: date, dtype: str
#
# Last entries of the 'date' column:
#
':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_s743ehxjyj8c8g9jtc7xrh7riw':
#
# First entries of the 'date' column:
# 0    Wednesday 12:20
# 1    Wednesday 12:21
# 2    Wednesday 13:55
# 3      Tuesday 08:07
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 12:20
# 1    Wednesday 12:21
# 2    Wednesday 13:55
# 3      Tuesday 08:07
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_j7acx3u6kjf6inanjn5db1ceeo':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_j7acx3u6kjf6inanjn5db1ceeo':
#
# First entries of the 'date' column:
# 0    Tuesday 10:13
# 1    Tuesday 11:05
# 2    Tuesday 11:11
# 3    Tuesday 11:11
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Tuesday 10:13
# 1    Tuesday 11:05
# 2    Tuesday 11:11
# 3    Tuesday 11:11
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_9ryan4qexbnjubsjctcoo9j3qc':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_9ryan4qexbnjubsjctcoo9j3qc':
#
# First entries of the 'date' column:
# 0    Friday 10:22
# 1    Friday 10:27
# 2    Monday 09:06
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Friday 10:22
# 1    Friday 10:27
# 2    Monday 09:06
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_zydt5aewxirbbxzipp5qq4euzo':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_zydt5aewxirbbxzipp5qq4euzo':
#
# First entries of the 'date' column:
# 0    Thursday 09:57
# 1    Thursday 10:00
# 2      Friday 10:18
# 3      Friday 10:18
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Thursday 09:57
# 1    Thursday 10:00
# 2      Friday 10:18
# 3      Friday 10:18
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_rjka39ghrjbxbgco5j4exmh8mh':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_rjka39ghrjbxbgco5j4exmh8mh':
#
# First entries of the 'date' column:
# 0    Sunday 18:35
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Sunday 18:35
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_sgchiwq8jfdxpyxq8sx5uecj8w':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_sgchiwq8jfdxpyxq8sx5uecj8w':
#
# First entries of the 'date' column:
# 0    Tuesday 13:14
# 1    Tuesday 13:41
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Tuesday 13:14
# 1    Tuesday 13:41
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ano_o9iwphbeajn5fbw8zm9xiuew7h':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ano_o9iwphbeajn5fbw8zm9xiuew7h':
#
# First entries of the 'date' column:
# 0    Monday 10:42
# 1    Monday 12:23
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Monday 10:42
# 1    Monday 12:23
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_k3dxykrpetnmznyqofncsj431a':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_k3dxykrpetnmznyqofncsj431a':
#
# First entries of the 'date' column:
# 0    Tuesday 11:11
# 1     Friday 08:29
# 2     Friday 11:22
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Tuesday 11:11
# 1     Friday 08:29
# 2     Friday 11:22
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ano_j7zahkepq3dbxn3x57hxuumwxe':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ano_j7zahkepq3dbxn3x57hxuumwxe':
#
# First entries of the 'date' column:
# 0    Wednesday 15:00
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 15:00
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_xmpzkwj4gjr8tedu559syackfw':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_xmpzkwj4gjr8tedu559syackfw':
#
# First entries of the 'date' column:
# 0       Monday 12:37
# 1       Monday 12:37
# 2      Tuesday 11:01
# 3    Wednesday 06:50
# 4    Wednesday 09:44
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 47    Friday 13:48
# 48    Friday 13:49
# 49    Friday 16:45
# 50    Friday 16:45
# 51    Monday 13:50
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_grhmr5o3rtbbuynmdw4expj4pe':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_grhmr5o3rtbbuynmdw4expj4pe':
#
# First entries of the 'date' column:
# 0      Tuesday 07:26
# 1      Tuesday 07:30
# 2      Tuesday 15:00
# 3      Tuesday 15:01
# 4    Wednesday 06:48
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 2      Tuesday 15:00
# 3      Tuesday 15:01
# 4    Wednesday 06:48
# 5    Wednesday 06:54
# 6    Wednesday 06:54
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_t1hzerhwx7rz8me76rsds3kxdr':
# date
# sender position
# sender name
# message
# conversation_id
#
# ...
# 2    Thursday 14:41
# 3    Thursday 14:42
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Thursday
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 44    Thursday 12:24
# 45    Thursday 13:22
# 46    Thursday 14:13
# 47    Thursday 14:14
# 48      Friday 08:05
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_tn347uhrhir47guomwxmwxohew':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_tn347uhrhir47guomwxmwxohew':
#
# First entries of the 'date' column:
# 0       Monday 10:19
# 1       Monday 10:21
# 2      Tuesday 14:14
# 3    Wednesday 06:34
# 4       Monday 09:33
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 21    Thursday 16:30
# 22      Monday 07:11
# 23      Monday 07:12
# 24      Monday 07:12
# 25      Monday 10:16
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_9mjzuspbatbhumt45petcrtciw':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_9mjzuspbatbhumt45petcrtciw':
#
# First entries of the 'date' column:
# 0    Wednesday 10:57
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 10:57
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_6bpai5erxjyezdd6edz1ik4sbe':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_6bpai5erxjyezdd6edz1ik4sbe':
#
# First entries of the 'date' column:
# 0     Tuesday 13:30
# 1     Tuesday 13:49
# 2    Thursday 09:07
# 3    Thursday 09:15
# 4    Thursday 09:16
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 24    Wednesday 12:30
# 25    Wednesday 12:31
# 26     Thursday 08:50
# 27     Thursday 09:19
# 28       Friday 11:15
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ti5oixwkspr83kfc6qcjwptbqh':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ti5oixwkspr83kfc6qcjwptbqh':
#
# First entries of the 'date' column:
# 0    Friday 17:57
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Friday 17:57
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_xjnekiedz7yx7r1qw8q3thhz8o':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_xjnekiedz7yx7r1qw8q3thhz8o':
#
# First entries of the 'date' column:
# 0    Wednesday 08:28
# 1    Wednesday 08:28
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 08:28
# 1    Wednesday 08:28
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_8cq6azqwfpybijk374f411zo9r':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_8cq6azqwfpybijk374f411zo9r':
#
# First entries of the 'date' column:
# 0    Saturday 09:42
# 1    Saturday 09:42
# 2    Saturday 09:47
# 3    Saturday 10:12
# 4    Saturday 10:14
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 2    Saturday 09:47
# 3    Saturday 10:12
# 4    Saturday 10:14
# 5    Saturday 11:10
# 6    Saturday 11:10
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_bnhpt5bf6pny5pok78sdq6xq4h':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_bnhpt5bf6pny5pok78sdq6xq4h':
#
# First entries of the 'date' column:
# 0    Thursday 15:27
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Thursday 15:27
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ano_99rpsxpc5pgcfydxcjtx6quuio':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ano_99rpsxpc5pgcfydxcjtx6quuio':
#
# First entries of the 'date' column:
# 0    Wednesday 13:12
# 1    Wednesday 13:12
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 13:12
# 1    Wednesday 13:12
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_pei6gwagftfeij9egd8wkcajye':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_pei6gwagftfeij9egd8wkcajye':
#
# First entries of the 'date' column:
# 0    Tuesday 08:22
# 1    Tuesday 08:24
# 2    Tuesday 08:25
# 3    Tuesday 08:26
# 4    Tuesday 08:27
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 16      Tuesday 10:27
# 17    Wednesday 10:33
# 18    Wednesday 10:33
# 19    Wednesday 10:34
# 20     Thursday 14:21
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_fi17kbdm3ibf7x1teyo6sjdwur':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_fi17kbdm3ibf7x1teyo6sjdwur':
#
# First entries of the 'date' column:
# 0    Wednesday 14:09
# 1    Wednesday 14:11
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 14:09
# 1    Wednesday 14:11
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch':
#
# First entries of the 'date' column:
# 0    Wednesday 12:45
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 12:45
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_7ygxcq5thibbzbsafxk4z8ckqh':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_7ygxcq5thibbzbsafxk4z8ckqh':
#
# First entries of the 'date' column:
# 0    Thursday 06:22
# 1    Thursday 06:23
# 2    Thursday 06:26
# 3    Thursday 06:27
# 4    Thursday 06:27
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 81    Tuesday 09:07
# 82    Tuesday 09:08
# 83    Tuesday 09:09
# 84    Tuesday 09:15
# 85    Tuesday 14:00
# Name: date, dtype: str
# No missing values found in the 'date' column.
#
# Column headers for DataFrame 'D_mMD_m5gmhf19ajbefq97kemojh98co':
# date
# sender position
# sender name
# message
# conversation_id
#
# Checking the 'date' column in DataFrame 'D_mMD_m5gmhf19ajbefq97kemojh98co':
#
# First entries of the 'date' column:
# 0    Wednesday 10:59
# Name: date, dtype: str
#
# Last entries of the 'date' column:
# 0    Wednesday 10:59
# Name: date, dtype: str
# No missing values found in the 'date' column.

# %% [markdown]
# #### Merge DataFrames from the `D_chat_dataframes` dictionary into a single DataFrame `D_Chat_df`

# %%
# Create an empty DataFrame to store the combined data
D_Chat_df = pd.DataFrame()

# Loop through the DataFrames in D_chat_dataframes and append them to the combined DataFrame
for D_df_name, df in D_chat_dataframes.items():
    D_Chat_df = pd.concat([D_Chat_df, df], ignore_index=True)

# Display the first rows of the combined DataFrame
print(D_Chat_df.head())
# Out:
#              date    sender position sender name  \
# 0  Thursday 10:51           redacted     Person1
# 1  Thursday 12:21           redacted     Person2
# 2  Thursday 07:27           redacted     Person1
# 3   Tuesday 08:05  assistenzaerzt*in     Person2
# 4   Tuesday 13:38           redacted     Person1
#
#                                              message  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...
# 1                                prima, vielen Dank!
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...
# 4                                   ja, war grade da
#
#                         conversation_id
# 0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h
# 1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h
# 2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh
# 3      D_oMD_w7135snps3d9xdmqz7ktgapw5o
# 4      D_oMD_w7135snps3d9xdmqz7ktgapw5o

# %% [markdown]
# #### Output: Save `D_Chat_df` to file (imported direct messages as DataFrame, without metadata)

# %%
# Create a copy of the combined chat DataFrame
df = D_Chat_df.copy()

# Move the 'sender name' column to the first position if it exists
if "sender name" in df.columns:
    cols = ["sender name"] + [col for col in df.columns if col != "sender name"]
    df = df[cols]
else:
    print("Warning: Column 'sender name' not found.")
    print("Available columns:", list(df.columns))

# Display the first rows of the adjusted DataFrame
display(df.head())

# Save the adjusted DataFrame as an Excel file
df.to_excel(
    DF_OUTPUT_DIR / "D_Chat_df.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved DataFrame to:")
print(DF_OUTPUT_DIR / "D_Chat_df.xlsx")
# Out:
#   sender name            date    sender position  \
# 0     Person1  Thursday 10:51           redacted
# 1     Person2  Thursday 12:21           redacted
# 2     Person1  Thursday 07:27           redacted
# 3     Person2   Tuesday 08:05  assistenzaerzt*in
# 4     Person1   Tuesday 13:38           redacted
#
#                                              message  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...
# 1                                prima, vielen Dank!
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...
# 4                                   ja, war grade da
#
#                         conversation_id
# 0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h
# 1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h
# 2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh
# 3      D_oMD_w7135snps3d9xdmqz7ktgapw5o
# 4      D_oMD_w7135snps3d9xdmqz7ktgapw5o
# Saved DataFrame to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/DF/D_Chat_df.xlsx

# %%
# Display data types and formats for each column
data_types = D_Chat_df.dtypes

print("Data types:")
print(data_types)
# Out:
# Data types:
# date               str
# sender position    str
# sender name        str
# message            str
# conversation_id    str
# dtype: object

# %% [markdown]
# #### Adjust column formats *(formerly: Anpassung der Spaltenformate)*
#
# The `"date"` column should be converted to a proper date/time format, preferably `datetime64` *(formerly: Datumsformat)*.
#
# #### Format the `"date"` column *(formerly: Formatierung der Spalte `"date"`)*
#
# 1. Convert from a weekday/time format such as `"Monday 12:00"` to a full datetime format such as `"2023-10-24 12:00:00"`
#    *(formerly: von `"Monday 12:00"` zu `"2023-10-24 12:00:00"`)*
#
# 2. Convert the datetime value to a Unix timestamp
#    *(formerly: von `"2023-10-24 12:00:00"` zu einem numerischen Zeitstempel wie `"123456789"`)*

# %% [markdown]
# #### Validate: Check that all values in the `date` column are formatted as strings

# %%
from datetime import datetime
import re


def is_valid_date_format(date_str):
    # Regular expression to check the pattern "weekday time"
    pattern = re.compile(
        r"^(Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday) \d{2}:\d{2}$"
    )

    # Check whether the value is a string before applying the pattern
    if not isinstance(date_str, str):
        return False

    return pattern.match(date_str) is not None


# Check each row before applying the conversion function
invalid_dates = D_Chat_df["date"].apply(
    lambda x: not is_valid_date_format(x)
)

if invalid_dates.any():
    print("Some date values are not correctly formatted:")
    print(D_Chat_df.loc[invalid_dates, "date"])
else:
    print("All date values follow the expected string format: 'Weekday HH:MM'.")
# Out:
# All date values follow the expected string format: 'Weekday HH:MM'.

# %%
# Create a date mapping for each weekday
date_mapping = {
    "Monday": "2022-01-03",
    "Tuesday": "2022-01-04",
    "Wednesday": "2022-01-05",
    "Thursday": "2022-01-06",
    "Friday": "2022-01-07",
    "Saturday": "2022-01-08",
    "Sunday": "2022-01-09"
}

# Extract the weekday from the date column
D_Chat_df["weekday"] = D_Chat_df["date"].str.split().str[0]

# Map each weekday to a calendar date
D_Chat_df["calendar_date"] = D_Chat_df["weekday"].map(date_mapping)

# Display the updated DataFrame
print(D_Chat_df.head())
# Out:
#              date    sender position sender name  \
# 0  Thursday 10:51           redacted     Person1
# 1  Thursday 12:21           redacted     Person2
# 2  Thursday 07:27           redacted     Person1
# 3   Tuesday 08:05  assistenzaerzt*in     Person2
# 4   Tuesday 13:38           redacted     Person1
#
#                                              message  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...
# 1                                prima, vielen Dank!
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...
# 4                                   ja, war grade da
#
#                         conversation_id   weekday calendar_date
# 0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h  Thursday    2022-01-06
# 1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h  Thursday    2022-01-06
# 2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh  Thursday    2022-01-06
# 3      D_oMD_w7135snps3d9xdmqz7ktgapw5o   Tuesday    2022-01-04
# 4      D_oMD_w7135snps3d9xdmqz7ktgapw5o   Tuesday    2022-01-04

# %%
# Extract the time from the 'date' column and reformat it to 'HH:MM:00'
D_Chat_df["time"] = D_Chat_df["date"].str.split().str[1] + ":00"

# Display the updated DataFrame
print(D_Chat_df.head())
# Out:
#              date    sender position sender name  \
# 0  Thursday 10:51           redacted     Person1
# 1  Thursday 12:21           redacted     Person2
# 2  Thursday 07:27           redacted     Person1
# 3   Tuesday 08:05  assistenzaerzt*in     Person2
# 4   Tuesday 13:38           redacted     Person1
#
#                                              message  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...
# 1                                prima, vielen Dank!
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...
# 4                                   ja, war grade da
#
#                         conversation_id   weekday calendar_date      time
# 0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h  Thursday    2022-01-06  10:51:00
# 1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h  Thursday    2022-01-06  12:21:00
# 2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh  Thursday    2022-01-06  07:27:00
# 3      D_oMD_w7135snps3d9xdmqz7ktgapw5o   Tuesday    2022-01-04  08:05:00
# 4      D_oMD_w7135snps3d9xdmqz7ktgapw5o   Tuesday    2022-01-04  13:38:00

# %%
# Combine calendar date and time into a datetime column
D_Chat_df["datetime"] = pd.to_datetime(
    D_Chat_df["calendar_date"] + " " + D_Chat_df["time"],
    format="%Y-%m-%d %H:%M:%S",
    errors="coerce"
)

# Convert datetime to Unix timestamp in seconds
D_Chat_df["timestamp"] = (
    (D_Chat_df["datetime"] - pd.Timestamp("1970-01-01"))
    // pd.Timedelta("1s")
)

# Display the updated DataFrame
print(D_Chat_df.head())
# Out:
#              date    sender position sender name  \
# 0  Thursday 10:51           redacted     Person1
# 1  Thursday 12:21           redacted     Person2
# 2  Thursday 07:27           redacted     Person1
# 3   Tuesday 08:05  assistenzaerzt*in     Person2
# 4   Tuesday 13:38           redacted     Person1
#
#                                              message  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...
# 1                                prima, vielen Dank!
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...
# 4                                   ja, war grade da
#
#                         conversation_id   weekday calendar_date      time  \
# 0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h  Thursday    2022-01-06  10:51:00
# 1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h  Thursday    2022-01-06  12:21:00
# 2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh  Thursday    2022-01-06  07:27:00
# 3      D_oMD_w7135snps3d9xdmqz7ktgapw5o   Tuesday    2022-01-04  08:05:00
# 4      D_oMD_w7135snps3d9xdmqz7ktgapw5o   Tuesday    2022-01-04  13:38:00
#
#              datetime   timestamp
# 0 2022-01-06 10:51:00  1641466260
# 1 2022-01-06 12:21:00  1641471660
# 2 2022-01-06 07:27:00  1641454020
# 3 2022-01-04 08:05:00  1641283500
# 4 2022-01-04 13:38:00  1641303480

# %% [markdown]
# Validierung der Timestamps

# %%
# Convert Unix timestamp to readable datetime
D_Chat_df["readable_date"] = pd.to_datetime(
    D_Chat_df["timestamp"],
    unit="s"
)

# Display the updated DataFrame
print(D_Chat_df.head())
# Out:
#              date    sender position sender name  \
# 0  Thursday 10:51           redacted     Person1
# 1  Thursday 12:21           redacted     Person2
# 2  Thursday 07:27           redacted     Person1
# 3   Tuesday 08:05  assistenzaerzt*in     Person2
# 4   Tuesday 13:38           redacted     Person1
#
#                                              message  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...
# 1                                prima, vielen Dank!
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...
# 4                                   ja, war grade da
#
#                         conversation_id   weekday calendar_date      time  \
# 0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h  Thursday    2022-01-06  10:51:00
# 1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h  Thursday    2022-01-06  12:21:00
# 2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh  Thursday    2022-01-06  07:27:00
# 3      D_oMD_w7135snps3d9xdmqz7ktgapw5o   Tuesday    2022-01-04  08:05:00
# 4      D_oMD_w7135snps3d9xdmqz7ktgapw5o   Tuesday    2022-01-04  13:38:00
#
#              datetime   timestamp       readable_date
# 0 2022-01-06 10:51:00  1641466260 2022-01-06 10:51:00
# 1 2022-01-06 12:21:00  1641471660 2022-01-06 12:21:00
# 2 2022-01-06 07:27:00  1641454020 2022-01-06 07:27:00
# 3 2022-01-04 08:05:00  1641283500 2022-01-04 08:05:00
# 4 2022-01-04 13:38:00  1641303480 2022-01-04 13:38:00

# %%
# Display data types and formats for each column
data_types = D_Chat_df.dtypes

print("Data types:")
print(data_types)
# Out:
# Data types:
# date                          str
# sender position               str
# sender name                   str
# message                       str
# conversation_id               str
# weekday                    object
# calendar_date                 str
# time                       object
# datetime           datetime64[us]
# timestamp                   int64
# readable_date       datetime64[s]
# dtype: object

# %% [markdown]
# #### Rename columns to match the target structure and create 'ID' from index

# %%
# Add an empty reply_to column
D_Chat_df["reply_to"] = None

# Rename columns to match the target structure
D_Chat_df.rename(
    columns={
        "sender name": "speaker",
        "message": "text",
        "conversation_id": "conversation_id"
    },
    inplace=True
)

# Reset the index and create a new ID column
D_Chat_df = D_Chat_df.reset_index(drop=True)
D_Chat_df["id"] = D_Chat_df.index

# Reorder important columns if they exist
preferred_column_order = [
    "id",
    "conversation_id",
    "reply_to",
    "speaker",
    "timestamp",
    "text"
]

remaining_columns = [
    col for col in D_Chat_df.columns
    if col not in preferred_column_order
]

D_Chat_df = D_Chat_df[
    preferred_column_order + remaining_columns
]

# Display the first rows of the updated DataFrame
print(D_Chat_df.head())
# Out:
#    id                       conversation_id reply_to  speaker   timestamp  \
# 0   0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h     None  Person1  1641466260
# 1   1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h     None  Person2  1641471660
# 2   2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh     None  Person1  1641454020
# 3   3      D_oMD_w7135snps3d9xdmqz7ktgapw5o     None  Person2  1641283500
# 4   4      D_oMD_w7135snps3d9xdmqz7ktgapw5o     None  Person1  1641303480
#
#                                                 text            date  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...  Thursday 10:51
# 1                                prima, vielen Dank!  Thursday 12:21
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...  Thursday 07:27
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...   Tuesday 08:05
# 4                                   ja, war grade da   Tuesday 13:38
#
#      sender position   weekday calendar_date      time            datetime  \
# 0           redacted  Thursday    2022-01-06  10:51:00 2022-01-06 10:51:00
# 1           redacted  Thursday    2022-01-06  12:21:00 2022-01-06 12:21:00
# 2           redacted  Thursday    2022-01-06  07:27:00 2022-01-06 07:27:00
# 3  assistenzaerzt*in   Tuesday    2022-01-04  08:05:00 2022-01-04 08:05:00
# 4           redacted   Tuesday    2022-01-04  13:38:00 2022-01-04 13:38:00
#
#         readable_date
# 0 2022-01-06 10:51:00
# 1 2022-01-06 12:21:00
# 2 2022-01-06 07:27:00
# 3 2022-01-04 08:05:00
# 4 2022-01-04 13:38:00

# %% [markdown]
# Überflüssige Spalten löschen

# %%
# Drop temporary date and time columns if they exist
columns_to_drop = [
    "date",
    "calendar_date",
    "time",
    "datetime",
    "readable_date"
]

D_Chat_df.drop(
    columns=[col for col in columns_to_drop if col in D_Chat_df.columns],
    inplace=True
)

# Display the updated DataFrame
print(D_Chat_df.head())
# Out:
#    id                       conversation_id reply_to  speaker   timestamp  \
# 0   0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h     None  Person1  1641466260
# 1   1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h     None  Person2  1641471660
# 2   2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh     None  Person1  1641454020
# 3   3      D_oMD_w7135snps3d9xdmqz7ktgapw5o     None  Person2  1641283500
# 4   4      D_oMD_w7135snps3d9xdmqz7ktgapw5o     None  Person1  1641303480
#
#                                                 text    sender position  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...           redacted
# 1                                prima, vielen Dank!           redacted
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...           redacted
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...  assistenzaerzt*in
# 4                                   ja, war grade da           redacted
#
#     weekday
# 0  Thursday
# 1  Thursday
# 2  Thursday
# 3   Tuesday
# 4   Tuesday

# %%
# Display data types and formats for each column
data_types = D_Chat_df.dtypes

print("Data types:")
print(data_types)
# Out:
# Data types:
# id                  int64
# conversation_id       str
# reply_to           object
# speaker               str
# timestamp           int64
# text                  str
# sender position       str
# weekday            object
# dtype: object

# %% [markdown]
# #### Format columns into the required format for the corpus class (`id` should be stored as a string)

# %%
# Convert selected columns to string while preserving missing values as empty strings
columns_to_convert = [
    "id",
    "sender position",
    "speaker",
    "text",
    "conversation_id",
    "reply_to"
]

for column in columns_to_convert:
    if column in D_Chat_df.columns:
        D_Chat_df[column] = D_Chat_df[column].fillna("").astype(str)

# Display data types to verify the conversion
print(D_Chat_df.dtypes)

# Display the updated DataFrame
print(D_Chat_df.head())
# Out:
# id                    str
# conversation_id       str
# reply_to              str
# speaker               str
# timestamp           int64
# text                  str
# sender position       str
# weekday            object
# dtype: object
#   id                       conversation_id reply_to  speaker   timestamp  \
# 0  0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h           Person1  1641466260
# 1  1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h           Person2  1641471660
# 2  2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh           Person1  1641454020
# 3  3      D_oMD_w7135snps3d9xdmqz7ktgapw5o           Person2  1641283500
# 4  4      D_oMD_w7135snps3d9xdmqz7ktgapw5o           Person1  1641303480
#
#                                                 text    sender position  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...           redacted
# 1                                prima, vielen Dank!           redacted
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...           redacted
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...  assistenzaerzt*in
# 4                                   ja, war grade da           redacted
#
#     weekday
# 0  Thursday
# 1  Thursday
# 2  Thursday
# 3   Tuesday
# 4   Tuesday

# %% [markdown]
# ### Insert metadata into `D_Conver_result_df`

# %%
# Merge chat data with metadata using conversation_id
D_Conver_result_df = pd.merge(
    D_Chat_df,
    D_Meta_result_df,
    on="conversation_id",
    how="left"
)

# Display the merged DataFrame as a table
display(D_Conver_result_df.head())
# Out:
#   id                       conversation_id reply_to  speaker   timestamp  \
# 0  0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h           Person1  1641466260
# 1  1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h           Person2  1641471660
# 2  2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh           Person1  1641454020
# 3  3      D_oMD_w7135snps3d9xdmqz7ktgapw5o           Person2  1641283500
# 4  4      D_oMD_w7135snps3d9xdmqz7ktgapw5o           Person1  1641303480
#
#                                                 text    sender position  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...           redacted
# 1                                prima, vielen Dank!           redacted
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...           redacted
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...  assistenzaerzt*in
# 4                                   ja, war grade da           redacted
#
#     weekday Channel Name            Channel Type Team Name Anonymized Format
# 0  Thursday         None  Direct Message Channel      none       True    CSV
# 1  Thursday         None  Direct Message Channel      none       True    CSV
# 2  Thursday         None  Direct Message Channel      none       True    CSV
# 3   Tuesday         None  Direct Message Channel      none       True    CSV
# 4   Tuesday         None  Direct Message Channel      none       True    CSV

# %%
# Display data types and formats for each column
data_types = D_Conver_result_df.dtypes

print("Data types:")
print(data_types)
# Out:
# Data types:
# id                    str
# conversation_id    object
# reply_to              str
# speaker               str
# timestamp           int64
# text                  str
# sender position       str
# weekday            object
# Channel Name       object
# Channel Type       object
# Team Name          object
# Anonymized         object
# Format             object
# dtype: object

# %% [markdown]
# #### Output: `D_Conver_result_df` (direct chat messages plus metadata)

# %%
# Save D_Conver_result_df to an Excel file

# Create a copy of the merged conversation DataFrame
df = D_Conver_result_df.copy()

# Display the first rows before saving
display(df.head())

# Save the DataFrame as an Excel file
df.to_excel(
    DF_OUTPUT_DIR / "D_Conver_result_df.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved DataFrame to:")
print(DF_OUTPUT_DIR / "D_Conver_result_df.xlsx")
# Out:
#   id                       conversation_id reply_to  speaker   timestamp  \
# 0  0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h           Person1  1641466260
# 1  1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h           Person2  1641471660
# 2  2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh           Person1  1641454020
# 3  3      D_oMD_w7135snps3d9xdmqz7ktgapw5o           Person2  1641283500
# 4  4      D_oMD_w7135snps3d9xdmqz7ktgapw5o           Person1  1641303480
#
#                                                 text    sender position  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...           redacted
# 1                                prima, vielen Dank!           redacted
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...           redacted
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...  assistenzaerzt*in
# 4                                   ja, war grade da           redacted
#
#     weekday Channel Name            Channel Type Team Name Anonymized Format
# 0  Thursday         None  Direct Message Channel      none       True    CSV
# 1  Thursday         None  Direct Message Channel      none       True    CSV
# 2  Thursday         None  Direct Message Channel      none       True    CSV
# 3   Tuesday         None  Direct Message Channel      none       True    CSV
# 4   Tuesday         None  Direct Message Channel      none       True    CSV
# Saved DataFrame to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/DF/D_Conver_result_df.xlsx

# %%
#Df in Datei Schreiben
import pandas as pd

df = pd.DataFrame(D_Conver_result_df)

# Verschieben der 'sender name' Spalte an die erste Stelle
#cols = ['sender name'] + [col for col in df.columns if col != 'sender name']
#df = df[cols]

# Schreiben des angepassten DataFrames in eine Excel-Datei
df.to_excel('D_Conver_result_df.xlsx', index=False, engine='openpyxl')

# %%
# Check for empty cells in the text column

empty_text_count = (
    D_Conver_result_df["text"].isna()
    | (D_Conver_result_df["text"].astype(str).str.strip() == "")
).sum()

total_rows = len(D_Conver_result_df)

if total_rows > 0:
    percentage = empty_text_count / total_rows * 100
else:
    percentage = 0

print(f"Empty text cells: {empty_text_count}")
print(f"Total number of rows: {total_rows}")
print(f"Percentage of empty text cells: {percentage:.2f} %")
# Out:
# Empty text cells: 42
# Total number of rows: 4957
# Percentage of empty text cells: 0.85 %

# %%
D_Conver_result_df_clean = D_Conver_result_df[
    D_Conver_result_df["text"].notna() &
    (D_Conver_result_df["text"].astype(str).str.strip() != "")
].copy()

# %%
# Display data types and formats for each column
data_types = D_Conver_result_df.dtypes

print("Data types:")
print(data_types)
# Out:
# Data types:
# id                    str
# conversation_id    object
# reply_to              str
# speaker               str
# timestamp           int64
# text                  str
# sender position       str
# weekday            object
# Channel Name       object
# Channel Type       object
# Team Name          object
# Anonymized         object
# Format             object
# dtype: object

# %%
# Save cleaned DataFrame to an Excel file

# Create a copy of the cleaned conversation DataFrame
df = D_Conver_result_df_clean.copy()

# Display the first rows before saving
display(df.head())

# Save the cleaned DataFrame as an Excel file
df.to_excel(
    DF_OUTPUT_DIR / "D_Conver_result_df_clean.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved cleaned DataFrame to:")
print(DF_OUTPUT_DIR / "D_Conver_result_df_clean.xlsx")
# Out:
#   id                       conversation_id reply_to  speaker   timestamp  \
# 0  0  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h           Person1  1641466260
# 1  1  D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h           Person2  1641471660
# 2  2      D_oMD_ckqwfkohjbgx3f91keisjh6tuh           Person1  1641454020
# 3  3      D_oMD_w7135snps3d9xdmqz7ktgapw5o           Person2  1641283500
# 4  4      D_oMD_w7135snps3d9xdmqz7ktgapw5o           Person1  1641303480
#
#                                                 text    sender position  \
# 0  Willkommen, schön, dass es funktioniert hat!<e...           redacted
# 1                                prima, vielen Dank!           redacted
# 2  Liebe <Vorname>, wenn Arztbriefe fertig sind a...           redacted
# 3  Hat Frau <Nachname> heute um 14 h den Termin b...  assistenzaerzt*in
# 4                                   ja, war grade da           redacted
#
#     weekday Channel Name            Channel Type Team Name Anonymized Format
# 0  Thursday         None  Direct Message Channel      none       True    CSV
# 1  Thursday         None  Direct Message Channel      none       True    CSV
# 2  Thursday         None  Direct Message Channel      none       True    CSV
# 3   Tuesday         None  Direct Message Channel      none       True    CSV
# 4   Tuesday         None  Direct Message Channel      none       True    CSV
# Saved cleaned DataFrame to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/DF/D_Conver_result_df_clean.xlsx

# %% [markdown]
# Result: `D_Conver_result_df_clean` is a DataFrame containing all messages from the direct channels in the required format for a ConvoKit corpus object.

# %% [markdown]
# #### _________________________

# %% [markdown]
# ## Create Corpus-Objekt  and fill with data

# %% [markdown]
# Corpus für convokit from pandas Methode (https://github.com/CornellNLP/ConvoKit/blob/master/examples/corpus_from_pandas.ipynb)
#
# corpus_directory <br>
#       |-- utterances.jsonl <br>
#       |-- speakers.json<br>
#       |-- conversations.json<br>
#       |-- corpus.json<br>
#       |-- index.json<br>

# %% [markdown]
# In Convokit, the primary data fields for an Utterance object are:
#
# - `id`: a unique identifier for the utterance
# - `speaker`: the ID of the speaker who made the utterance
# - `conversation_id`: the ID of the conversation to which the utterance belongs
# - `reply_to`: the ID of the utterance to which this utterance is a reply (if any)
# - `timestamp`: the timestamp of the utterance
# - `text`: the text of the utterance

# %%
from convokit import Corpus, Speaker, Utterance


# Create Speaker objects with 'sender position' stored as speaker metadata
speakers = {}

for index, row in D_Conver_result_df_clean.iterrows():

    speaker_id = str(row["speaker"])

    if speaker_id not in speakers:
        speakers[speaker_id] = Speaker(
            id=speaker_id,
            meta={
                "sender_position": row["sender position"]
            }
        )


# Create Utterance objects with conversation metadata
utterances = []

for index, row in D_Conver_result_df_clean.iterrows():

    meta = {
        "Channel Name": row["Channel Name"],
        "Channel Type": row["Channel Type"],
        "Team Name": row["Team Name"]
    }

    # Convert empty reply_to values back to None
    reply_to = row["reply_to"]

    if pd.isna(reply_to) or reply_to in ["", "None", "nan"]:
        reply_to = None

    utterance = Utterance(
        id=str(row["id"]),
        speaker=speakers[str(row["speaker"])],
        conversation_id=str(row["conversation_id"]),
        reply_to=reply_to,
        timestamp=int(row["timestamp"]),
        text=str(row["text"]),
        meta=meta
    )

    utterances.append(utterance)


# Create a Corpus object from the utterances
D_corpus = Corpus(utterances=utterances)

print(D_corpus)
# Out:
# <convokit.model.corpus.Corpus object at 0x131a76010>

# %%
# Display a sample utterance for validation
for utterance_id, utterance in D_corpus.utterances.items():
    print("Utterance ID:", utterance_id)
    print("Speaker:", utterance.speaker.id)
    print("Text:", utterance.text)
    print("Conversation ID:", utterance.conversation_id)
    print("Timestamp:", utterance.timestamp)
    print("Metadata:", utterance.meta)
    break  # Display only the first utterance as an example
# Out:
# Utterance ID: 0
# Speaker: Person1
# Text: Willkommen, schön, dass es funktioniert hat!<enter>
# Conversation ID: D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h
# Timestamp: 1641466260
# Metadata: ConvoKitMeta({'Channel Name': None, 'Channel Type': 'Direct Message Channel', 'Team Name': 'none'})

# %%
# Save the corpus object
D_corpus.dump(CORPUS_OUTPUT_DIR / "D_corpus")

print("Saved corpus object to:")
print(CORPUS_OUTPUT_DIR / "D_corpus")
# Out:
# Saved corpus object to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/corpus_objects/D_corpus

# %% [markdown]
# ### Result: `D_corpus`<br>
# The corpus was created as `D_corpus` (`D` represents direct messages). <br>
#
# ---

# %% [markdown]
# ## D-Corpus Object - Initial Overview

# %% [markdown]
# ### Summary Overview of the D_Corpus <br>

# %%
from convokit import Corpus

# Load the saved ConvoKit corpus
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Print summary statistics
D_corpus.print_summary_stats()
# Out:
# Number of Speakers: 2
# Number of Utterances: 4915
# Number of Conversations: 293

# %% [markdown]
# **Note**: The speakers in the individual conversations in the data provided here are numbered consecutively.
# For data protection reasons, the link between the original user ID and the numbering in the export has been removed. <brY>
# However, “summery_stats” assumes a unique speaker designation across all conversations and does not distinguish, for example, between Speaker 1 in Conversation 1 and Speaker 1 in Conversation 2. <br>
# Therefore, the **“Number of Speakers”** in “summery_stats” should be understood as the **maximum number of speakers per conversation in the corpus**!

# %% [markdown]
# ### Total number of utterances:

# %%
total_utterances = len(D_corpus.utterances)
print("Total number of utterances::", total_utterances)
# Out:
# Total number of utterances:: 4915

# %% [markdown]
# ### Data frame of frequencies per conversation<br>
# 'ID', 'Number of Speakers', 'Number of Utterances', 'Number of Words', 'Number of Tokens'

# %%
import spacy
from convokit import Corpus

# Load the spaCy German language model
nlp = spacy.load("de_core_news_sm")

# Load the saved ConvoKit corpus
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Initialize a list to collect the results
data = []

# Iterate over all conversations in the corpus
for conversation in D_corpus.iter_conversations():

    conversation_id = conversation.id
    num_utterances = len(conversation.get_utterance_ids())
    speaker_ids = set()
    num_words = 0
    num_tokens = 0

    # Iterate over all utterances in the conversation
    for utterance_id in conversation.get_utterance_ids():

        utterance = D_corpus.get_utterance(utterance_id)
        speaker_ids.add(utterance.speaker.id)

        doc = nlp(utterance.text)

        # Count words excluding punctuation and whitespace
        num_words += sum(
            1 for token in doc
            if not token.is_punct and not token.is_space
        )

        # Count all tokens excluding whitespace
        num_tokens += sum(
            1 for token in doc
            if not token.is_space
        )

    num_speakers = len(speaker_ids)

    # Add collected values to the result list
    data.append([
        conversation_id,
        num_speakers,
        num_utterances,
        num_words,
        num_tokens
    ])

# Create a DataFrame from the collected results
D_frequency_df = pd.DataFrame(
    data,
    columns=[
        "conversation_id",
        "number_of_speakers",
        "number_of_utterances",
        "number_of_words",
        "number_of_tokens_spacy_sm"
    ]
)

# Display the DataFrame
display(D_frequency_df)

# Save the DataFrame as an Excel file
D_frequency_df.to_excel(
    DF_OUTPUT_DIR / "D_frequency_df.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved DataFrame to:")
print(DF_OUTPUT_DIR / "D_frequency_df.xlsx")
# Out:
#                           conversation_id  number_of_speakers  \
# 0    D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h                   2
# 1        D_oMD_ckqwfkohjbgx3f91keisjh6tuh                   1
# 2        D_oMD_w7135snps3d9xdmqz7ktgapw5o                   2
# 3    D_oMD_ano_xtf5teqg9i8rtcrt6huuwrhu8w                   2
# 4        D_oMD_wh79x5q17pbaz89jw3xrhd31ua                   2
# ..                                    ...                 ...
# 288      D_mMD_pei6gwagftfeij9egd8wkcajye                   2
# 289      D_mMD_fi17kbdm3ibf7x1teyo6sjdwur                   1
# 290  D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch                   1
# 291      D_mMD_7ygxcq5thibbzbsafxk4z8ckqh                   2
# 292      D_mMD_m5gmhf19ajbefq97kemojh98co                   1
#
#      number_of_utterances  number_of_words  number_of_tokens_spacy_sm
# 0                       2               10                         14
# 1                       1               25                         30
# 2                       2               21                         24
# 3                       3              185                        214
# 4                       3              110                        128
# ..                    ...              ...                        ...
# 288                    21              472                        543
# 289                     2              135                        162
# 290                     1                1                          2
# 291                    82             1921                       2310
# 292                     1               68                         88
#
# [293 rows x 5 columns]
# Saved DataFrame to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/DF/D_frequency_df.xlsx

# %% [markdown]
# ### Results:

# %%
# Calculate totals
total_conversations = len(D_frequency_df)
total_utterances = D_frequency_df["number_of_utterances"].sum()
total_words = D_frequency_df["number_of_words"].sum()
total_tokens = D_frequency_df["number_of_tokens_spacy_sm"].sum()

# Print totals
print(f"Total conversations: {total_conversations}")
print(f"Total utterances: {total_utterances}")
print(f"Total words: {total_words}")
print(f"Total tokens: {total_tokens}")
# Out:
# Total conversations: 293
# Total utterances: 4915
# Total words: 97292
# Total tokens: 112939

# %% [markdown]
# # General description of corpus: `D_corpus` <br>
#
# The corpus `D_corpus` of the DocTalk project contains:
#
# - 293 conversations from direct chat channels
# - 4915 utterances after removing empty text messages
# - 97292 words, including stop words
# - 112939 tokens, counted with the German spaCy small model (`de_core_news_sm`)
#
# The corpus consists of German chat transcripts from medical communication contexts involving treatment teams from different specialties.

# %% [markdown]
# ## export: Corpus composision summery of `D_corpus` <br>
# creating and filling 'corpus_composition_summary.xlsx' as result table

# %%
# Create summary row for the direct-message corpus
D_corpus_summary_row = pd.DataFrame([
    {
        "corpus_id": "D_corpus",
        "message_type": "direct",
        "number_of_conversations": total_conversations,
        "number_of_utterances": total_utterances,
        "number_of_words_including_stopwords": total_words,
        "number_of_tokens_spacy_sm": total_tokens,
        "language": "German",
        "spacy_model": "de_core_news_sm",
        "cleaning_status": "empty_text_messages_removed"
    }
])

# Define output file
corpus_summary_file = RESULT_TABLE_DIR / "corpus_composition_summary.xlsx"

# If a summary file already exists, load it and update the direct-message row
if corpus_summary_file.exists():
    corpus_composition_summary_df = pd.read_excel(corpus_summary_file)

    # Remove older direct-message row if it already exists
    corpus_composition_summary_df = corpus_composition_summary_df[
        corpus_composition_summary_df["message_type"] != "direct"
    ]

    # Add updated direct-message row
    corpus_composition_summary_df = pd.concat(
        [corpus_composition_summary_df, D_corpus_summary_row],
        ignore_index=True
    )

else:
    corpus_composition_summary_df = D_corpus_summary_row.copy()

# Display summary table
display(corpus_composition_summary_df)

# Save summary table
corpus_composition_summary_df.to_excel(
    corpus_summary_file,
    index=False,
    engine="openpyxl"
)

print("Saved corpus composition summary to:")
print(corpus_summary_file)
# Out:
#   corpus_id message_type  number_of_conversations  number_of_utterances  \
# 0  G_corpus        group                       86                  2547
# 1  D_corpus       direct                      293                  4915
#
#    number_of_words_including_stopwords  number_of_tokens_spacy_sm language  \
# 0                               107533                     127954   German
# 1                                97292                     112939   German
#
#        spacy_model                                    cleaning_status  \
# 0  de_core_news_sm  empty_text_messages_removed; non_analytical_ch...
# 1  de_core_news_sm                        empty_text_messages_removed
#
#    number_of_words  number_of_tokens
# 0              NaN               NaN
# 1              NaN               NaN
# Saved corpus composition summary to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/corpus_composition_summary.xlsx

# %% [markdown]
# ---

# %% [markdown]
# ## Description of `D_corpus` <br>
#
# ### Distribution of utterances per conversation

# %%
# Count how many conversations have 1, 2, ... n utterances
utterance_counts = (
    D_frequency_df["number_of_utterances"]
    .value_counts()
    .sort_index()
)

# Display the overview
print("Overview of the number of utterances per conversation:")
print(utterance_counts)
# Out:
# Overview of the number of utterances per conversation:
# number_of_utterances
# 1      49
# 2      39
# 3      27
# 4      22
# 5      16
#        ..
# 142     1
# 179     1
# 212     1
# 251     1
# 342     1
# Name: count, Length: 63, dtype: int64

# %%
# Group conversations by number of utterances

utterance_bins = [0, 1, 2, 5, 10, 20, 50, 100, float("inf")]

utterance_bin_labels = [
    "1",
    "2",
    "3-5",
    "6-10",
    "11-20",
    "21-50",
    "51-100",
    ">100"
]

D_frequency_df["utterance_count_group"] = pd.cut(
    D_frequency_df["number_of_utterances"],
    bins=utterance_bins,
    labels=utterance_bin_labels,
    right=True
)

# Count conversations per utterance group
D_utterance_grouped_df = (
    D_frequency_df["utterance_count_group"]
    .value_counts()
    .reindex(utterance_bin_labels)
    .reset_index()
)

D_utterance_grouped_df.columns = [
    "utterance_count_group",
    "number_of_conversations"
]

# Add percentage column
D_utterance_grouped_df["percentage_of_conversations"] = (
    D_utterance_grouped_df["number_of_conversations"]
    / D_utterance_grouped_df["number_of_conversations"].sum()
    * 100
)

# Display grouped table
display(D_utterance_grouped_df)

# Save grouped table
D_utterance_grouped_df.to_excel(
    RESULT_TABLE_DIR / "D_utterance_count_grouped_distribution.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved grouped distribution table to:")
print(RESULT_TABLE_DIR / "D_utterance_count_grouped_distribution.xlsx")
# Out:
#   utterance_count_group  number_of_conversations  percentage_of_conversations
# 0                     1                       49                    16.723549
# 1                     2                       39                    13.310580
# 2                   3-5                       65                    22.184300
# 3                  6-10                       49                    16.723549
# 4                 11-20                       32                    10.921502
# 5                 21-50                       36                    12.286689
# 6                51-100                       15                     5.119454
# 7                  >100                        8                     2.730375
# Saved grouped distribution table to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/D_utterance_count_grouped_distribution.xlsx

# %% [markdown]
# #### Abb.: Grouped distribution of utterances per conversation | Direct-message corpus

# %%
import matplotlib.pyplot as plt

# Sort groups by number of conversations in descending order
plot_df = D_utterance_grouped_df.sort_values(
    by="number_of_conversations",
    ascending=False
)

# Create horizontal bar plot
fig, ax = plt.subplots(figsize=(9, 6))

ax.barh(
    plot_df["utterance_count_group"],
    plot_df["number_of_conversations"],
    color="lightgray",
    edgecolor="black"
)

# Put the largest group at the top
ax.invert_yaxis()

ax.set_title("Grouped distribution of utterances per conversation | Direct-message corpus")
ax.set_xlabel("Number of conversations")
ax.set_ylabel("Number of utterances per conversation")

ax.grid(True, axis="x", linestyle="--", linewidth=0.5)

plt.tight_layout()

# Save figure
plt.savefig(
    FIGURE_OUTPUT_DIR / "D_grouped_utterances_per_conversation_distribution_horizontal.png",
    dpi=300,
    bbox_inches="tight"
)

plt.savefig(
    FIGURE_OUTPUT_DIR / "D_grouped_utterances_per_conversation_distribution_horizontal.svg",
    bbox_inches="tight"
)

plt.show()

print("Saved figure to:")
print(FIGURE_OUTPUT_DIR / "D_grouped_utterances_per_conversation_distribution_horizontal.png")
# Out:
# Saved figure to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/figures/D_grouped_utterances_per_conversation_distribution_horizontal.png

# %% [markdown]
# The grouped distribution of utterances per conversation shows that direct-message communication was dominated by short conversations. Conversations with only one or two utterances formed the largest groups, while longer conversations occurred less frequently.

# %%
# Create descriptive statistics for utterances per conversation
D_utterance_descriptives_df = pd.DataFrame([
    {
        "corpus_id": "D_corpus",
        "message_type": "direct",
        "variable": "number_of_utterances_per_conversation",
        "median": D_frequency_df["number_of_utterances"].median(),
        "mean": D_frequency_df["number_of_utterances"].mean(),
        "min": D_frequency_df["number_of_utterances"].min(),
        "max": D_frequency_df["number_of_utterances"].max(),
        "q1": D_frequency_df["number_of_utterances"].quantile(0.25),
        "q3": D_frequency_df["number_of_utterances"].quantile(0.75),
        "iqr": (
            D_frequency_df["number_of_utterances"].quantile(0.75)
            - D_frequency_df["number_of_utterances"].quantile(0.25)
        )
    }
])

# Display descriptive statistics
display(D_utterance_descriptives_df)

# Save descriptive statistics
D_utterance_descriptives_df.to_excel(
    RESULT_TABLE_DIR / "D_utterances_per_conversation_descriptives.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved utterance descriptives table to:")
print(RESULT_TABLE_DIR / "D_utterances_per_conversation_descriptives.xlsx")
# Out:
#   corpus_id message_type                               variable  median  \
# 0  D_corpus       direct  number_of_utterances_per_conversation     5.0
#
#         mean  min  max   q1    q3   iqr
# 0  16.774744    1  342  2.0  15.0  13.0
# Saved utterance descriptives table to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/D_utterances_per_conversation_descriptives.xlsx

# %%
# Create min-max summary table
D_utterance_min_max_df = pd.DataFrame([
    {
        "corpus_id": "D_corpus",
        "message_type": "direct",
        "variable": "number_of_utterances_per_conversation",
        "min": D_frequency_df["number_of_utterances"].min(),
        "max": D_frequency_df["number_of_utterances"].max()
    }
])

display(D_utterance_min_max_df)
# Out:
#   corpus_id message_type                               variable  min  max
# 0  D_corpus       direct  number_of_utterances_per_conversation    1  342

# %%
D_utterance_min_max_df.to_excel(
    RESULT_TABLE_DIR / "D_utterances_per_conversation_min_max.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved min-max table to:")
print(RESULT_TABLE_DIR / "D_utterances_per_conversation_min_max.xlsx")
# Out:
# Saved min-max table to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/D_utterances_per_conversation_min_max.xlsx

# %%
# Calculate Q1, Q3 and IQR for utterances per direct-message thread
D_q1_utterances_per_conversation = D_frequency_df["number_of_utterances"].quantile(0.25)
D_q3_utterances_per_conversation = D_frequency_df["number_of_utterances"].quantile(0.75)

D_iqr_utterances_per_conversation = (
    D_q3_utterances_per_conversation
    - D_q1_utterances_per_conversation
)

print("Q1 number of utterances per direct-message thread:")
print(D_q1_utterances_per_conversation)

print("Q3 number of utterances per direct-message thread:")
print(D_q3_utterances_per_conversation)

print("IQR number of utterances per direct-message thread:")
print(D_iqr_utterances_per_conversation)
# Out:
# Q1 number of utterances per direct-message thread:
# 2.0
# Q3 number of utterances per direct-message thread:
# 15.0
# IQR number of utterances per direct-message thread:
# 13.0

# %%
# Create Q1, Q3 and IQR summary table
D_utterance_iqr_df = pd.DataFrame([
    {
        "corpus_id": "D_corpus",
        "message_type": "direct",
        "variable": "number_of_utterances_per_direct_message_thread",
        "q1": D_frequency_df["number_of_utterances"].quantile(0.25),
        "q3": D_frequency_df["number_of_utterances"].quantile(0.75),
        "iqr": (
            D_frequency_df["number_of_utterances"].quantile(0.75)
            - D_frequency_df["number_of_utterances"].quantile(0.25)
        )
    }
])

display(D_utterance_iqr_df)

# Save table
D_utterance_iqr_df.to_excel(
    RESULT_TABLE_DIR / "D_utterances_per_direct_message_thread_iqr.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved IQR table to:")
print(RESULT_TABLE_DIR / "D_utterances_per_direct_message_thread_iqr.xlsx")
# Out:
#   corpus_id message_type                                        variable   q1  \
# 0  D_corpus       direct  number_of_utterances_per_direct_message_thread  2.0
#
#      q3   iqr
# 0  15.0  13.0
# Saved IQR table to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/D_utterances_per_direct_message_thread_iqr.xlsx

# %% [markdown]
# The interquartile range of utterances per direct-message thread ranged from 2.0 to 15.0 utterances, with an IQR of 13.0. Thus, the middle 50% of dyadic direct-message threads contained between 2 and 15 utterances across the project period. Together with a median of 5.0 utterances and a maximum of 342 utterances, this indicates a right-skewed distribution with a small number of highly active dyadic communication threads.

# %%
# Calculate cumulative proportions of short direct-message threads

thresholds = [2, 5, 10, 20, 50, 100]

D_short_thread_summary_df = pd.DataFrame([
    {
        "corpus_id": "D_corpus",
        "message_type": "direct",
        "threshold_utterances": f"≤{threshold}",
        "number_of_threads": (
            D_frequency_df["number_of_utterances"] <= threshold
        ).sum(),
        "percentage_of_threads": (
            (D_frequency_df["number_of_utterances"] <= threshold).sum()
            / len(D_frequency_df)
            * 100
        )
    }
    for threshold in thresholds
])

display(D_short_thread_summary_df)

# Save table
D_short_thread_summary_df.to_excel(
    RESULT_TABLE_DIR / "D_short_direct_message_threads_summary.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved short direct-message thread summary to:")
print(RESULT_TABLE_DIR / "D_short_direct_message_threads_summary.xlsx")
# Out:
#   corpus_id message_type threshold_utterances  number_of_threads  \
# 0  D_corpus       direct                   ≤2                 88
# 1  D_corpus       direct                   ≤5                153
# 2  D_corpus       direct                  ≤10                202
# 3  D_corpus       direct                  ≤20                234
# 4  D_corpus       direct                  ≤50                270
# 5  D_corpus       direct                 ≤100                285
#
#    percentage_of_threads
# 0              30.034130
# 1              52.218430
# 2              68.941980
# 3              79.863481
# 4              92.150171
# 5              97.269625
# Saved short direct-message thread summary to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/D_short_direct_message_threads_summary.xlsx

# %% [markdown]
# ---

# %% [markdown]
# ### Number of speakers per conversation <br>
# This is not required for the main analysis, since direct-message conversations should usually involve only one to two persons. This step serves only as a validation check.

# %%
from convokit import Corpus

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Initialize a list to store speaker counts per conversation
data = []

# Iterate over all conversations in the corpus
for conversation in D_corpus.iter_conversations():

    conversation_id = conversation.id
    speaker_ids = set()

    # Collect all speaker IDs within the conversation
    for utterance_id in conversation.get_utterance_ids():
        utterance = D_corpus.get_utterance(utterance_id)
        speaker_ids.add(utterance.speaker.id)

    # Add results to list
    data.append({
        "conversation_id": conversation_id,
        "number_of_speakers": len(speaker_ids),
        "speaker_ids": ", ".join(sorted(speaker_ids))
    })

# Create DataFrame with number of speakers per conversation
D_speaker_validation_df = pd.DataFrame(data)

# Display table
display(D_speaker_validation_df)

# Display distribution of speaker counts
speaker_count_distribution = (
    D_speaker_validation_df["number_of_speakers"]
    .value_counts()
    .sort_index()
)

print("Distribution of number of speakers per conversation:")
print(speaker_count_distribution)

# Check for conversations with more than two speakers
unexpected_speaker_counts = D_speaker_validation_df[
    D_speaker_validation_df["number_of_speakers"] > 2
]

if len(unexpected_speaker_counts) > 0:
    print("\nWarning: Some direct-message conversations include more than two speakers.")
    display(unexpected_speaker_counts)
else:
    print("\nValidation passed: all direct-message conversations include one or two speakers.")

# Save validation table
D_speaker_validation_df.to_excel(
    RESULT_TABLE_DIR / "D_speaker_count_validation.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved validation table to:")
print(RESULT_TABLE_DIR / "D_speaker_count_validation.xlsx")
# Out:
#                           conversation_id  number_of_speakers  \
# 0    D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h                   2
# 1        D_oMD_ckqwfkohjbgx3f91keisjh6tuh                   1
# 2        D_oMD_w7135snps3d9xdmqz7ktgapw5o                   2
# 3    D_oMD_ano_xtf5teqg9i8rtcrt6huuwrhu8w                   2
# 4        D_oMD_wh79x5q17pbaz89jw3xrhd31ua                   2
# ..                                    ...                 ...
# 288      D_mMD_pei6gwagftfeij9egd8wkcajye                   2
# 289      D_mMD_fi17kbdm3ibf7x1teyo6sjdwur                   1
# 290  D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch                   1
# 291      D_mMD_7ygxcq5thibbzbsafxk4z8ckqh                   2
# 292      D_mMD_m5gmhf19ajbefq97kemojh98co                   1
#
#           speaker_ids
# 0    Person1, Person2
# 1             Person1
# 2    Person1, Person2
# 3    Person1, Person2
# 4    Person1, Person2
# ..                ...
# 288  Person1, Person2
# 289           Person1
# 290           Person1
# 291  Person1, Person2
# 292           Person1
#
# [293 rows x 3 columns]
# Distribution of number of speakers per conversation:
# number_of_speakers
# 1     81
# 2    212
# Name: count, dtype: int64
#
# Validation passed: all direct-message conversations include one or two speakers.
# Saved validation table to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/D_speaker_count_validation.xlsx

# %%
from convokit import Corpus

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Initialize lists to store speaker counts and conversation IDs
num_speakers_list = []
conversation_ids = []

# Iterate over all conversations in the corpus
for conversation in D_corpus.iter_conversations():

    speaker_ids = set()

    # Collect speaker IDs from all utterances in the conversation
    for utterance_id in conversation.get_utterance_ids():
        utterance = D_corpus.get_utterance(utterance_id)
        speaker_ids.add(utterance.speaker.id)

    num_speakers = len(speaker_ids)

    print(
        "Conversation ID:", conversation.id,
        "- Number of speakers:", num_speakers
    )

    num_speakers_list.append(num_speakers)
    conversation_ids.append(conversation.id)
# Out:
# Conversation ID: D_oMD_ano_dq64b8dm7j8zfjrqxj5c7waw1h - Number of speakers: 2
# Conversation ID: D_oMD_ckqwfkohjbgx3f91keisjh6tuh - Number of speakers: 1
# Conversation ID: D_oMD_w7135snps3d9xdmqz7ktgapw5o - Number of speakers: 2
# Conversation ID: D_oMD_ano_xtf5teqg9i8rtcrt6huuwrhu8w - Number of speakers: 2
# Conversation ID: D_oMD_wh79x5q17pbaz89jw3xrhd31ua - Number of speakers: 2
# Conversation ID: D_oMD_kheihukp57bzbyyzkhwa95n5iw - Number of speakers: 1
# Conversation ID: D_oMD_6m9xoczsebdx8ks7o897cqgusr - Number of speakers: 2
# Conversation ID: D_oMD_o4arupbmxpy4jyqiorffyrak7r - Number of speakers: 2
# Conversation ID: D_oMD_ano_1s4kyirj1t8u7n66b4abg8jo7y - Number of speakers: 1
# Conversation ID: D_oMD_cbih9n17bibo7g7jd1sa736a8o - Number of speakers: 2
# Conversation ID: D_mMD_onk9o47dhprzubq3gzz5cb8hwy - Number of speakers: 2
# Conversation ID: D_oMD_u5y6sm4i4jrnfxwb53iuzr7qqr - Number of speakers: 2
# Conversation ID: D_mMD_mk6d6xq1d7g4ixj9zkabz8upyr - Number of speakers: 2
# Conversation ID: D_oMD_ano_6wq673qc9jdixpxs35e4dogxhy - Number of speakers: 1
# Conversation ID: D_mMD_qjubuxjokpdp5ezxziwn1ufw4a - Number of speakers: 2
# Conversation ID: D_oMD_ano_agaooigawfnnbp3ysgge9kemth - Number of speakers: 1
# Conversation ID: D_oMD_ano_3b11znij3bg8fg3s5ukffbm35a - Number of speakers: 2
# Conversation ID: D_mMD_o1e97uza138ftkfaanjkpfomiw - Number of speakers: 2
# Conversation ID: D_oMD_ano_5mkhyo7bu3n18d5t1k46rc13xo - Number of speakers: 2
# Conversation ID: D_mMD_wybzqww4tbr6jfq7sjjx5c76by - Number of speakers: 2
# Conversation ID: D_oMD_igxc77mfcpd3zyitcjoe193yso - Number of speakers: 2
# Conversation ID: D_oMD_ano_g9b1bjhnx3bkfcucyhbx17aptc - Number of speakers: 2
# Conversation ID: D_oMD_ano_prshntjgrpdgjg4q3y6yee669h - Number of speakers: 1
# Conversation ID: D_mMD_efqb8bk4sbyn5j7iubwd5nspaa - Number of speakers: 2
# Conversation ID: D_oMD_6bpai5erxjyezdd6edz1ik4sbe - Number of speakers: 2
# Conversation ID: D_oMD_ti5oixwkspr83kfc6qcjwptbqh - Number of speakers: 1
# Conversation ID: D_oMD_xjnekiedz7yx7r1qw8q3thhz8o - Number of speakers: 1
# Conversation ID: D_mMD_8cq6azqwfpybijk374f411zo9r - Number of speakers: 1
# Conversation ID: D_oMD_bnhpt5bf6pny5pok78sdq6xq4h - Number of speakers: 1
# Conversation ID: D_oMD_ano_99rpsxpc5pgcfydxcjtx6quuio - Number of speakers: 2
# Conversation ID: D_mMD_pei6gwagftfeij9egd8wkcajye - Number of speakers: 2
# Conversation ID: D_mMD_fi17kbdm3ibf7x1teyo6sjdwur - Number of speakers: 1
# Conversation ID: D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch - Number of speakers: 1
# Conversation ID: D_mMD_7ygxcq5thibbzbsafxk4z8ckqh - Number of speakers: 2
# Conversation ID: D_mMD_m5gmhf19ajbefq97kemojh98co - Number of speakers: 1

# %%
from convokit import Corpus

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Lists for conversation-level and utterance-level results
one_speaker_conversation_rows = []
one_speaker_text_rows = []

# Iterate over all conversations in the corpus
for conversation in D_corpus.iter_conversations():

    conversation_id = conversation.id
    utterance_ids = conversation.get_utterance_ids()

    speaker_ids = set()
    utterance_data = []

    # Collect speaker IDs and utterance data for the current conversation
    for utterance_id in utterance_ids:
        utterance = D_corpus.get_utterance(utterance_id)
        speaker_ids.add(utterance.speaker.id)

        utterance_data.append({
            "utterance_id": utterance.id,
            "speaker": utterance.speaker.id,
            "timestamp": utterance.timestamp,
            "text": utterance.text,
            "Channel Name": utterance.meta.get("Channel Name"),
            "Channel Type": utterance.meta.get("Channel Type"),
            "Team Name": utterance.meta.get("Team Name")
        })

    # Keep only conversations with exactly one speaker
    if len(speaker_ids) == 1:

        speaker_id = list(speaker_ids)[0]

        # Sort utterances by timestamp
        utterance_data = sorted(
            utterance_data,
            key=lambda x: x["timestamp"]
        )

        # Combine all utterance texts into one column
        combined_text = "\n\n---\n\n".join(
            item["text"] for item in utterance_data
        )

        # Combine utterance IDs for traceability
        combined_utterance_ids = "; ".join(
            item["utterance_id"] for item in utterance_data
        )

        # Store conversation-level information with appended text column
        one_speaker_conversation_rows.append({
            "conversation_id": conversation_id,
            "number_of_speakers": len(speaker_ids),
            "speaker_id": speaker_id,
            "number_of_utterances": len(utterance_ids),
            "utterance_ids": combined_utterance_ids,
            "combined_utterance_texts": combined_text
        })

        # Store utterance-level information as additional detailed sheet
        for item in utterance_data:
            one_speaker_text_rows.append({
                "conversation_id": conversation_id,
                "utterance_id": item["utterance_id"],
                "speaker": item["speaker"],
                "timestamp": item["timestamp"],
                "text": item["text"],
                "Channel Name": item["Channel Name"],
                "Channel Type": item["Channel Type"],
                "Team Name": item["Team Name"]
            })

# Create DataFrames
D_one_speaker_conversations_df = pd.DataFrame(one_speaker_conversation_rows)
D_one_speaker_texts_df = pd.DataFrame(one_speaker_text_rows)

# Display results
print("Number of one-speaker conversations:", len(D_one_speaker_conversations_df))
print("Number of utterances in one-speaker conversations:", len(D_one_speaker_texts_df))

display(D_one_speaker_conversations_df)

# Save results to Excel
output_file = RESULT_TABLE_DIR / "D_one_speaker_conversations_texts.xlsx"

with pd.ExcelWriter(output_file, engine="openpyxl") as writer:

    # Sheet 1: conversation overview with appended combined utterance texts
    D_one_speaker_conversations_df.to_excel(
        writer,
        sheet_name="conversations_with_texts",
        index=False
    )

    # Sheet 2: utterance-level long format
    D_one_speaker_texts_df.to_excel(
        writer,
        sheet_name="utterances_long_format",
        index=False
    )

print("Saved one-speaker conversation texts to:")
print(output_file)
# Out:
# Number of one-speaker conversations: 81
# Number of utterances in one-speaker conversations: 239
#                          conversation_id  number_of_speakers speaker_id  \
# 0       D_oMD_ckqwfkohjbgx3f91keisjh6tuh                   1    Person1
# 1       D_oMD_kheihukp57bzbyyzkhwa95n5iw                   1    Person1
# 2   D_oMD_ano_1s4kyirj1t8u7n66b4abg8jo7y                   1    Person1
# 3   D_oMD_ano_6wq673qc9jdixpxs35e4dogxhy                   1    Person1
# 4   D_oMD_ano_agaooigawfnnbp3ysgge9kemth                   1    Person1
# ..                                   ...                 ...        ...
# 76      D_mMD_8cq6azqwfpybijk374f411zo9r                   1    Person1
# 77      D_oMD_bnhpt5bf6pny5pok78sdq6xq4h                   1    Person1
# 78      D_mMD_fi17kbdm3ibf7x1teyo6sjdwur                   1    Person1
# 79  D_oMD_ano_cea6fr3i13bppnq3hoj8kezwch                   1    Person1
# 80      D_mMD_m5gmhf19ajbefq97kemojh98co                   1    Person1
#
#     number_of_utterances                             utterance_ids  \
# 0                      1                                         2
# 1                      1                                        11
# 2                      1                                        27
# 3                      1                                       264
# 4                      3                             285; 283; 284
# ..                   ...                                       ...
# 76                     7  4836; 4837; 4838; 4839; 4840; 4841; 4842
# 77                     1                                      4843
# 78                     2                                4867; 4868
# 79                     1                                      4869
# 80                     1                                      4956
#
#                              combined_utterance_texts
# 0   Liebe <Vorname>, wenn Arztbriefe fertig sind a...
# 1   Moin! Es hat sich jetzt kurzfristig ergeben, d...
# 2          Lieber Herr <Nachname>, hier mal zum Test
# 3   Liebe Kolleg:innen, könntet ihr mich zum Psych...
# 4   Lieber <Vorname>, kannst Du bitte den folgende...
# ..                                                ...
# 76  Liebe <Vorname>,\n\n---\n\nzur Übergabe vom VD...
# 77                                         <Passwort>
# 78  liebe <Vorname>, Fr. <Nachname> hat selbst ihr...
# 79                        https://www.ueberleben.org/
# 80  lieber <Vorname>, vermutlich siehst Du am Do. ...
#
# [81 rows x 6 columns]
# Saved one-speaker conversation texts to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/D_one_speaker_conversations_texts.xlsx
# /var/folders/7w/h2mhddw95r5_yz5g6jrf7s1w0000gn/T/ipykernel_86752/702150251.py:94: UserWarning: Cell contents too long (35882), truncated to 32767 characters
#   D_one_speaker_conversations_df.to_excel(

# %% [markdown]
# Validation showed that conversations with only one speaker do not represent empty or invalid text entries. Instead, these cases correspond to direct messages that did not receive a reply within the exported chat data.
#
# ---

# %% [markdown]
# ## Determination of the average word count per utterance

# %%
import spacy
from convokit import Corpus

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Load the German spaCy model
nlp = spacy.load("de_core_news_sm")


def assign_utterance_count_group(num_utterances):
    # Assign conversations to utterance-count groups
    if num_utterances == 1:
        return "1"
    elif num_utterances == 2:
        return "2"
    elif num_utterances <= 5:
        return "3-5"
    elif num_utterances <= 10:
        return "6-10"
    elif num_utterances <= 20:
        return "11-20"
    elif num_utterances <= 50:
        return "21-50"
    elif num_utterances <= 100:
        return "51-100"
    else:
        return ">100"


def analyze_utterance_stats(corpus):
    # Define group order
    group_order = [
        "1",
        "2",
        "3-5",
        "6-10",
        "11-20",
        "21-50",
        "51-100",
        ">100"
    ]

    # Define result containers
    word_count_categories = {group: [] for group in group_order}
    sentence_count_categories = {group: [] for group in group_order}
    words_per_sentence_categories = {group: [] for group in group_order}
    conversation_count_categories = {group: 0 for group in group_order}

    # Iterate over all conversations in the corpus
    for conversation in corpus.iter_conversations():

        utterance_ids = conversation.get_utterance_ids()
        num_utterances = len(utterance_ids)

        utterance_count_group = assign_utterance_count_group(num_utterances)

        # Count one conversation in the corresponding group
        conversation_count_categories[utterance_count_group] += 1

        # Iterate over all utterances in the conversation
        for utterance_id in utterance_ids:

            utterance = corpus.get_utterance(utterance_id)
            text = utterance.text if utterance.text is not None else ""

            doc = nlp(text)

            # Count words excluding punctuation and whitespace
            word_count = sum(
                1 for token in doc
                if not token.is_punct and not token.is_space
            )

            # Count sentences
            sentence_count = len(list(doc.sents))

            # Avoid division by zero
            words_per_sentence = (
                word_count / sentence_count
                if sentence_count > 0
                else 0
            )

            word_count_categories[utterance_count_group].append(word_count)
            sentence_count_categories[utterance_count_group].append(sentence_count)
            words_per_sentence_categories[utterance_count_group].append(words_per_sentence)

    # Create result table
    result_rows = []

    for group in group_order:

        average_words = (
            sum(word_count_categories[group]) / len(word_count_categories[group])
            if word_count_categories[group]
            else 0
        )

        average_sentences = (
            sum(sentence_count_categories[group]) / len(sentence_count_categories[group])
            if sentence_count_categories[group]
            else 0
        )

        average_words_per_sentence = (
            sum(words_per_sentence_categories[group])
            / len(words_per_sentence_categories[group])
            if words_per_sentence_categories[group]
            else 0
        )

        result_rows.append({
            "utterance_count_group": group,
            "number_of_conversations_in_group": conversation_count_categories[group],
            "number_of_utterances_in_group": len(word_count_categories[group]),
            "average_words_per_utterance": round(average_words, 2),
            "average_sentences_per_utterance": round(average_sentences, 2),
            "average_words_per_sentence": round(average_words_per_sentence, 2)
        })

    result_df = pd.DataFrame(result_rows)

    return result_df


# Run analysis
D_utterance_stats_by_conversation_length_df = analyze_utterance_stats(D_corpus)

# Display result table
display(D_utterance_stats_by_conversation_length_df)

# Save result table
D_utterance_stats_by_conversation_length_df.to_excel(
    RESULT_TABLE_DIR / "D_utterance_stats_by_conversation_length.xlsx",
    index=False,
    engine="openpyxl"
)

print("Saved utterance statistics table to:")
print(RESULT_TABLE_DIR / "D_utterance_stats_by_conversation_length.xlsx")
# Out:
#   utterance_count_group  number_of_conversations_in_group  \
# 0                     1                                49
# 1                     2                                39
# 2                   3-5                                65
# 3                  6-10                                49
# 4                 11-20                                32
# 5                 21-50                                36
# 6                51-100                                15
# 7                  >100                                 8
#
#    number_of_utterances_in_group  average_words_per_utterance  \
# 0                             49                        30.82
# 1                             78                        18.69
# 2                            249                        24.94
# 3                            367                        23.03
# 4                            468                        20.76
# 5                           1192                        23.09
# 6                           1037                        21.67
# 7                           1475                        13.53
#
#    average_sentences_per_utterance  average_words_per_sentence
# 0                             3.96                        7.06
# 1                             2.19                        7.95
# 2                             3.18                        7.62
# 3                             2.72                        8.48
# 4                             2.43                        8.49
# 5                             2.74                        8.36
# 6                             2.31                        9.34
# 7                             1.76                        7.29
# Saved utterance statistics table to:
# /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/D_utterance_stats_by_conversation_length.xlsx

# %% [markdown]
# Across conversation-length groups, utterances in direct-message conversations contained on average between 13.53 and 30.82 words. One-utterance conversations showed the highest average utterance length, suggesting that these cases often consisted of self-contained messages that did not receive a reply. In contrast, very long conversations with more than 100 utterances showed the lowest average word count per utterance, indicating a more interactive communication pattern with shorter conversational turns.
#
# ---

# %% [markdown]
# # Time Analysis of `D_corpus` <br>
# ## Message frequencies by hour of day

# %%
import convokit
from convokit import Corpus
import pandas as pd
from pathlib import Path

# Define the path to the ConvoKit corpus
corpus_path = Path.cwd()

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")



# Extract timestamps from all utterances
timestamps = []

for conversation in D_corpus.iter_conversations():
    for utterance in conversation.iter_utterances():
        timestamps.append(utterance.timestamp)

# Create a DataFrame from the timestamps
timestamp_df = pd.DataFrame(timestamps, columns=["timestamp"])

# Remove missing timestamps
timestamp_df = timestamp_df.dropna(subset=["timestamp"]).copy()

# Convert timestamps to numeric values
timestamp_df["timestamp"] = pd.to_numeric(
    timestamp_df["timestamp"],
    errors="coerce"
)

# Remove invalid timestamps after conversion
timestamp_df = timestamp_df.dropna(subset=["timestamp"]).copy()

# Convert Unix timestamps to datetime format
timestamp_df["datetime"] = pd.to_datetime(
    timestamp_df["timestamp"],
    unit="s"
)

# Extract weekday and hour
timestamp_df["weekday"] = timestamp_df["datetime"].dt.weekday
timestamp_df["hour"] = timestamp_df["datetime"].dt.hour

# Add weekday names
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday"
}

timestamp_df["weekday_name"] = timestamp_df["weekday"].map(weekday_names)

# Count utterances by weekday and hour
weekday_hour_count = (
    timestamp_df
    .groupby(["weekday", "weekday_name", "hour"])
    .size()
    .reset_index(name="count")
)

# Sort by frequency
sorted_weekday_hour_count = weekday_hour_count.sort_values(
    by="count",
    ascending=False
)

print(sorted_weekday_hour_count)
# Out:
#     weekday weekday_name  hour  count
# 34        2    Wednesday    12    169
# 6         0       Monday    11    169
# 32        2    Wednesday    10    163
# 5         0       Monday    10    162
# 18        1      Tuesday    10    151
# ..      ...          ...   ...    ...
# 40        2    Wednesday    19      1
# 79        6       Sunday     9      1
# 26        1      Tuesday    19      1
# 81        6       Sunday    11      1
# 82        6       Sunday    18      1
#
# [83 rows x 4 columns]

# %%
import convokit
from convokit import Corpus
import pandas as pd

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Extract timestamps from all utterances
timestamps = []

for conversation in D_corpus.iter_conversations():
    for utterance in conversation.iter_utterances():
        timestamps.append(utterance.timestamp)

# Create a DataFrame from the timestamps
timestamp_df = pd.DataFrame(timestamps, columns=["timestamp"])

# Remove missing timestamps
timestamp_df = timestamp_df.dropna(subset=["timestamp"]).copy()

# Convert timestamps to numeric values
timestamp_df["timestamp"] = pd.to_numeric(
    timestamp_df["timestamp"],
    errors="coerce"
)

# Remove invalid timestamps after conversion
timestamp_df = timestamp_df.dropna(subset=["timestamp"]).copy()

# Convert Unix timestamps to readable datetime format
# Use unit="s" for Unix timestamps stored in seconds
timestamp_df["datetime"] = pd.to_datetime(
    timestamp_df["timestamp"],
    unit="s"
)

# Extract weekday and hour
timestamp_df["weekday"] = timestamp_df["datetime"].dt.weekday
timestamp_df["hour"] = timestamp_df["datetime"].dt.hour

# Add readable weekday names
weekday_names = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday"
}

timestamp_df["weekday_name"] = timestamp_df["weekday"].map(weekday_names)

# Count utterances by weekday and hour
weekday_hour_count = (
    timestamp_df
    .groupby(["weekday", "weekday_name", "hour"])
    .size()
    .reset_index(name="count")
)

# Sort the data by frequency
sorted_weekday_hour_count = weekday_hour_count.sort_values(
    by="count",
    ascending=False
)

print(sorted_weekday_hour_count)
# Out:
#     weekday weekday_name  hour  count
# 34        2    Wednesday    12    169
# 6         0       Monday    11    169
# 32        2    Wednesday    10    163
# 5         0       Monday    10    162
# 18        1      Tuesday    10    151
# ..      ...          ...   ...    ...
# 40        2    Wednesday    19      1
# 79        6       Sunday     9      1
# 26        1      Tuesday    19      1
# 81        6       Sunday    11      1
# 82        6       Sunday    18      1
#
# [83 rows x 4 columns]

# %% [markdown]
# ### Visualize Direct messages over day

# %%
import numpy as np
import convokit
from convokit import Corpus
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Extract timestamps from all utterances
timestamps = []

for convo in D_corpus.iter_conversations():
    for utt in convo.iter_utterances():
        timestamps.append(utt.timestamp)

# Create DataFrame from timestamps
df = pd.DataFrame(timestamps, columns=["timestamp"])

# Validate raw timestamps
print("Number of timestamps:", len(df))
print("Number of missing timestamps:", df["timestamp"].isna().sum())
print("Minimum raw timestamp:", df["timestamp"].min())
print("Maximum raw timestamp:", df["timestamp"].max())

# Convert Unix timestamps to readable datetime format
df["datetime"] = pd.to_datetime(df["timestamp"], unit="s", errors="coerce")

# Validate converted timestamps
print("Number of invalid converted timestamps:", df["datetime"].isna().sum())
print("Minimum datetime:", df["datetime"].min())
print("Maximum datetime:", df["datetime"].max())

# Extract hour of day
df["hour"] = df["datetime"].dt.hour

# Count messages by hour
hour_count = df.groupby("hour").size().reset_index(name="count")

# Ensure that all 24 hours are represented, including hours with zero messages
all_hours = pd.DataFrame({"hour": range(24)})
hour_count = all_hours.merge(hour_count, on="hour", how="left")
hour_count["count"] = hour_count["count"].fillna(0).astype(int)

# Calculate relative frequencies
total_messages = hour_count["count"].sum()
hour_count["relative_frequency"] = (
    hour_count["count"] / total_messages
) * 100

# Display table
display(hour_count)

# Create output directory if it does not exist 
output_dir = OUTPUT_DIR / "results" / "time" / "Abb"
output_dir.mkdir(parents=True, exist_ok=True)

# Visualize message frequency as a horizontal bar chart
plt.figure(figsize=(14, 8))

# Define pastel salmon color
pastel_salmon = (1.0, 0.8, 0.7)

bars = plt.barh(
    hour_count["hour"],
    hour_count["count"],
    color="lightgray"
)

# Add value labels to each bar
for bar, count, rel_freq in zip(
    bars,
    hour_count["count"],
    hour_count["relative_frequency"]
):
    plt.text(
        bar.get_width() + max(hour_count["count"]) * 0.01,
        bar.get_y() + bar.get_height() / 2,
        f"{count} ({rel_freq:.2f}%)",
        va="center",
        fontsize=8
    )

plt.title("Message frequency in direct messages by hour of day")
plt.ylabel("Hour of day")
plt.xlabel("Number of messages")

# Format y-axis labels
hour_labels = [f"{hour}:00–{hour + 1}:00" for hour in range(24)]
plt.yticks(range(24), hour_labels, fontsize=8)

plt.grid(axis="x", linestyle="--", alpha=0.7)

# Invert y-axis so the day starts at the top
plt.gca().invert_yaxis()

# Set x-axis limit dynamically
plt.xlim(0, max(hour_count["count"]) * 1.15)

plt.tight_layout()

# Save figure in high resolution
plt.savefig(output_dir / "Dir_HaeuStd.png", dpi=300)

plt.show()
# Out:
# Number of timestamps: 4915
# Number of missing timestamps: 0
# Minimum raw timestamp: 1641187620
# Maximum raw timestamp: 1641753300
# Number of invalid converted timestamps: 0
# Minimum datetime: 2022-01-03 05:27:00
# Maximum datetime: 2022-01-09 18:35:00
#     hour  count  relative_frequency
# 0      0      0            0.000000
# 1      1      0            0.000000
# 2      2      0            0.000000
# 3      3      0            0.000000
# 4      4      0            0.000000
# 5      5     30            0.610376
# 6      6    325            6.612411
# 7      7    421            8.565615
# 8      8    439            8.931841
# 9      9    586           11.922686
# 10    10    721           14.669379
# 11    11    589           11.983723
# 12    12    547           11.129196
# 13    13    451            9.175992
# 14    14    428            8.708037
# 15    15    210            4.272635
# 16    16    126            2.563581
# 17    17     35            0.712106
# 18    18      4            0.081384
# 19    19      2            0.040692
# 20    20      1            0.020346
# 21    21      0            0.000000
# 22    22      0            0.000000
# 23    23      0            0.000000

# %%
from pathlib import Path
import pandas as pd

# ------------------------------------------------------------
# Create hourly distribution table for direct messages
# This table is prepared for later combination with group messages
# Current ConvoKit corpus object: D_corpus
# Uses the path variables defined in the notebook setup
# ------------------------------------------------------------

# 0. Define output directories based on existing setup variables

# Direct-message-specific intermediate results:
# Code_KorpusAnalyse/1_An_direktNachrichten/output/results/time
DIRECT_TIME_OUTPUT_DIR = OUTPUT_DIR / "results" / "time"

# Shared table for later combined analysis:
# Code_KorpusAnalyse/output/results/tables/time
COMBINED_TIME_OUTPUT_DIR = RESULT_TABLE_DIR / "time"

DIRECT_TIME_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
COMBINED_TIME_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


# 1. Extract timestamps from all utterances in the direct-message ConvoKit corpus
timestamps = []

for convo in D_corpus.iter_conversations():
    for utt in convo.iter_utterances():
        timestamps.append(utt.timestamp)


# 2. Create DataFrame with raw timestamps
direct_timestamp_df = pd.DataFrame(timestamps, columns=["timestamp"])


# 3. Convert Unix timestamps to datetime
direct_timestamp_df["datetime"] = pd.to_datetime(
    direct_timestamp_df["timestamp"],
    unit="s",
    errors="coerce"
)


# 4. Extract hour of day
direct_timestamp_df["hour"] = direct_timestamp_df["datetime"].dt.hour


# 5. Count messages by hour
direct_hour_count = (
    direct_timestamp_df
    .groupby("hour")
    .size()
    .reset_index(name="count")
)


# 6. Ensure that all 24 hours are represented
all_hours = pd.DataFrame({"hour": range(24)})

direct_hour_count = all_hours.merge(
    direct_hour_count,
    on="hour",
    how="left"
)

direct_hour_count["count"] = (
    direct_hour_count["count"]
    .fillna(0)
    .astype(int)
)


# 7. Calculate relative frequencies
total_direct_messages = direct_hour_count["count"].sum()

direct_hour_count["relative_frequency"] = (
    direct_hour_count["count"] / total_direct_messages
) * 100


# 8. Add message type identifier
direct_hour_count["message_type"] = "Direct messages"


# 9. Add readable hour interval
direct_hour_count["hour_interval"] = direct_hour_count["hour"].apply(
    lambda x: f"{x}:00–{x + 1}:00"
)


# 10. Create final clean analysis table in long format
direct_hourly_distribution = direct_hour_count[
    ["message_type", "hour", "hour_interval", "count", "relative_frequency"]
].copy()


# 11. Save direct-message-specific intermediate results
direct_timestamp_df.to_csv(
    DIRECT_TIME_OUTPUT_DIR / "direct_messages_timestamps.csv",
    index=False,
    encoding="utf-8"
)

direct_hour_count.to_csv(
    DIRECT_TIME_OUTPUT_DIR / "direct_messages_hour_count_raw.csv",
    index=False,
    encoding="utf-8"
)

direct_hourly_distribution.to_csv(
    DIRECT_TIME_OUTPUT_DIR / "direct_messages_hourly_distribution.csv",
    index=False,
    encoding="utf-8"
)


# 12. Save first version of the later combined table
# Group message data can later be appended to this file.
combined_hourly_distribution = direct_hourly_distribution.copy()

combined_hourly_distribution.to_csv(
    COMBINED_TIME_OUTPUT_DIR / "combined_messages_hourly_distribution.csv",
    index=False,
    encoding="utf-8"
)


# 13. Display and validate result
display(direct_hourly_distribution)

print("Direct message hourly distribution table created and saved.")

print("\nPath check:")
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
print("Direct-message time output directory:", DIRECT_TIME_OUTPUT_DIR)
print("Combined time table output directory:", COMBINED_TIME_OUTPUT_DIR)

print("\nValidation:")
print("Rows:", len(direct_hourly_distribution))
print("Total direct messages:", direct_hourly_distribution["count"].sum())
print("Number of extracted timestamps:", len(direct_timestamp_df))
print("Number of missing raw timestamps:", direct_timestamp_df["timestamp"].isna().sum())
print("Number of missing datetime values:", direct_timestamp_df["datetime"].isna().sum())
print("Minimum raw timestamp:", direct_timestamp_df["timestamp"].min())
print("Maximum raw timestamp:", direct_timestamp_df["timestamp"].max())
print("Minimum datetime:", direct_timestamp_df["datetime"].min())
print("Maximum datetime:", direct_timestamp_df["datetime"].max())

print("\nAggregation check:")
print(len(direct_timestamp_df) == direct_hourly_distribution["count"].sum())
# Out:
#        message_type  hour hour_interval  count  relative_frequency
# 0   Direct messages     0     0:00–1:00      0            0.000000
# 1   Direct messages     1     1:00–2:00      0            0.000000
# 2   Direct messages     2     2:00–3:00      0            0.000000
# 3   Direct messages     3     3:00–4:00      0            0.000000
# 4   Direct messages     4     4:00–5:00      0            0.000000
# 5   Direct messages     5     5:00–6:00     30            0.610376
# 6   Direct messages     6     6:00–7:00    325            6.612411
# 7   Direct messages     7     7:00–8:00    421            8.565615
# 8   Direct messages     8     8:00–9:00    439            8.931841
# 9   Direct messages     9    9:00–10:00    586           11.922686
# 10  Direct messages    10   10:00–11:00    721           14.669379
# 11  Direct messages    11   11:00–12:00    589           11.983723
# 12  Direct messages    12   12:00–13:00    547           11.129196
# 13  Direct messages    13   13:00–14:00    451            9.175992
# 14  Direct messages    14   14:00–15:00    428            8.708037
# 15  Direct messages    15   15:00–16:00    210            4.272635
# 16  Direct messages    16   16:00–17:00    126            2.563581
# 17  Direct messages    17   17:00–18:00     35            0.712106
# 18  Direct messages    18   18:00–19:00      4            0.081384
# 19  Direct messages    19   19:00–20:00      2            0.040692
# 20  Direct messages    20   20:00–21:00      1            0.020346
# 21  Direct messages    21   21:00–22:00      0            0.000000
# 22  Direct messages    22   22:00–23:00      0            0.000000
# 23  Direct messages    23   23:00–24:00      0            0.000000
# Direct message hourly distribution table created and saved.
#
# Path check:
# NOTEBOOK_DIR: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis
# PROJECT_DIR: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse
# Direct-message time output directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/results/time
# Combined time table output directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/time
#
# Validation:
# Rows: 24
# Total direct messages: 4915
# Number of extracted timestamps: 4915
# Number of missing raw timestamps: 0
# Number of missing datetime values: 0
# Minimum raw timestamp: 1641187620
# Maximum raw timestamp: 1641753300
# Minimum datetime: 2022-01-03 05:27:00
# Maximum datetime: 2022-01-09 18:35:00
#
# Aggregation check:
# True

# %% [markdown]
# ## Message frequencies by hour of week

# %%
import numpy as np
import convokit
from convokit import Corpus
import pandas as pd
from pathlib import Path

# ------------------------------------------------------------
# Analyze message frequencies by weekday for direct messages
# Current notebook directory:
# Code_KorpusAnalyse/1_An_direktNachrichten
# ------------------------------------------------------------

# Load the saved ConvoKit corpus from the direct-message corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Extract timestamps from all utterances
timestamps = []

for convo in D_corpus.iter_conversations():
    for utt in convo.iter_utterances():
        timestamps.append(utt.timestamp)

# Create DataFrame from timestamps
weekday_timestamp_df = pd.DataFrame(timestamps, columns=["timestamp"])

# Validate raw timestamps
print("Number of timestamps:", len(weekday_timestamp_df))
print("Number of missing timestamps:", weekday_timestamp_df["timestamp"].isna().sum())
print("Minimum raw timestamp:", weekday_timestamp_df["timestamp"].min())
print("Maximum raw timestamp:", weekday_timestamp_df["timestamp"].max())

# Convert Unix timestamps to readable datetime format
weekday_timestamp_df["datetime"] = pd.to_datetime(
    weekday_timestamp_df["timestamp"],
    unit="s",
    errors="coerce"
)

# Validate converted timestamps
print("Number of invalid converted timestamps:", weekday_timestamp_df["datetime"].isna().sum())
print("Minimum datetime:", weekday_timestamp_df["datetime"].min())
print("Maximum datetime:", weekday_timestamp_df["datetime"].max())

# Extract weekday
# Monday = 0, Sunday = 6
weekday_timestamp_df["weekday"] = weekday_timestamp_df["datetime"].dt.dayofweek

# Count messages by weekday
weekday_count = (
    weekday_timestamp_df
    .groupby("weekday")
    .size()
    .reset_index(name="count")
)

# Ensure that all seven weekdays are represented, including days with zero messages
all_weekdays = pd.DataFrame({"weekday": range(7)})

weekday_count = all_weekdays.merge(
    weekday_count,
    on="weekday",
    how="left"
)

weekday_count["count"] = weekday_count["count"].fillna(0).astype(int)

# Add weekday labels
weekday_labels = [
    "Monday",
    "Tuesday",
    "Wednesday",
    "Thursday",
    "Friday",
    "Saturday",
    "Sunday"
]

weekday_count["weekday_name"] = weekday_count["weekday"].map(
    lambda x: weekday_labels[x]
)

# Reorder columns
weekday_count = weekday_count[
    ["weekday", "weekday_name", "count"]
].copy()

# Display result
display(weekday_count)

# Validation
print("Total messages:", weekday_count["count"].sum())
print("Number of extracted timestamps:", len(weekday_timestamp_df))
print("Aggregation check:", len(weekday_timestamp_df) == weekday_count["count"].sum())
# Out:
# Number of timestamps: 4915
# Number of missing timestamps: 0
# Minimum raw timestamp: 1641187620
# Maximum raw timestamp: 1641753300
# Number of invalid converted timestamps: 0
# Minimum datetime: 2022-01-03 05:27:00
# Maximum datetime: 2022-01-09 18:35:00
#    weekday weekday_name  count
# 0        0       Monday   1045
# 1        1      Tuesday   1006
# 2        2    Wednesday   1058
# 3        3     Thursday    976
# 4        4       Friday    783
# 5        5     Saturday     33
# 6        6       Sunday     14
# Total messages: 4915
# Number of extracted timestamps: 4915
# Aggregation check: True

# %% [markdown]
# ### Visualization Message frequencies by hour of week

# %%
import matplotlib.pyplot as plt
from pathlib import Path

# ------------------------------------------------------------
# Plot message frequencies by weekday for direct messages
# Assumption: weekday_count already contains the columns:
# "weekday", "weekday_name", and "count"
# ------------------------------------------------------------

# Create output directory for the figure
# Target:
# Code_KorpusAnalyse/1_An_direktNachrichten/output/results/time/Abb
figure_output_dir = OUTPUT_DIR / "results" / "time" / "Abb"
figure_output_dir.mkdir(parents=True, exist_ok=True)

# Define pastel salmon color
pastel_salmon = (1.0, 0.8, 0.7)

# Create figure
plt.figure(figsize=(10, 6))

bars = plt.bar(
    weekday_count["weekday_name"],
    weekday_count["count"],
    color="lightgray"
)

plt.xlabel("Weekday")
plt.ylabel("Number of messages")
plt.title("Number of direct messages by weekday")

plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Calculate total number of messages for relative frequencies
total_messages = weekday_count["count"].sum()

# Set y-axis limit dynamically
max_height = weekday_count["count"].max()
plt.ylim(0, max_height * 1.15)

# Add absolute and relative frequencies above the bars
for bar in bars:
    count = int(bar.get_height())
    relative_frequency = count / total_messages

    plt.text(
        bar.get_x() + bar.get_width() / 2,
        count + max_height * 0.01,
        f"{count}\n({relative_frequency:.2%})",
        ha="center",
        va="bottom",
        fontsize=9
    )

plt.tight_layout()

# Save figure in high resolution
figure_path = figure_output_dir / "Dir_messages_by_weekday.png"
plt.savefig(figure_path, dpi=300)

plt.show()

print("Figure saved to:", figure_path)
# Out:
# Figure saved to: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/results/time/Abb/Dir_messages_by_weekday.png

# %%
from pathlib import Path
import pandas as pd

# ------------------------------------------------------------
# Create weekday distribution table for direct messages
# This table is prepared for later combination with group messages
# Current ConvoKit corpus object: D_corpus
# Uses the path variables defined in the notebook setup
# ------------------------------------------------------------

# 0. Define output directories based on existing setup variables

# Direct-message-specific intermediate results:
# Code_KorpusAnalyse/1_An_direktNachrichten/output/results/time
DIRECT_TIME_OUTPUT_DIR = OUTPUT_DIR / "results" / "time"

# Shared table for later combined analysis:
# Code_KorpusAnalyse/output/results/tables/time
COMBINED_TIME_OUTPUT_DIR = RESULT_TABLE_DIR / "time"

DIRECT_TIME_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
COMBINED_TIME_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


# 1. Extract timestamps from all utterances in the direct-message ConvoKit corpus
timestamps = []

for convo in D_corpus.iter_conversations():
    for utt in convo.iter_utterances():
        timestamps.append(utt.timestamp)


# 2. Create DataFrame with raw timestamps
direct_weekday_timestamp_df = pd.DataFrame(timestamps, columns=["timestamp"])


# 3. Convert Unix timestamps to datetime
direct_weekday_timestamp_df["datetime"] = pd.to_datetime(
    direct_weekday_timestamp_df["timestamp"],
    unit="s",
    errors="coerce"
)


# 4. Extract weekday
# Monday = 0, Sunday = 6
direct_weekday_timestamp_df["weekday"] = (
    direct_weekday_timestamp_df["datetime"].dt.dayofweek
)


# 5. Count messages by weekday
direct_weekday_count = (
    direct_weekday_timestamp_df
    .groupby("weekday")
    .size()
    .reset_index(name="count")
)


# 6. Ensure that all seven weekdays are represented
all_weekdays = pd.DataFrame({"weekday": range(7)})

direct_weekday_count = all_weekdays.merge(
    direct_weekday_count,
    on="weekday",
    how="left"
)

direct_weekday_count["count"] = (
    direct_weekday_count["count"]
    .fillna(0)
    .astype(int)
)


# 7. Calculate relative frequencies
total_direct_messages = direct_weekday_count["count"].sum()

direct_weekday_count["relative_frequency"] = (
    direct_weekday_count["count"] / total_direct_messages
) * 100


# 8. Add message type identifier
direct_weekday_count["message_type"] = "Direct messages"


# 9. Add weekday labels
weekday_labels = {
    0: "Monday",
    1: "Tuesday",
    2: "Wednesday",
    3: "Thursday",
    4: "Friday",
    5: "Saturday",
    6: "Sunday"
}

direct_weekday_count["weekday_name"] = (
    direct_weekday_count["weekday"].map(weekday_labels)
)


# 10. Create final clean analysis table in long format
direct_weekday_distribution = direct_weekday_count[
    [
        "message_type",
        "weekday",
        "weekday_name",
        "count",
        "relative_frequency"
    ]
].copy()


# 11. Save direct-message-specific intermediate results
direct_weekday_timestamp_df.to_csv(
    DIRECT_TIME_OUTPUT_DIR / "direct_messages_weekday_timestamps.csv",
    index=False,
    encoding="utf-8"
)

direct_weekday_count.to_csv(
    DIRECT_TIME_OUTPUT_DIR / "direct_messages_weekday_count_raw.csv",
    index=False,
    encoding="utf-8"
)

direct_weekday_distribution.to_csv(
    DIRECT_TIME_OUTPUT_DIR / "direct_messages_weekday_distribution.csv",
    index=False,
    encoding="utf-8"
)


# 12. Save first version of the later combined weekday table
# Group message data can later be appended to this file.
combined_weekday_distribution = direct_weekday_distribution.copy()

combined_weekday_distribution.to_csv(
    COMBINED_TIME_OUTPUT_DIR / "combined_messages_weekday_distribution.csv",
    index=False,
    encoding="utf-8"
)


# 13. Display and validate result
display(direct_weekday_distribution)

print("Direct message weekday distribution table created and saved.")

print("\nPath check:")
print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("PROJECT_DIR:", PROJECT_DIR)
print("Direct-message time output directory:", DIRECT_TIME_OUTPUT_DIR)
print("Combined time table output directory:", COMBINED_TIME_OUTPUT_DIR)

print("\nValidation:")
print("Rows:", len(direct_weekday_distribution))
print("Total direct messages:", direct_weekday_distribution["count"].sum())
print("Number of extracted timestamps:", len(direct_weekday_timestamp_df))
print("Number of missing raw timestamps:", direct_weekday_timestamp_df["timestamp"].isna().sum())
print("Number of missing datetime values:", direct_weekday_timestamp_df["datetime"].isna().sum())
print("Minimum raw timestamp:", direct_weekday_timestamp_df["timestamp"].min())
print("Maximum raw timestamp:", direct_weekday_timestamp_df["timestamp"].max())
print("Minimum datetime:", direct_weekday_timestamp_df["datetime"].min())
print("Maximum datetime:", direct_weekday_timestamp_df["datetime"].max())

print("\nAggregation check:")
print(
    len(direct_weekday_timestamp_df)
    == direct_weekday_distribution["count"].sum()
)
# Out:
#       message_type  weekday weekday_name  count  relative_frequency
# 0  Direct messages        0       Monday   1045           21.261445
# 1  Direct messages        1      Tuesday   1006           20.467955
# 2  Direct messages        2    Wednesday   1058           21.525941
# 3  Direct messages        3     Thursday    976           19.857579
# 4  Direct messages        4       Friday    783           15.930824
# 5  Direct messages        5     Saturday     33            0.671414
# 6  Direct messages        6       Sunday     14            0.284842
# Direct message weekday distribution table created and saved.
#
# Path check:
# NOTEBOOK_DIR: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis
# PROJECT_DIR: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse
# Direct-message time output directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/results/time
# Combined time table output directory: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/time
#
# Validation:
# Rows: 7
# Total direct messages: 4915
# Number of extracted timestamps: 4915
# Number of missing raw timestamps: 0
# Number of missing datetime values: 0
# Minimum raw timestamp: 1641187620
# Maximum raw timestamp: 1641753300
# Minimum datetime: 2022-01-03 05:27:00
# Maximum datetime: 2022-01-09 18:35:00
#
# Aggregation check:
# True

# %% [markdown]
# ---

# %% [markdown]
# # Export raw message texts
# from the direct-message ConvoKit corpus to an external directory outside the project folder as ` D_corpus_raw.txt `

# %%
from pathlib import Path

# Define external output directory
EXTERNAL_TEXT_OUTPUT_DIR = Path.home() / "Desktop" / "Korpus_Exports" / "text"
EXTERNAL_TEXT_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Define output file path
raw_text_file = EXTERNAL_TEXT_OUTPUT_DIR / "D_corpus_raw.txt"

# Print only the first 20 utterances for validation
print("First 20 utterances:\n")

for i, utt in enumerate(D_corpus.iter_utterances()):
    if i >= 20:
        break
    print(f"{i + 1}: {utt.text}")

# Write all utterance texts to a text file
with open(raw_text_file, "w", encoding="utf-8") as file:
    for utt in D_corpus.iter_utterances():
        file.write(utt.text + "\n")

# Validation
number_of_utterances = sum(1 for _ in D_corpus.iter_utterances())

print("\nRaw corpus text exported successfully.")
print("Number of exported utterances:", number_of_utterances)
print("Saved to:", raw_text_file)
# Out:
# First 20 utterances:
#
# 1: Willkommen, schön, dass es funktioniert hat!<enter>
# 2: prima, vielen Dank!
# 3: Liebe <Vorname>, wenn Arztbriefe fertig sind aus deiner Sicht (inkl Bezugstherapie etc) dann in den OA-Kontrolle Ordner verschieben. Weißt du wie das geht?
# 4: Hat Frau <Nachname> heute um 14 h den Termin bei Dir? Wollte sie gerne wissen.
# 5: ja, war grade da
# 6: liebe <Vorname>, hatte gerade mit Hr. <Nachname> gesprochen, u.a. auch über die Bewegung, da wir die Zusatznahrung erst weiter reduzieren können, wenn er sich weniger bewegt. Er sieht während des Laufens ständig auf sein Handy, damit lenke er sich ab. Ich hatte versucht, ein paar konkrete Maßnahmen zu besprechen, z.B. 5 Min. vor EG-Beginn hinsetzen, nicht erst 30 sec. vorher, in dieser Zeit nicht das Handy nutzen. Außerdem hatte ich vorgeschlagen, dass er für den Rückweg von der EB zur Station den Fahrstuhl nutzt, das wollt er machen.
# 7: Ja, ich finde auch, dass wir ihm da jetzt einen stärkeren Rahmen bieten müssen. Ich sehe ihn morgen im Einzel und werde das mit ihm besprechen. Danke :)
# 8: liebe <Vorname>, hab gesehen, dass Fr. <Nachname> am Di. um 9:10 einen Termin bei Dir hat, sie hat um 10:00 Uhr den <Stationsteam>termin und 09:45 Uhr ist Zwischenmahlzeit - ggf. wird das etwas knapp? Mit dem <Stationsteam>termin bin ich leider sehr unflexibel, da mir nur für dieses Zeitfenster der Raum zur Verfügung steht. lg <Vorname>
# 9: Liebe <Vorname>, ich habe die biografische Anamnese im Brief für <Name_Abkürzung> gekürzt, ich hoffe, das passt so besser. Wenn dir wieder so etwas auffällt, gerne Rückmeldung an mich, ich lerne ja noch und außerdem bin ich beim Schreiben vermutlich von meiner Arbeit in der Psychiatrie geprägt. Danke :)
# 10: Ich habe von der Psychosomatik <Klinik> den Brief für Herrn #<Nachname> erhalten, möchtest du den auch sehen? Ansonsten würde ich ihn nächste Woche <Vorname> geben.
# 11: Liebe <Vorname>, das ist ja super, vielen Dank! Könntest Du den Brief bitten <Vorname> <Nachname> geben? So können wir schon reinschauen. Danke!
# 12: Moin! Es hat sich jetzt kurzfristig ergeben, dass ich Frau <Nachname> noch weiter therapeutisch betreue.. Könntest du ihr morgen in der Visite vielleicht 2 Termine von mir geben?<enter>Dienstag 10Uhr und Donnerstag 09Uhr<enter>Vielen Dank!
# 13: Liebe @<Person2>,<enter>ich habe an dich gedacht, weil ich letztens einen <Station>brief von dir in der Hand hielt und sehr beeindruckt von der Umfänglichkeit war, und weil ich eigentlich heute für ein <Station>gespräch einspringen sollte und bei der Einarbeitung gemerkt habe, dass ich mir die Arbeit in der <Station> sehr intensiv und kondensiert vorstelle - so viele Informationen, die man sammeln muss und Dinge, die abgeklärt werden müssen, plus Rückmeldung und das alles in 50 Minuten! Und dann auch jedes Mal einen Brief schreiben. <enter>Wie geht es dir denn so in der PT-Stelle, gefällt es dir?<enter>Liebe Grüße aus <Ort>!
# 14: Liebe <Vorname>, es ist schön von dir zu hören. Es geht mir gut. An die Intensität habe ich mich schon gewöhnt :). Es ist ziemlich komplex, aber es macht Spaß und ich schaffe nicht immer alles in 50 min! So ist das einfach. Bist du doch nicht eingesprungen?
# 15: Viele Grüße
# 16: <Vorname>
# 17: Es freut mich sehr zu hören, dass es dir Spaß macht  - das ist ja das Wichtigste! Du wirst auf jeden Fall die Queen der Blitzdiagnosen sein, wenn du mit der PT-Zeit fertig bist. <enter>Die Patientin hatte den Termin dann wohl nicht bestätigt und ist nicht gekommen. <enter><enter>Kommst du morgen zum Sommerfest?
# 18: Ja, ich bin morgen da. Du auch?
# 19: Schön! Ja, ich komme auch :) Von den <Klinikstandort>-/<Klinikstandort>-<Vorname> kommen <Vorname>, <Vorname> (die kennst du glaube ich noch, oder?) und ich und wir treffen uns wahrscheinlich gegen 19 Uhr und gehen dann zusammen hin - falls du dich anschließen mags? Vielleicht gehst du aber auch eh mit den <Klinikstandort>-Kolleg*innen hin oder auch ganz alleine :)
# 20: ich lasse dir für den Fall mal meine Handynummer da: <Telefonnummer>
#
# Raw corpus text exported successfully.
# Number of exported utterances: 4915
# Saved to: /Users/sayegh-jodehl/Desktop/Korpus_Exports/text/D_corpus_raw.txt

# %% [markdown]
# ---

# %% [markdown]
# # Emojies

# %%
from collections import Counter
import pandas as pd
import emoji

# Define Unicode symbols that may be detected as emojis,
# but are not treated as communicative emojis in this analysis
excluded_unicode_symbols = {"®", "©", "™"}

# Function to extract communicative Unicode emojis from text
def extract_communicative_unicode_emojis(text):
    if pd.isna(text):
        return []
    
    emoji_items = emoji.emoji_list(str(text))
    
    return [
        item["emoji"]
        for item in emoji_items
        if item["emoji"] not in excluded_unicode_symbols
    ]


# Extract communicative Unicode emojis from all utterances
all_communicative_unicode_emojis = []
utterance_count = 0
utterances_with_communicative_unicode_emojis = 0

for utterance in D_corpus.iter_utterances():
    utterance_count += 1
    
    found_emojis = extract_communicative_unicode_emojis(utterance.text)
    
    if found_emojis:
        utterances_with_communicative_unicode_emojis += 1
        all_communicative_unicode_emojis.extend(found_emojis)

# Count frequencies
communicative_unicode_emoji_counts = Counter(all_communicative_unicode_emojis)

# Create frequency DataFrame
communicative_unicode_emoji_frequency_df = pd.DataFrame(
    communicative_unicode_emoji_counts.most_common(),
    columns=["unicode_emoji", "count"]
)

# Calculate total count safely
total_communicative_unicode_emoji_count = len(all_communicative_unicode_emojis)

# Add percentage column only if emojis were found
if total_communicative_unicode_emoji_count > 0:
    communicative_unicode_emoji_frequency_df["percentage"] = (
        communicative_unicode_emoji_frequency_df["count"]
        / total_communicative_unicode_emoji_count
        * 100
    ).round(2)

# Print summary
print(f"Total number of utterances: {utterance_count}")
print(
    f"Utterances containing communicative Unicode emojis: "
    f"{utterances_with_communicative_unicode_emojis}"
)
print(
    f"Total number of communicative Unicode emojis: "
    f"{total_communicative_unicode_emoji_count}"
)
print(
    f"Number of unique communicative Unicode emojis: "
    f"{len(communicative_unicode_emoji_counts)}"
)

if utterance_count > 0:
    percentage = (
        utterances_with_communicative_unicode_emojis
        / utterance_count
        * 100
    )
    print(
        f"Percentage of utterances containing communicative Unicode emojis: "
        f"{percentage:.2f} %"
    )

communicative_unicode_emoji_frequency_df.head(50)
# Out:
# Total number of utterances: 4915
# Utterances containing communicative Unicode emojis: 0
# Total number of communicative Unicode emojis: 0
# Number of unique communicative Unicode emojis: 0
# Percentage of utterances containing communicative Unicode emojis: 0.00 %
# Empty DataFrame
# Columns: [unicode_emoji, count]
# Index: []

# %%
from convokit import Corpus
import re
from collections import Counter
import pandas as pd

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Define a regular expression pattern for emoji shortcodes
# Example matches: :smile:, :thumbs_up:, :heart:, :+1:, :skin-tone-3:
emoji_shortcode_pattern = re.compile(r":[A-Za-z0-9_+\-]+:")

# Function to extract emoji shortcodes from text
def extract_emoji_shortcodes(text):
    if pd.isna(text):
        return []
    return emoji_shortcode_pattern.findall(str(text))


# Extract emoji shortcodes from all utterances
all_emoji_shortcodes = []
emoji_example_rows = []

total_utterance_count = 0
utterances_with_emoji_shortcodes = 0

for utterance in D_corpus.iter_utterances():
    total_utterance_count += 1
    
    found_shortcodes = extract_emoji_shortcodes(utterance.text)
    
    if found_shortcodes:
        utterances_with_emoji_shortcodes += 1
        all_emoji_shortcodes.extend(found_shortcodes)
        
        emoji_example_rows.append({
            "utterance_id": utterance.id,
            "text": utterance.text,
            "emoji_shortcodes": found_shortcodes,
            "emoji_shortcode_count": len(found_shortcodes)
        })

# Count emoji shortcode frequencies
emoji_shortcode_counts = Counter(all_emoji_shortcodes)

# Convert frequency counts to a DataFrame
emoji_shortcode_frequency_df = pd.DataFrame(
    emoji_shortcode_counts.most_common(),
    columns=["emoji_shortcode", "count"]
)

# Add percentage column safely
total_emoji_shortcode_count = emoji_shortcode_frequency_df["count"].sum()

if total_emoji_shortcode_count > 0:
    emoji_shortcode_frequency_df["percentage"] = (
        emoji_shortcode_frequency_df["count"] 
        / total_emoji_shortcode_count 
        * 100
    ).round(2)
else:
    emoji_shortcode_frequency_df["percentage"] = []

# Create a DataFrame with example utterances
emoji_shortcode_examples_df = pd.DataFrame(emoji_example_rows)

# Print summary
print(f"Total number of utterances: {total_utterance_count}")
print(f"Utterances containing emoji shortcodes: {utterances_with_emoji_shortcodes}")
print(f"Total number of emoji shortcodes: {total_emoji_shortcode_count}")
print(f"Number of unique emoji shortcodes: {len(emoji_shortcode_counts)}")

if total_utterance_count > 0:
    emoji_shortcode_utterance_percentage = (
        utterances_with_emoji_shortcodes / total_utterance_count * 100
    )
    print(
        f"Percentage of utterances containing emoji shortcodes: "
        f"{emoji_shortcode_utterance_percentage:.2f} %"
    )

# Display the 200 most frequent emoji shortcodes
emoji_shortcode_frequency_df.head(200)
# Out:
# Total number of utterances: 4915
# Utterances containing emoji shortcodes: 155
# Total number of emoji shortcodes: 162
# Number of unique emoji shortcodes: 63
# Percentage of utterances containing emoji shortcodes: 3.15 %
#             emoji_shortcode  count  percentage
# 0                      :+1:     23       14.20
# 1             :sweat_smile:     13        8.02
# 2                   :blush:     12        7.41
# 3                 :relaxed:      9        5.56
# 4   :slightly_smiling_face:      7        4.32
# ..                      ...    ...         ...
# 58                   :bulb:      1        0.62
# 59            :arrow_right:      1        0.62
# 60                  :tulip:      1        0.62
# 61          :kissing_heart:      1        0.62
# 62                  :10-17:      1        0.62
#
# [63 rows x 3 columns]

# %%
# Identify potentially suspicious shortcode matches
# These may be time ranges, codes, or export artefacts rather than emoji shortcodes

suspicious_shortcode_pattern = re.compile(r"^:[0-9\-]+:$")

suspicious_emoji_shortcodes_df = emoji_shortcode_frequency_df[
    emoji_shortcode_frequency_df["emoji_shortcode"].str.match(
        suspicious_shortcode_pattern
    )
].copy()

suspicious_emoji_shortcodes_df
# Out:
#    emoji_shortcode  count  percentage
# 56         :00-15:      1        0.62
# 62         :10-17:      1        0.62

# %%
from convokit import Corpus
import re
from collections import Counter
import pandas as pd

# Load the saved ConvoKit corpus from the central corpus output directory
D_corpus = Corpus(filename=CORPUS_OUTPUT_DIR / "D_corpus")

# Broad regular expression pattern for colon-enclosed shortcode-like strings
# Example matches: :+1:, :sweat_smile:, :blush:
emoji_shortcode_pattern = re.compile(r":[A-Za-z0-9_+\-]+:")

# Pattern for non-emoji artefacts such as :10-17:
non_emoji_time_pattern = re.compile(r"^:[0-9]+(?:-[0-9]+)+:$")

# Function to extract emoji shortcodes from text
def extract_emoji_shortcodes(text):
    if pd.isna(text):
        return []
    
    candidates = emoji_shortcode_pattern.findall(str(text))
    
    # Exclude time-like artefacts such as :10-17:
    cleaned_candidates = [
        shortcode
        for shortcode in candidates
        if not non_emoji_time_pattern.match(shortcode)
    ]
    
    return cleaned_candidates


# Extract emoji shortcodes from all utterances
all_emoji_shortcodes = []
emoji_example_rows = []

total_utterance_count = 0
utterances_with_emoji_shortcodes = 0

for utterance in D_corpus.iter_utterances():
    total_utterance_count += 1
    
    found_shortcodes = extract_emoji_shortcodes(utterance.text)
    
    if found_shortcodes:
        utterances_with_emoji_shortcodes += 1
        all_emoji_shortcodes.extend(found_shortcodes)
        
        emoji_example_rows.append({
            "utterance_id": utterance.id,
            "text": utterance.text,
            "emoji_shortcodes": found_shortcodes,
            "emoji_shortcode_count": len(found_shortcodes)
        })

# Count emoji shortcode frequencies
emoji_shortcode_counts = Counter(all_emoji_shortcodes)

# Convert frequency counts to a DataFrame
emoji_shortcode_frequency_df = pd.DataFrame(
    emoji_shortcode_counts.most_common(),
    columns=["emoji_shortcode", "count"]
)

# Calculate total count
total_emoji_shortcode_count = emoji_shortcode_frequency_df["count"].sum()

# Add percentage column
if total_emoji_shortcode_count > 0:
    emoji_shortcode_frequency_df["percentage"] = (
        emoji_shortcode_frequency_df["count"]
        / total_emoji_shortcode_count
        * 100
    ).round(2)

# Create a DataFrame with example utterances
emoji_shortcode_examples_df = pd.DataFrame(emoji_example_rows)

# Print summary
print(f"Total number of utterances: {total_utterance_count}")
print(f"Utterances containing emoji shortcodes: {utterances_with_emoji_shortcodes}")
print(f"Total number of emoji shortcodes: {total_emoji_shortcode_count}")
print(f"Number of unique emoji shortcodes: {len(emoji_shortcode_counts)}")

if total_utterance_count > 0:
    emoji_shortcode_utterance_percentage = (
        utterances_with_emoji_shortcodes / total_utterance_count * 100
    )
    print(
        f"Percentage of utterances containing emoji shortcodes: "
        f"{emoji_shortcode_utterance_percentage:.2f} %"
    )

# Display the 200 most frequent emoji shortcodes
emoji_shortcode_frequency_df.head(200)
# Out:
# Total number of utterances: 4915
# Utterances containing emoji shortcodes: 153
# Total number of emoji shortcodes: 160
# Number of unique emoji shortcodes: 61
# Percentage of utterances containing emoji shortcodes: 3.11 %
#             emoji_shortcode  count  percentage
# 0                      :+1:     23       14.37
# 1             :sweat_smile:     13        8.12
# 2                   :blush:     12        7.50
# 3                 :relaxed:      9        5.62
# 4   :slightly_smiling_face:      7        4.38
# ..                      ...    ...         ...
# 56                 :smiley:      1        0.62
# 57                   :bulb:      1        0.62
# 58            :arrow_right:      1        0.62
# 59                  :tulip:      1        0.62
# 60          :kissing_heart:      1        0.62
#
# [61 rows x 3 columns]

# %% [markdown]
# The emoji analysis distinguished between communicative Unicode emojis and colon-enclosed emoji shortcodes, with the latter serving as the primary basis for analysis because Unicode emojis were not meaningfully present in the corpus. Numeric artefacts resembling shortcodes, such as time ranges, were excluded during preprocessing.
#
# Because emoji use was relatively infrequent, emoji shortcodes were not interpreted individually in depth but were additionally grouped into broad communicative categories to support a descriptive interpretation of their pragmatic functions in the corpus.

# %%
from pathlib import Path
import pandas as pd

# Define output directory for DataFrame exports
dataframe_output_dir = Path.cwd() / "output" / "dataframes"

# Create the directory if it does not exist yet
dataframe_output_dir.mkdir(parents=True, exist_ok=True)

# Define Excel output path
emoji_excel_path = dataframe_output_dir / "emoji_shortcode_analysis.xlsx"

# Create a summary DataFrame
emoji_summary_df = pd.DataFrame({
    "metric": [
        "Total number of utterances",
        "Utterances containing emoji shortcodes",
        "Total number of emoji shortcodes",
        "Number of unique emoji shortcodes",
        "Percentage of utterances containing emoji shortcodes"
    ],
    "value": [
        total_utterance_count,
        utterances_with_emoji_shortcodes,
        total_emoji_shortcode_count,
        len(emoji_shortcode_counts),
        round(emoji_shortcode_utterance_percentage, 2)
    ]
})

# Save results to an Excel file with multiple sheets
with pd.ExcelWriter(emoji_excel_path, engine="openpyxl") as writer:
    emoji_summary_df.to_excel(
        writer,
        sheet_name="summary",
        index=False
    )
    
    emoji_shortcode_frequency_df.to_excel(
        writer,
        sheet_name="emoji_frequencies",
        index=False
    )
    
    emoji_shortcode_examples_df.to_excel(
        writer,
        sheet_name="emoji_examples",
        index=False
    )

print(f"Emoji analysis saved to: {emoji_excel_path}")
# Out:
# Emoji analysis saved to: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/01_direct_messages_analysis/output/dataframes/emoji_shortcode_analysis.xlsx

# %% [markdown]
# ## save results to excel table for comparison with result analyzed of group messages

# %%
from pathlib import Path
import pandas as pd

# Define the project directory one level above the current working directory
project_dir = Path.cwd().parent

# Define output directory for non-sensitive result tables
table_output_dir = project_dir / "output" / "results" / "tables"

# Create the directory if it does not exist yet
table_output_dir.mkdir(parents=True, exist_ok=True)

# Define Excel output path
emoji_comparison_excel_path = table_output_dir / "emoji_direct_group_comparison.xlsx"

# Create a non-sensitive comparison table
# Group message values can be added later
emoji_comparison_df = pd.DataFrame({
    "analysis_area": [
        "Unicode emojis",
        "Unicode emojis",
        "Unicode emojis",
        "Unicode emojis",
        "Emoji shortcodes",
        "Emoji shortcodes",
        "Emoji shortcodes",
        "Emoji shortcodes",
        "Emoji shortcodes"
    ],
    "metric": [
        "Total number of utterances",
        "Utterances containing communicative Unicode emojis",
        "Total number of communicative Unicode emojis",
        "Number of unique communicative Unicode emojis",
        "Total number of utterances",
        "Utterances containing emoji shortcodes",
        "Total number of emoji shortcodes",
        "Number of unique emoji shortcodes",
        "Percentage of utterances containing emoji shortcodes"
    ],
    "direct_messages": [
        4915,
        0,
        0,
        0,
        total_utterance_count,
        utterances_with_emoji_shortcodes,
        total_emoji_shortcode_count,
        len(emoji_shortcode_counts),
        round(emoji_shortcode_utterance_percentage, 2)
    ],
    "group_messages": [
        pd.NA,
        pd.NA,
        pd.NA,
        pd.NA,
        pd.NA,
        pd.NA,
        pd.NA,
        pd.NA,
        pd.NA
    ],
    "notes": [
        "Aggregated count only; no utterance text included.",
        "Aggregated count only; no utterance text included.",
        "Aggregated count only; no utterance text included.",
        "Aggregated count only; no utterance text included.",
        "Aggregated count only; no utterance text included.",
        "Aggregated count only; no utterance text included.",
        "Aggregated count only; no utterance text included.",
        "Aggregated count only; no utterance text included.",
        "Percentage based on utterances, not on total emoji counts."
    ]
})

# Save the comparison table as an Excel file with one sheet only
with pd.ExcelWriter(emoji_comparison_excel_path, engine="openpyxl") as writer:
    emoji_comparison_df.to_excel(
        writer,
        sheet_name="emoji_comparison",
        index=False
    )

print(f"Emoji comparison table saved to: {emoji_comparison_excel_path}")
# Out:
# Emoji comparison table saved to: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/emoji_direct_group_comparison.xlsx

# %%
from pathlib import Path
import pandas as pd

# Create a working copy of the emoji frequency table
emoji_category_df = emoji_shortcode_frequency_df.copy()

# Define broad communicative emoji categories
emoji_category_mapping = {
    # Approval / agreement
    ":+1:": "approval / agreement",
    ":ok_hand:": "approval / agreement",
    ":clap:": "approval / agreement",
    ":raised_hands:": "approval / agreement",
    ":white_check_mark:": "approval / agreement",
    ":heavy_check_mark:": "approval / agreement",

    # Positive affect / friendliness
    ":blush:": "positive affect / friendliness",
    ":relaxed:": "positive affect / friendliness",
    ":slightly_smiling_face:": "positive affect / friendliness",
    ":smiley:": "positive affect / friendliness",
    ":smile:": "positive affect / friendliness",
    ":grinning:": "positive affect / friendliness",
    ":grin:": "positive affect / friendliness",
    ":wink:": "positive affect / friendliness",

    # Humor / softening
    ":sweat_smile:": "humor / softening",
    ":joy:": "humor / softening",
    ":laughing:": "humor / softening",
    ":rofl:": "humor / softening",
    ":see_no_evil:": "humor / softening",

    # Affection / support
    ":heart:": "affection / support",
    ":heart_eyes:": "affection / support",
    ":kissing_heart:": "affection / support",
    ":pray:": "affection / support",
    ":hugs:": "affection / support",
    ":tulip:": "affection / support",

    # Information / direction
    ":bulb:": "information / direction",
    ":arrow_right:": "information / direction",
    ":point_right:": "information / direction",
    ":point_up:": "information / direction",
    ":eyes:": "information / direction",
    ":memo:": "information / direction",

    # Concern / uncertainty
    ":thinking_face:": "concern / uncertainty",
    ":confused:": "concern / uncertainty",
    ":worried:": "concern / uncertainty",
    ":grimacing:": "concern / uncertainty",
    ":disappointed:": "concern / uncertainty",
    ":cry:": "concern / uncertainty",

    # Objects / symbols / other
    ":coffee:": "objects / symbols / other",
    ":tada:": "objects / symbols / other",
    ":gift:": "objects / symbols / other",
    ":calendar:": "objects / symbols / other",
    ":warning:": "objects / symbols / other"
}

# Assign categories to emoji shortcodes
emoji_category_df["category"] = (
    emoji_category_df["emoji_shortcode"]
    .map(emoji_category_mapping)
    .fillna("uncategorized")
)

# Aggregate emoji counts by category
emoji_category_summary_df = (
    emoji_category_df
    .groupby("category", as_index=False)
    .agg(
        total_count=("count", "sum"),
        unique_emoji_shortcodes=("emoji_shortcode", "nunique")
    )
    .sort_values(by="total_count", ascending=False)
)

# Add percentage of all emoji shortcode occurrences
emoji_category_summary_df["percentage"] = (
    emoji_category_summary_df["total_count"]
    / emoji_category_summary_df["total_count"].sum()
    * 100
).round(2)

# Show category-level summary
emoji_category_summary_df
# Out:
#                          category  total_count  unique_emoji_shortcodes  \
# 7                   uncategorized           60                       38
# 6  positive affect / friendliness           43                        8
# 1            approval / agreement           24                        2
# 3               humor / softening           21                        3
# 2           concern / uncertainty            6                        4
# 0             affection / support            3                        3
# 4         information / direction            2                        2
# 5       objects / symbols / other            1                        1
#
#    percentage
# 7       37.50
# 6       26.88
# 1       15.00
# 3       13.12
# 2        3.75
# 0        1.88
# 4        1.25
# 5        0.62

# %%
# Inspect uncategorized emoji shortcodes
uncategorized_emoji_df = emoji_category_df[
    emoji_category_df["category"] == "uncategorized"
].copy()

uncategorized_emoji_df
# Out:
#                    emoji_shortcode  count  percentage       category
# 7         :face_with_rolling_eyes:      4        2.50  uncategorized
# 8                       :innocent:      4        2.50  uncategorized
# 9                :woman_shrugging:      3        1.88  uncategorized
# 11                     :roll_eyes:      3        1.88  uncategorized
# 12                      :unamused:      3        1.88  uncategorized
# 15                 :sun_with_face:      3        1.88  uncategorized
# 16                             :v:      2        1.25  uncategorized
# 17              :upside_down_face:      2        1.25  uncategorized
# 19     :face_with_hand_over_mouth:      2        1.25  uncategorized
# 20              :stuck_out_tongue:      2        1.25  uncategorized
# 22                      :no_mouth:      2        1.25  uncategorized
# 23                     :nerd_face:      2        1.25  uncategorized
# 24                        :muscle:      2        1.25  uncategorized
# 25               :woman-shrugging:      2        1.25  uncategorized
# 26                  :hugging_face:      1        0.62  uncategorized
# 27                     :champagne:      1        0.62  uncategorized
# 29                        :rocket:      1        0.62  uncategorized
# 30    :smiling_face_with_3_hearts:      1        0.62  uncategorized
# 31                        :hearts:      1        0.62  uncategorized
# 32                       :Patient:      1        0.62  uncategorized
# 33                :christmas_tree:      1        0.62  uncategorized
# 34                 :frowning_face:      1        0.62  uncategorized
# 35                :couch_and_lamp:      1        0.62  uncategorized
# 36                          :stew:      1        0.62  uncategorized
# 37                        :scream:      1        0.62  uncategorized
# 38                    :sunglasses:      1        0.62  uncategorized
# 39                         :innen:      1        0.62  uncategorized
# 40                  :call_me_hand:      1        0.62  uncategorized
# 42                          :cake:      1        0.62  uncategorized
# 44                      :sleeping:      1        0.62  uncategorized
# 45                     :zany_face:      1        0.62  uncategorized
# 46                :disguised_face:      1        0.62  uncategorized
# 47                          :mask:      1        0.62  uncategorized
# 48                      :sandwich:      1        0.62  uncategorized
# 49                   :green_salad:      1        0.62  uncategorized
# 50                     :hamburger:      1        0.62  uncategorized
# 51  :stuck_out_tongue_winking_eye:      1        0.62  uncategorized
# 53                      :thinking:      1        0.62  uncategorized

# %% [markdown]
# ## categorizing emoji shortcodes into broad communicative functions

# %%
# Exclude shortcode-like artefacts that are not emojis
non_emoji_shortcode_values = {
    ":Patient:",
    ":innen:"
}

# Extend emoji category mapping
emoji_category_mapping.update({
    # Skepticism / mild negativity
    ":face_with_rolling_eyes:": "skepticism / mild negativity",
    ":roll_eyes:": "skepticism / mild negativity",
    ":unamused:": "skepticism / mild negativity",
    ":upside_down_face:": "skepticism / mild negativity",
    ":no_mouth:": "skepticism / mild negativity",

    # Uncertainty / ambiguity
    ":woman_shrugging:": "concern / uncertainty",
    ":woman-shrugging:": "concern / uncertainty",
    ":thinking:": "concern / uncertainty",
    ":frowning_face:": "concern / uncertainty",
    ":scream:": "concern / uncertainty",

    # Positive affect / friendliness
    ":innocent:": "positive affect / friendliness",
    ":sun_with_face:": "positive affect / friendliness",
    ":hugging_face:": "positive affect / friendliness",
    ":smiling_face_with_3_hearts:": "positive affect / friendliness",
    ":sunglasses:": "positive affect / friendliness",
    ":call_me_hand:": "positive affect / friendliness",

    # Humor / softening
    ":face_with_hand_over_mouth:": "humor / softening",
    ":stuck_out_tongue:": "humor / softening",
    ":stuck_out_tongue_winking_eye:": "humor / softening",
    ":zany_face:": "humor / softening",
    ":disguised_face:": "humor / softening",
    ":nerd_face:": "humor / softening",

    # Approval / encouragement
    ":v:": "approval / agreement",
    ":muscle:": "approval / agreement",
    ":rocket:": "approval / agreement",

    # Affection / support
    ":hearts:": "affection / support",

    # Celebration / seasonal
    ":champagne:": "celebration / seasonal",
    ":christmas_tree:": "celebration / seasonal",
    ":cake:": "celebration / seasonal",

    # Objects / symbols / other
    ":couch_and_lamp:": "objects / symbols / other",
    ":stew:": "objects / symbols / other",
    ":mask:": "objects / symbols / other",
    ":sandwich:": "objects / symbols / other",
    ":green_salad:": "objects / symbols / other",
    ":hamburger:": "objects / symbols / other",
    ":sleeping:": "objects / symbols / other"
})

# %%
# Remove non-emoji artefacts from the frequency table
emoji_category_df = emoji_shortcode_frequency_df[
    ~emoji_shortcode_frequency_df["emoji_shortcode"].isin(non_emoji_shortcode_values)
].copy()

# Assign categories
emoji_category_df["category"] = (
    emoji_category_df["emoji_shortcode"]
    .map(emoji_category_mapping)
    .fillna("uncategorized")
)

# Aggregate emoji counts by category
emoji_category_summary_df = (
    emoji_category_df
    .groupby("category", as_index=False)
    .agg(
        total_count=("count", "sum"),
        unique_emoji_shortcodes=("emoji_shortcode", "nunique")
    )
    .sort_values(by="total_count", ascending=False)
)

# Add percentage of all categorized emoji shortcode occurrences
emoji_category_summary_df["percentage"] = (
    emoji_category_summary_df["total_count"]
    / emoji_category_summary_df["total_count"].sum()
    * 100
).round(2)

emoji_category_summary_df
# Out:
#                          category  total_count  unique_emoji_shortcodes  \
# 7  positive affect / friendliness           54                       14
# 4               humor / softening           30                        9
# 1            approval / agreement           29                        5
# 3           concern / uncertainty           14                        9
# 8    skepticism / mild negativity           14                        5
# 6       objects / symbols / other            8                        8
# 0             affection / support            4                        4
# 2          celebration / seasonal            3                        3
# 5         information / direction            2                        2
#
#    percentage
# 7       34.18
# 4       18.99
# 1       18.35
# 3        8.86
# 8        8.86
# 6        5.06
# 0        2.53
# 2        1.90
# 5        1.27

# %%
# Calculate the combined percentage of the three most frequent categories
top_3_percentage = emoji_category_summary_df.head(3)["percentage"].sum().round(2)

print(f"Combined percentage of the three most frequent categories: {top_3_percentage} %")
# Out:
# Combined percentage of the three most frequent categories: 71.52 %

# %% [markdown]
# After excluding shortcode-like artefacts, 158 emoji shortcodes were categorized into broad communicative functions. <br>
# The largest category was positive affect/friendliness (34.18%), <br>
# followed by humor/softening (18.99%) and approval/agreement (18.35%). <br>
# Together, these categories accounted for approximately 71.5% of all categorized emoji shortcode occurrences, <br> suggesting that **emoji use primarily served affiliative, supportive, or tone-softening functions**.
#
# Given the low overall frequency of emoji shortcodes, this categorization should be interpreted as an exploratory descriptive analysis rather than as a basis for statistical inference.

# %%
from pathlib import Path
import pandas as pd
import emoji

# Create a copy of the categorized emoji table
emoji_category_publication_df = emoji_category_df.copy()

# Calculate total number of categorized emoji shortcode occurrences
total_categorized_emoji_count = emoji_category_publication_df["count"].sum()

# Calculate percentage of each shortcode among all categorized shortcode occurrences
emoji_category_publication_df["percentage_of_all_categorized_emojis"] = (
    emoji_category_publication_df["count"]
    / total_categorized_emoji_count
    * 100
).round(2)

# Optional: convert shortcodes to Unicode display where possible
def shortcode_to_unicode(shortcode):
    manual_mapping = {
        ":+1:": "👍",
        ":relaxed:": "☺️",
        ":woman_shrugging:": "🤷‍♀️",
        ":woman-shrugging:": "🤷‍♀️",
        ":v:": "✌️",
        ":thinking:": "🤔",
        ":hearts:": "♥️"
    }
    
    if shortcode in manual_mapping:
        return manual_mapping[shortcode]
    
    rendered = emoji.emojize(shortcode, language="alias")
    
    # If emojize cannot convert the shortcode, keep the field empty
    if rendered == shortcode:
        return ""
    
    return rendered

emoji_category_publication_df["unicode_display"] = (
    emoji_category_publication_df["emoji_shortcode"]
    .apply(shortcode_to_unicode)
)

# Create a readable shortcode-with-count column
emoji_category_publication_df["shortcode_example"] = (
    emoji_category_publication_df["emoji_shortcode"]
    + " ("
    + emoji_category_publication_df["count"].astype(str)
    + ")"
)

# Create a readable Unicode-with-count column
emoji_category_publication_df["unicode_example"] = emoji_category_publication_df.apply(
    lambda row: (
        f"{row['unicode_display']} ({row['count']})"
        if row["unicode_display"] != ""
        else ""
    ),
    axis=1
)

# Select the top N emoji shortcodes per category
top_n_examples = 3

top_emoji_examples_per_category_df = (
    emoji_category_publication_df
    .sort_values(["category", "count"], ascending=[True, False])
    .groupby("category")
    .head(top_n_examples)
    .copy()
)

# Aggregate representative examples per category
representative_examples_df = (
    top_emoji_examples_per_category_df
    .groupby("category", as_index=False)
    .agg(
        representative_shortcodes=("shortcode_example", lambda x: "; ".join(x)),
        representative_unicode=("unicode_example", lambda x: "; ".join([i for i in x if i != ""]))
    )
)

# Merge representative examples with the category summary
emoji_category_publication_table_df = (
    emoji_category_summary_df
    .merge(representative_examples_df, on="category", how="left")
    .sort_values("total_count", ascending=False)
)

emoji_category_publication_table_df
# Out:
#                          category  total_count  unique_emoji_shortcodes  \
# 0  positive affect / friendliness           54                       14
# 1               humor / softening           30                        9
# 2            approval / agreement           29                        5
# 3           concern / uncertainty           14                        9
# 4    skepticism / mild negativity           14                        5
# 5       objects / symbols / other            8                        8
# 6             affection / support            4                        4
# 7          celebration / seasonal            3                        3
# 8         information / direction            2                        2
#
#    percentage                          representative_shortcodes  \
# 0       34.18  :blush: (12); :relaxed: (9); :slightly_smiling...
# 1       18.99   :sweat_smile: (13); :joy: (5); :see_no_evil: (3)
# 2       18.35                   :+1: (23); :v: (2); :muscle: (2)
# 3        8.86  :woman_shrugging: (3); :thinking_face: (3); :w...
# 4        8.86  :face_with_rolling_eyes: (4); :roll_eyes: (3);...
# 5        5.06     :couch_and_lamp: (1); :stew: (1); :coffee: (1)
# 6        2.53              :hearts: (1); :pray: (1); :tulip: (1)
# 7        1.90  :champagne: (1); :christmas_tree: (1); :cake: (1)
# 8        1.27                      :bulb: (1); :arrow_right: (1)
#
#       representative_unicode
# 0      😊 (12); ☺️ (9); 🙂 (7)
# 1       😅 (13); 😂 (5); 🙈 (3)
# 2      👍 (23); ✌️ (2); 💪 (2)
# 3  🤷‍♀️ (3); 🤔 (3); 🤷‍♀️ (2)
# 4        🙄 (4); 🙄 (3); 😒 (3)
# 5       🛋️ (1); 🍲 (1); ☕ (1)
# 6       ♥️ (1); 🙏 (1); 🌷 (1)
# 7        🍾 (1); 🎄 (1); 🍰 (1)
# 8              💡 (1); ➡️ (1)

# %%
from pathlib import Path
import pandas as pd
import emoji
from IPython.display import HTML, display

# ------------------------------------------------------------
# Create publication-ready emoji codebook and category table
# No utterance text is included.
# ------------------------------------------------------------

# Create a working copy
direct_emoji_codebook_df = emoji_category_df.copy()

# Recalculate percentages after excluding non-emoji artefacts
total_direct_categorized_emoji_count = direct_emoji_codebook_df["count"].sum()

direct_emoji_codebook_df["percentage_of_categorized_shortcodes"] = (
    direct_emoji_codebook_df["count"]
    / total_direct_categorized_emoji_count
    * 100
).round(2)


# ------------------------------------------------------------
# Convert emoji shortcodes to visual Unicode display
# ------------------------------------------------------------

def shortcode_to_unicode(shortcode):
    """
    Convert emoji shortcode to Unicode emoji where possible.
    Manual mappings are used for selected shortcodes that may not be
    handled consistently by the emoji package.
    """

    manual_mapping = {
        ":+1:": "👍",
        ":relaxed:": "☺️",
        ":slightly_smiling_face:": "🙂",
        ":sweat_smile:": "😅",
        ":blush:": "😊",
        ":woman_shrugging:": "🤷‍♀️",
        ":woman-shrugging:": "🤷‍♀️",
        ":face_with_rolling_eyes:": "🙄",
        ":roll_eyes:": "🙄",
        ":upside_down_face:": "🙃",
        ":face_with_hand_over_mouth:": "🤭",
        ":no_mouth:": "😶",
        ":nerd_face:": "🤓",
        ":v:": "✌️",
        ":muscle:": "💪",
        ":thinking:": "🤔",
        ":hearts:": "♥️",
        ":bulb:": "💡",
        ":arrow_right:": "➡️",
        ":tulip:": "🌷",
        ":kissing_heart:": "😘",
        ":rocket:": "🚀",
        ":champagne:": "🍾",
        ":christmas_tree:": "🎄",
        ":cake:": "🎂",
        ":mask:": "😷",
        ":sleeping:": "😴",
        ":sunglasses:": "😎",
        ":call_me_hand:": "🤙"
    }

    if shortcode in manual_mapping:
        return manual_mapping[shortcode]

    rendered = emoji.emojize(shortcode, language="alias")

    # If conversion fails, keep the cell empty rather than inventing a display
    if rendered == shortcode:
        return ""

    return rendered


direct_emoji_codebook_df["unicode_display"] = (
    direct_emoji_codebook_df["emoji_shortcode"]
    .apply(shortcode_to_unicode)
)

# Sort codebook for readability
direct_emoji_codebook_df = direct_emoji_codebook_df.sort_values(
    by=["category", "count"],
    ascending=[True, False]
).reset_index(drop=True)


# ------------------------------------------------------------
# Create representative examples per category
# ------------------------------------------------------------

top_n_examples = 3

direct_emoji_codebook_df["shortcode_with_count"] = (
    direct_emoji_codebook_df["emoji_shortcode"]
    + " ("
    + direct_emoji_codebook_df["count"].astype(str)
    + ")"
)

direct_emoji_codebook_df["unicode_with_count"] = direct_emoji_codebook_df.apply(
    lambda row: (
        f"{row['unicode_display']} ({row['count']})"
        if row["unicode_display"] != ""
        else ""
    ),
    axis=1
)

top_examples_df = (
    direct_emoji_codebook_df
    .sort_values(["category", "count"], ascending=[True, False])
    .groupby("category")
    .head(top_n_examples)
    .copy()
)

representative_examples_df = (
    top_examples_df
    .groupby("category", as_index=False)
    .agg(
        direct_representative_shortcodes=(
            "shortcode_with_count",
            lambda x: "; ".join(x)
        ),
        direct_visual_examples=(
            "unicode_with_count",
            lambda x: "; ".join([item for item in x if item != ""])
        )
    )
)


# ------------------------------------------------------------
# Create category-level summary for Direct Messages
# ------------------------------------------------------------

direct_category_summary_df = (
    direct_emoji_codebook_df
    .groupby("category", as_index=False)
    .agg(
        direct_total_count=("count", "sum"),
        direct_unique_emoji_shortcodes=("emoji_shortcode", "nunique")
    )
)

direct_category_summary_df["direct_percentage"] = (
    direct_category_summary_df["direct_total_count"]
    / direct_category_summary_df["direct_total_count"].sum()
    * 100
).round(2)

direct_category_summary_df = direct_category_summary_df.merge(
    representative_examples_df,
    on="category",
    how="left"
)

direct_category_summary_df = direct_category_summary_df.sort_values(
    by="direct_total_count",
    ascending=False
).reset_index(drop=True)


# ------------------------------------------------------------
# Add empty Group Message columns for later completion
# ------------------------------------------------------------

emoji_category_publication_table_df = direct_category_summary_df.copy()

emoji_category_publication_table_df["group_total_count"] = pd.NA
emoji_category_publication_table_df["group_unique_emoji_shortcodes"] = pd.NA
emoji_category_publication_table_df["group_percentage"] = pd.NA
emoji_category_publication_table_df["group_representative_shortcodes"] = pd.NA
emoji_category_publication_table_df["group_visual_examples"] = pd.NA

emoji_category_publication_table_df
# Out:
#                          category  direct_total_count  \
# 0  positive affect / friendliness                  54
# 1               humor / softening                  30
# 2            approval / agreement                  29
# 3           concern / uncertainty                  14
# 4    skepticism / mild negativity                  14
# 5       objects / symbols / other                   8
# 6             affection / support                   4
# 7          celebration / seasonal                   3
# 8         information / direction                   2
#
#    direct_unique_emoji_shortcodes  direct_percentage  \
# 0                              14              34.18
# 1                               9              18.99
# 2                               5              18.35
# 3                               9               8.86
# 4                               5               8.86
# 5                               8               5.06
# 6                               4               2.53
# 7                               3               1.90
# 8                               2               1.27
#
#                     direct_representative_shortcodes  \
# 0  :blush: (12); :relaxed: (9); :slightly_smiling...
# 1   :sweat_smile: (13); :joy: (5); :see_no_evil: (3)
# 2                   :+1: (23); :v: (2); :muscle: (2)
# 3  :woman_shrugging: (3); :thinking_face: (3); :w...
# 4  :face_with_rolling_eyes: (4); :roll_eyes: (3);...
# 5     :couch_and_lamp: (1); :stew: (1); :coffee: (1)
# 6              :hearts: (1); :pray: (1); :tulip: (1)
# 7  :champagne: (1); :christmas_tree: (1); :cake: (1)
# 8                      :bulb: (1); :arrow_right: (1)
#
#       direct_visual_examples group_total_count group_unique_emoji_shortcodes  \
# 0      😊 (12); ☺️ (9); 🙂 (7)              <NA>                          <NA>
# 1       😅 (13); 😂 (5); 🙈 (3)              <NA>                          <NA>
# 2      👍 (23); ✌️ (2); 💪 (2)              <NA>                          <NA>
# 3  🤷‍♀️ (3); 🤔 (3); 🤷‍♀️ (2)              <NA>                          <NA>
# 4        🙄 (4); 🙄 (3); 😒 (3)              <NA>                          <NA>
# 5       🛋️ (1); 🍲 (1); ☕ (1)              <NA>                          <NA>
# 6       ♥️ (1); 🙏 (1); 🌷 (1)              <NA>                          <NA>
# 7        🍾 (1); 🎄 (1); 🎂 (1)              <NA>                          <NA>
# 8              💡 (1); ➡️ (1)              <NA>                          <NA>
#
#   group_percentage group_representative_shortcodes group_visual_examples
# 0             <NA>                            <NA>                  <NA>
# 1             <NA>                            <NA>                  <NA>
# 2             <NA>                            <NA>                  <NA>
# 3             <NA>                            <NA>                  <NA>
# 4             <NA>                            <NA>                  <NA>
# 5             <NA>                            <NA>                  <NA>
# 6             <NA>                            <NA>                  <NA>
# 7             <NA>                            <NA>                  <NA>
# 8             <NA>                            <NA>                  <NA>

# %%
# ------------------------------------------------------------
# Display a compact visual table in the notebook
# ------------------------------------------------------------

emoji_visual_display_df = emoji_category_publication_table_df[
    [
        "category",
        "direct_total_count",
        "direct_percentage",
        "direct_visual_examples",
        "direct_representative_shortcodes"
    ]
].copy()

emoji_visual_display_df = emoji_visual_display_df.rename(columns={
    "category": "Category",
    "direct_total_count": "Direct messages: count",
    "direct_percentage": "Direct messages: percentage",
    "direct_visual_examples": "Visual examples",
    "direct_representative_shortcodes": "Shortcode examples"
})

display(HTML(f"""
<div style="
    color: black;
    background-color: white;
    padding: 20px;
    border-radius: 10px;
    border: 1px solid #ddd;
">
    <h3 style="color: black;">
        Emoji shortcode categories in direct messages
    </h3>
    <p style="color: black;">
        Representative examples show the most frequent emoji shortcodes per category.
    </p>
    {
        emoji_visual_display_df.to_html(
            index=False,
            escape=False
        )
    }
</div>
"""))
# Out:
# <div style="
#     color: black;
#     background-color: white;
#     padding: 20px;
#     border-radius: 10px;
#     border: 1px solid #ddd;
# ">
#     <h3 style="color: black;">
#         Emoji shortcode categories in direct messages
#     </h3>
#     <p style="color: black;">
#         Representative examples show the most frequent emoji shortcodes per category.
#     </p>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Category</th>
#       <th>Direct messages: count</th>
#       <th>Direct messages: percentage</th>
#       <th>Visual examples</th>
#       <th>Shortcode examples</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>positive affect / friendliness</td>
#       <td>54</td>
#       <td>34.18</td>
#       <td>😊 (12); ☺️ (9); 🙂 (7)</td>
#       <td>:blush: (12); :relaxed: (9); :slightly_smiling_face: (7)</td>
#     </tr>
#     <tr>
#       <td>humor / softening</td>
#       <td>30</td>
#       <td>18.99</td>
#       <td>😅 (13); 😂 (5); 🙈 (3)</td>
#       <td>:sweat_smile: (13); :joy: (5); :see_no_evil: (3)</td>
#     </tr>
#     <tr>
#       <td>approval / agreement</td>
#       <td>29</td>
#       <td>18.35</td>
#       <td>👍 (23); ✌️ (2); 💪 (2)</td>
#       <td>:+1: (23); :v: (2); :muscle: (2)</td>
#     </tr>
#     <tr>
#       <td>concern / uncertainty</td>
#       <td>14</td>
#       <td>8.86</td>
#       <td>🤷‍♀️ (3); 🤔 (3); 🤷‍♀️ (2)</td>
#       <td>:woman_shrugging: (3); :thinking_face: (3); :woman-shrugging: (2)</td>
#     </tr>
#     <tr>
#       <td>skepticism / mild negativity</td>
#       <td>14</td>
#       <td>8.86</td>
#       <td>🙄 (4); 🙄 (3); 😒 (3)</td>
#       <td>:face_with_rolling_eyes: (4); :roll_eyes: (3); :unamused: (3)</td>
#     </tr>
#     <tr>
#       <td>objects / symbols / other</td>
#       <td>8</td>
#       <td>5.06</td>
#       <td>🛋️ (1); 🍲 (1); ☕ (1)</td>
#       <td>:couch_and_lamp: (1); :stew: (1); :coffee: (1)</td>
#     </tr>
#     <tr>
#       <td>affection / support</td>
#       <td>4</td>
#       <td>2.53</td>
#       <td>♥️ (1); 🙏 (1); 🌷 (1)</td>
#       <td>:hearts: (1); :pray: (1); :tulip: (1)</td>
#     </tr>
#     <tr>
#       <td>celebration / seasonal</td>
#       <td>3</td>
#       <td>1.90</td>
#       <td>🍾 (1); 🎄 (1); 🎂 (1)</td>
#       <td>:champagne: (1); :christmas_tree: (1); :cake: (1)</td>
#     </tr>
#     <tr>
#       <td>information / direction</td>
#       <td>2</td>
#       <td>1.27</td>
#       <td>💡 (1); ➡️ (1)</td>
#       <td>:bulb: (1); :arrow_right: (1)</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# foodnote:
# Percentages refer to categorized emoji shortcode occurrences after exclusion of shortcode-like artefacts.

# %%
# ------------------------------------------------------------
# Save publication-ready non-sensitive tables
# ------------------------------------------------------------

project_dir = Path.cwd().parent

table_output_dir = project_dir / "output" / "results" / "tables"
table_output_dir.mkdir(parents=True, exist_ok=True)

emoji_publication_excel_path = (
    table_output_dir / "emoji_category_publication_table_with_codebook.xlsx"
)

with pd.ExcelWriter(emoji_publication_excel_path, engine="openpyxl") as writer:
    emoji_category_publication_table_df.to_excel(
        writer,
        sheet_name="category_comparison",
        index=False
    )

    direct_emoji_codebook_df.to_excel(
        writer,
        sheet_name="direct_emoji_codebook",
        index=False
    )

    emoji_visual_display_df.to_excel(
        writer,
        sheet_name="visual_summary",
        index=False
    )

print(f"Emoji publication table saved to: {emoji_publication_excel_path}")
# Out:
# Emoji publication table saved to: /Users/sayegh-jodehl/Documents/Publikationen/Korpusanalyse_JMIR/Code_KorpusAnalyse/output/results/tables/emoji_category_publication_table_with_codebook.xlsx

# %% [markdown]
# After excluding shortcode-like artefacts, 158 emoji shortcodes in the direct-message corpus were assigned to broad communicative categories. The largest category was positive affect / friendliness (n = 54; 34.18%), followed by humor / softening (n = 30; 18.99%) and approval / agreement (n = 29; 18.35%). Together, these three categories accounted for approximately 71.5% of all categorized emoji shortcode occurrences.
#
# Compared with group messages, direct messages showed a broader distribution across communicative categories, including higher proportions of concern / uncertainty and skepticism / mild negativity. This suggests that emoji shortcodes in direct messages were not only used for affiliation and tone-softening, but also to express uncertainty, hesitation, or mildly negative stance-taking in dyadic communication. Given the low overall frequency of emoji shortcodes, these findings should be interpreted as exploratory and descriptive.

# %% [markdown]
# ---

# %% [markdown]
# Export `D_utterances_raw.csv`

# %%
from pathlib import Path

PROJECT_DIR = Path.cwd().parent if Path.cwd().name.startswith("01_direct") else Path.cwd()

out_dir = PROJECT_DIR / "outputs" / "confidential" / "dataframes"
out_dir.mkdir(parents=True, exist_ok=True)

D_Conver_result_df.to_csv(out_dir / "D_utterances_raw.csv", index=False)

# %% [markdown]
# ## ________________________________________________________________________________________

# %% [markdown]
# # Cleaning corpusspezifisch

# %% [markdown]
# ## 1. entfernen von "< enter >" Marken

# %%
corpus_path = cwd

# Laden des Corpus aus der Datei
corpus = Corpus(filename=corpus_path)

replacements1 = {
    "<enter>": "",
    "< enter>": "",
    "< enter >": "",
    "<enter > ": "",
    "enter>": "",
    " <enter> ": ""}

# Schleife über die Utterances im Corpus und Anwenden der Ersetzungen
for utterance in corpus.iter_utterances():
    updated_text = utterance.text  # Kopie des ursprünglichen Texts
    # Kombinieren Sie alle Ersetzungen in einer Schleife
    for replacements in [replacements1]:
        for pattern, replacement in replacements.items():
            updated_text = updated_text.replace(pattern, replacement)
    utterance.text = updated_text


# Speichern des Corpus
corpus.dump(
    r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean_V")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 corpus_path = cwd
#       2
#       3 # Laden des Corpus aus der Datei
#       4 corpus = Corpus(filename=corpus_path)
#
# NameError: name 'cwd' is not defined

# %%
# Laden des ConvoKit Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean_V"
corpus = Corpus(filename=corpus_path)



replacements1 = {
    "#": "",
    ",": "",
    ":": "",
    ";": "",
    "*": "",
    "(": "",
    ")": "",
    ".": "",
    "-": ""
}

replacements2 = {

    "to do": " Platzhalter ",
    "to do's ": " Platzhalter ",
    "to dos": " Platzhalter ",
    "todos": " Platzhalter ",
    "To Dos": " Platzhalter ",
    "To Do": " Platzhalter ",
    "To do's": " Platzhalter ",
    "To do ' s": " Platzhalter ",
    "to do's": " Platzhalter ",
    "To-Do's": " Platzhalter ",
    "Todo's": " Platzhalter ",
    "To dos": " Platzhalter ",
    " to Dos ": " Platzhalter "
}

replacements3 = {
    "keine aktiven  Platzhalter 's": "kein_Todo",
    "kein  Platzhalter": "kein_Todo",
    "keine aktiven  Platzhalter": "kein_Todo",
    "kein aktives  Platzhalter": "kein_Todo",
    "keine  Platzhalter s": "kein_Todo",
    "aktiven ToDo'skann": "kein_Todo",
    "keine akuten  Platzhalter": "kein_Todo",
    "kein aktives  Platzhalter": "kein_Todo"
}

replacements4 = {
    " Platzhalter": " Todo ",
    " Platzhalter 's ": " Todo "
}

replacements5 = {
    "Frau ": " ",
    "Fr ": " ",
    " Fr ": " ",
    "Hr ": " ",
    "Herr": " ",
    "Herrn": " "
}

replacements6 = {
    "<Nachname>": " Ersatz ",
    "<Nachname> ": " Ersatz ",
    "<Name_Abkürzung>": " Ersatz ",
    "Patient": " Ersatz ",
    "Patient_in": " Ersatz ",
    "Pat.": " Ersatz ",
    "Pat. ": " Ersatz ",
    "Pat": " Ersatz ",
    "Patient_in": " Ersatz ",
    "Herr < Name_Abkürzung >": " Ersatz "
}

replacements7 = {
    " Ersatz ": " PatName ",
    " Gesprächsgruppe ": " GT ",
    " kt ": "KT",
    " mt ": "MT",
}

replacements8 = {
    " > ": " ",
    "> ": " ",
    " >": " ",
    ">": " ",
    "<": " ",
    " < ": " ",
    "< ": " ",
    " <": " ",
    "@": " "
}


# Schleife über die Utterances im Corpus und Anwenden der Ersetzungen

for utterance in corpus.iter_utterances():
    updated_text = utterance.text  # Kopie des ursprünglichen Texts

    # Kombinieren Sie alle Ersetzungen in einer Schleife
    for replacements in [replacements1, replacements2, replacements3, replacements4,
                         replacements5, replacements6, replacements7, replacements8]:
        for pattern, replacement in replacements.items():
            updated_text = updated_text.replace(pattern, replacement)

    utterance.text = updated_text


# Speichern des Corpus
corpus.dump(
    r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean")

# %%
# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Iterieren  über alle Utterance-Objekte im Corpus und Texte ausgeben
for utt in corpus.iter_utterances():
    print(utt.text)

# %%
from convokit import Corpus  

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Iterieren über alle Utterance-Objekte im Corpus und Texte mit Utterance ID ausgeben
for utt in corpus.iter_utterances():
    print(f"Utterance ID: {utt.id}")
    print(f"Text: {utt.text}\n")

# %% [markdown]
# ---

# %%
from pathlib import Path

PROJECT_DIR = Path.cwd().parent if Path.cwd().name.startswith("01_direct") else Path.cwd()

out_dir = PROJECT_DIR / "outputs" / "confidential" / "dataframes"
out_dir.mkdir(parents=True, exist_ok=True)

D_Conver_result_df.to_csv(out_dir / "D_utterances_raw.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# # Sentimentanalyse

# %% [markdown]
# ### Analyse mit Roberta Model für Twitter auf Deutsch optimiert "citizenlab/twitter-xlm-roberta-base-sentiment-finetunned"

# %%
device = 0 if torch.cuda.is_available() else -1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 device = 0 if torch.cuda.is_available() else -1
#
# NameError: name 'torch' is not defined

# %%
# %pip install sentencepiece

# %%
import torch

# Select the best available device
if torch.backends.mps.is_available():
    device = "mps"
    print("Using Apple Silicon GPU via MPS.")
elif torch.cuda.is_available():
    device = 0
    print("Using CUDA GPU.")
else:
    device = -1
    print("Using CPU.")

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import torch

# Recommended primary model for short multilingual/social-media-like texts
model_name = "cardiffnlp/twitter-xlm-roberta-base-sentiment"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Use Apple Silicon GPU via MPS if available
if torch.backends.mps.is_available():
    device = "mps"
    print("Using Apple Silicon GPU via MPS.")
else:
    device = -1
    print("Using CPU.")

sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device
)

# %%
from convokit import Corpus
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import pandas as pd
import matplotlib.pyplot as plt

# Laden des Transformers-Modells
tokenizer = AutoTokenizer.from_pretrained(
    "citizenlab/twitter-xlm-roberta-base-sentiment-finetunned")
model = AutoModelForSequenceClassification.from_pretrained(
    "citizenlab/twitter-xlm-roberta-base-sentiment-finetunned")


def extract_texts_from_corpus(corpus):
    """
    Extrahiert Texte aus einem Convokit Corpus.

    Args:
        corpus (Corpus): Der Convokit Corpus.

    Returns:
        list: Eine Liste mit den Texten aller Utterances im Corpus.
    """
    texts = []
    for utterance in corpus.iter_utterances():
        texts.append(utterance.text)
    return texts


def analyze_sentiment_with_roberta_and_export(texts, output_file="sentiment_analysis.csv"):
    """
    Analysiert Sentiments mit Roberta und exportiert Ergebnisse als CSV.

    Args:
        texts (list): Eine Liste von Texten.
        output_file (str): Der Dateiname für die CSV-Ausgabe.

    Returns:
        dict: Sentiment counts für positive, neutrale und negative Texte.
    """
    # Sentiment-Analyse initialisieren
    sentiment_pipeline = pipeline(
        "sentiment-analysis", model=model, tokenizer=tokenizer)

    # Kategorien und Zähler
    sentiment_counts = {"positive": 0, "neutral": 0, "negative": 0}
    results = []

    for text in texts:
        result = sentiment_pipeline(text[:512])  # Token-Limit beachten
        label = result[0]["label"].lower()
        score = result[0]["score"]

        # Sentiment-Ergebnisse speichern
        results.append({
            "Text": text,
            "Sentiment": label,
            "Score": score
        })

        # Sentiment-Zähler aktualisieren
        if label in sentiment_counts:
            sentiment_counts[label] += 1

    # Ergebnisse in CSV exportieren
    df = pd.DataFrame(results)
    # Kodierung hier angegeben
    df.to_csv(output_file, index=False, encoding="utf-8")
    print(f"Sentiment analysis results exported to {output_file}")

    return sentiment_counts


def visualize_sentiment(sentiment_counts):
    """
    Visualisiert die Sentiment-Verteilung mit einem Balkendiagramm.

    Args:
        sentiment_counts (dict): Sentiment counts für positive, neutrale und negative Texte.
    """
    categories = list(sentiment_counts.keys())
    counts = list(sentiment_counts.values())

    # Balkendiagramm erstellen
    plt.figure(figsize=(8, 5))
    plt.bar(categories, counts, color=["green", "grey", "red"])
    plt.title("Sentiment Distribution (Roberta)")
    plt.xlabel("Sentiment")
    plt.ylabel("Count")
    plt.grid(axis="y", linestyle="--", alpha=0.7)

    # Diagramm abspeichern

    plt.show()

# Statistik berechnen
    total_texts = len(texts)
    statistics = []
    for sentiment, count in sentiment_counts.items():
        relative_frequency = (count / total_texts) * \
            100 if total_texts > 0 else 0
        statistics.append({
            "Sentiment": sentiment,
            "Absolute Frequency": count,
            "Relative Frequency (%)": relative_frequency
        })

    stats_df = pd.DataFrame(statistics)
    print("\nSentiment Statistics:\n", stats_df)

    return sentiment_counts, stats_df


# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Texte aus dem Corpus extrahieren
texts = extract_texts_from_corpus(corpus)

# Sentimentanalyse durchführen und Ergebnisse exportieren
sentiment_counts = analyze_sentiment_with_roberta_and_export(
    texts, output_file="utterances_sentiment.csv"
)

# Ergebnisse visualisieren
visualize_sentiment(sentiment_counts)

# %% [markdown]
# ### Gemeinsame Darstellung der Gruppen und Direktnachrichten Sentiment

# %%
# !pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Daten für das Diagramm vorbereiten
data = {
    'Sentiment': ['Positiv', 'Neutral', 'Negativ', 'Positiv', 'Neutral', 'Negativ'],
    'Prozent': [13.536413, 83.498084, 2.965503, 8.672087, 89.663182, 1.664731],
    'Kommunikationsform': ['Direktnachrichten', 'Direktnachrichten', 'Direktnachrichten',
                           'Gruppennachrichten', 'Gruppennachrichten', 'Gruppennachrichten']
}

df = pd.DataFrame(data)

# Figure und Größe festlegen
plt.figure(figsize=(12, 6))

# Sentiment-spezifische Farben definieren
colors = {'Positiv': '#2ecc71',    # Grün
          'Neutral': '#95a5a6',    # Grau
          'Negativ': '#e74c3c'}    # Rot

# Zwei separate Balkendiagramme für die verschiedenen Kommunikationsformen erstellen
bar_width = 0.35
index = range(3)  # für die drei Sentiments

# Daten für beide Kommunikationsformen separieren
direkt = df[df['Kommunikationsform'] == 'Direktnachrichten']['Prozent'].values
gruppe = df[df['Kommunikationsform'] == 'Gruppennachrichten']['Prozent'].values

# Balken für Direktnachrichten
plt.bar([i - bar_width/2 for i in index], direkt, bar_width,
        label='Direktnachrichten',
        color=[colors['Positiv'], colors['Neutral'], colors['Negativ']],
        alpha=1)

# Balken für Gruppennachrichten
plt.bar([i + bar_width/2 for i in index], gruppe, bar_width,
        label='Gruppennachrichten',
        color=[colors['Positiv'], colors['Neutral'], colors['Negativ']],
        alpha=0.7)  # leicht transparent für Unterscheidung

# Prozentangaben über den Balken hinzufügen
for i in index:
    # Für Direktnachrichten
    plt.text(i - bar_width/2, direkt[i], f'{direkt[i]:.1f}%',
             ha='center', va='bottom')
    # Für Gruppennachrichten
    plt.text(i + bar_width/2, gruppe[i], f'{gruppe[i]:.1f}%',
             ha='center', va='bottom')

# Diagramm-Eigenschaften anpassen
plt.title('Vergleich der Sentiment-Verteilung in Direkt- und Gruppennachrichten',
          pad=20, fontsize=14)
plt.xlabel('Sentiment', fontsize=12)
plt.ylabel('Anteil in Prozent', fontsize=12)

# X-Achsen-Labels anpassen
plt.xticks(index, ['Positiv', 'Neutral', 'Negativ'])

# Y-Achse von 0 bis 100 skalieren
plt.ylim(0, 100)

# Legende anpassen
plt.legend(title='Kommunikationsform',
           bbox_to_anchor=(1.05, 1), loc='upper left')

# Layout optimieren
plt.tight_layout()

# Plot anzeigen
plt.show()

# Optional: Plot speichern
# plt.savefig('sentiment_comparison.png', dpi=300, bbox_inches='tight')
# plt.close()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Daten vorbereiten
# Äußerer Ring (Gruppennachrichten)
group_values = [8.672087, 89.663182, 1.664731]  # Positiv, Neutral, Negativ
# Innerer Ring (Direktnachrichten)
direct_values = [13.536413, 83.498084, 2.965503]  # Positiv, Neutral, Negativ

# Farben definieren
colors = ['#2ecc71', '#95a5a6', '#e74c3c']  # Grün, Grau, Rot

# Figur erstellen
plt.figure(figsize=(10, 10))

# Größerer (äußerer) Ring für Gruppennachrichten
plt.pie(group_values,
        radius=1.3,
        colors=colors,
        labels=['Positiv\n(8,7%)', 'Neutral\n(89,7%)', 'Negativ\n(1,7%)'],
        labeldistance=0.85,
        pctdistance=0.7,
        startangle=90,
        counterclock=False)

# Kleinerer (innerer) Ring für Direktnachrichten
plt.pie(direct_values,
        radius=1.0,
        colors=colors,
        labels=['Positiv\n(13,5%)', 'Neutral\n(83,5%)', 'Negativ\n(3,0%)'],
        labeldistance=0.6,
        pctdistance=0.45,
        startangle=90,
        counterclock=False)

# Titel und Legende
plt.title('SENTIMENT\nGruppennachrichten (außen) vs. Direktnachrichten (innen)',
          pad=20, fontsize=14)

# Mitte ausschneiden für Donut-Effekt
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Layout optimieren
plt.tight_layout()

# Plot anzeigen
plt.show()

# Optional: Plot speichern
# plt.savefig('sentiment_donut_comparison.png', dpi=300, bbox_inches='tight')
# plt.close()

# %% [markdown]
# #### Schreibe den Messagetext in eine csv Datei für Bertopic

# %% [markdown]
# Der Corpus wird nur um die Wichtigsten Dinge gereinigt und normalisiert, Satzzeichen bleiben erhalten

# %%
# Laden des ConvoKit Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean_V"
corpus = Corpus(filename=corpus_path)


replacements1 = {
    "#": "",
    "*": ""
}


replacements5 = {
    "Frau ": " ",
    "Fr ": " ",
    " Fr ": " ",
    "Hr ": " ",
    "Herr": " ",
    "Herrn": " "
}

replacements6 = {
    "<Nachname>": " Ersatz ",
    "<Nachname> ": " Ersatz ",
    "<Name_Abkürzung>": " Ersatz ",
    "Patient": " Ersatz ",
    "Patient_in": " Ersatz ",
    "Pat.": " Ersatz ",
    "Pat. ": " Ersatz ",
    "Pat": " Ersatz ",
    "Patient_in": " Ersatz ",
    "Herr < Name_Abkürzung >": " Ersatz "
}

replacements7 = {
    " Ersatz ": " PatName ",
    " Gesprächsgruppe ": " GT ",
    " kt ": "KT",
    " mt ": "MT",
}

replacements8 = {
    " > ": " ",
    "> ": " ",
    " >": " ",
    ">": " ",
    "<": " ",
    " < ": " ",
    "< ": " ",
    " <": " ",
    "@": " "
}


# Schleife über die Utterances im Corpus und Anwenden der Ersetzungen

for utterance in corpus.iter_utterances():
    updated_text = utterance.text  # Kopie des ursprünglichen Texts

    # Kombinieren Sie alle Ersetzungen in einer Schleife
    for replacements in [replacements1, replacements2, replacements3, replacements4,
                         replacements5, replacements6, replacements7, replacements8]:
        for pattern, replacement in replacements.items():
            updated_text = updated_text.replace(pattern, replacement)

    utterance.text = updated_text


# Speichern des Corpus
corpus.dump(
    r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean_V2")

# %%
import pandas as pd
import convokit 

# Pfad zur Datei des Corpus
corpus_path =  r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean_V2"
corpus = Corpus(filename=corpus_path)

# Extrahiere nur die Nachrichtentexte aus dem Corpus
message = [utt.text for utt in corpus.iter_utterances()]

# Erstelle einen DataFrame mit einer Spalte für den Nachrichtentext
df = pd.DataFrame(message, columns=['message_text'])

# Speichere die Nachrichtentexte in einer CSV-Datei
output_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\Corpus_clean_texts.csv"
df.to_csv(output_path, index=False)
print("Nachrichtentexte wurden erfolgreich in eine CSV-Datei **Corpus_clean_texts.csv** exportiert.")

# %% [markdown]
# Text in Datei des gereinigten Corpus *UG_corpus_cleaned.txt*

# %%
# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Ergebnis in eine Datei schreiben
# Öffnen der Datei im Schreibmodus
with open("UG_corpus_cleaned.txt", "w", encoding="utf-8") as file:
    # Iterieren über alle Utterance-Objekte im Corpus und schreiben der Text in die Datei
    for utt in corpus.iter_utterances():
        file.write(utt.text + "\n")

# %% [markdown]
# Wortliste erstellen und in Datei speichern

# %%
# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Wortliste erstellen und in Datei speichern
# Extrahieren der Wortliste aus dem Corpus
word_list = []
for utterance in corpus.iter_utterances():
    tokens = utterance.text.split()
    word_list.extend(tokens)

# Speichern der Wortliste in einer Datei
with open("word_list_voll.txt", "w", encoding="utf-8") as file:
    for word in word_list:
        file.write(word + "\n")

# %% [markdown]
# Am häufigsten verwendete Wörter vor Stopwortentfernung:

# %%
from collections import Counter

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Extrahieren und zählen der Wörter aus den Nachrichten
text_data = [utterance.text for utterance in corpus.iter_utterances()]
word_counts = Counter(" ".join(text_data).split())

# Die 100 am häufigsten verwendeten Wörter
most_common_words = word_counts.most_common(100)
print("Die 200 am häufigsten verwendeten Wörter:", most_common_words)

# Speichern der 100 am häufigsten verwendeten Wörter in einer Textdatei
with open("most_common_words.txt", "w", encoding="utf-8") as file:
    for word, count in most_common_words:
        file.write(f"{word}: {count}\n")

print("Die 100 am häufigsten verwendeten Wörter wurden in 'most_common_words.txt' gespeichert.")

# %% [markdown]
# Wortzahlen pro Utterance vor Stopwortentfernung

# %%
from convokit import Corpus

# Laden des ConvoKit Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Funktion zur Berechnung der Wortanzahl in einem Text


def count_words(text):
    # Trennen des Texts in Wörter (Worte sind durch Leerzeichen getrennt)
    words = text.split()
    # Rückgabe der Anzahl der Wörter im Text
    return len(words)


# Durchlaufen aller Utterances im Corpus und Berechnen der Wortanzahl
for utterance in corpus.iter_utterances():
    text = utterance.text
    word_count = count_words(text)
    print(f"Utterance ID: {utterance.id}, Wortanzahl: {word_count}")

# %% [markdown]
# Gesamtzahl der Wörter im Corpus vor Entfernung der Stopwörter

# %%
# Laden des ConvoKit Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Funktion zur Berechnung der Wortanzahl in einem Text


def count_words(text):
    words = text.split()
    return len(words)


# Initialisieren einer Variablen für die Gesamtzahl der Wörter
total_word_count = 0

# Durchlaufen aller Utterances im Corpus und Berechnen der Wortanzahl
for utterance in corpus.iter_utterances():
    total_word_count += count_words(utterance.text)

print(
    f"Gesamtzahl der Wörter im Corpus vor Entfernung der Stopwörter: {total_word_count}")

# %% [markdown]
# Durchschnittliche Anzahl von Wörtern pro Utterance vor Entfernung der Stopwörter

# %%
# Laden des ConvoKit Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Funktion zur Berechnung der Wortanzahl in einem Text


def count_words(text):
    # Trennen des Texts in Wörter (Worte sind durch Leerzeichen getrennt)
    words = text.split()
    # Rückgabe der Anzahl der Wörter im Text
    return len(words)


# Berechnung der durchschnittlichen Wortanzahl
word_count = [count_words(utterance.text)
              for utterance in corpus.iter_utterances()]
durchschnittliche_wortanzahl = sum(word_count) / len(word_count)

# Ausgabe der durchschnittlichen Wortanzahl
print("Direktnachrichten: Durchschnittliche Wortanzahl pro Äußerung vor Entfernung der Stopwörter: " +
      str(round(durchschnittliche_wortanzahl, 2)))

# %%
import numpy as np
from convokit import Corpus

# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Liste zur Speicherung der Wortzahlen pro Äußerung
word_counts = []

# Durchlaufen aller Äußerungen im Corpus und Zählen der Wortzahlen
for utterance in corpus.iter_utterances():
    words = utterance.text.split()  # Text in Wörter aufteilen
    word_count = len(words)
    word_counts.append(word_count)

# Erstellen von Intervallen (Bins) für die Gruppierung
bins = [0, 10, 20, 30, 40, 50, np.inf]

# Zählen der Wortzahlen in den Intervallen
word_count_groups = np.histogram(word_counts, bins=bins)

# Ausgabe der Anzahl der Wörter in den Intervallen
for i, count in enumerate(word_count_groups[0]):
    if i < len(bins) - 1:
        print(f"{bins[i]}-{bins[i+1]-1} Wörter: {count} Äußerungen")
    else:
        print(f"{bins[i]} und mehr Wörter: {count} Äußerungen")

# %%
import matplotlib.pyplot as plt
from convokit import Corpus

# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Listen zur Speicherung der Wortzahlen
word_counts = []

# Durchlaufen aller Äußerungen im Corpus
for utterance in corpus.iter_utterances():
    words = utterance.text.split()  # Text in Wörter aufteilen
    word_count = len(words)

    word_counts.append(word_count)
    # additional_feature_values.append(additional_feature)

# Erstellen des Scatterplots
plt.scatter(range(len(word_counts)), word_counts, marker='o', c='#6080c0')
plt.xlabel('Äußerungen')
plt.ylabel('Wortanzahl pro Äußerung vor Entfernung der Stopwörter')
plt.title('Scatterplot der Wortzahlen pro Äußerung')
plt.grid(True)

plt.show()

# %%
import numpy as np
# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Liste zur Speicherung der Wortzahlen pro Äußerung
word_counts = []

# Durchlaufen aller Äußerungen im Corpus
for utterance in corpus.iter_utterances():
    words = utterance.text.split()  # Text in Wörter aufteilen
    word_count = len(words)
    word_counts.append(word_count)

# Sortieren der Wortzahlen
sorted_word_counts = sorted(word_counts)

# Berechnung der CDF
cdf = np.arange(1, len(sorted_word_counts) + 1) / len(sorted_word_counts)

# Erstellen des CDF-Diagramms
plt.plot(sorted_word_counts, cdf, marker='.', linestyle='none', c='#6080c0')
plt.xlabel('Wortanzahl pro Äußerung vor Entfernung der Stopwörter')
plt.ylabel('Kumulative Wahrscheinlichkeit')
plt.title('Kumulative Verteilung der Wortzahlen pro Äußerung')
plt.grid(True)

plt.show()

# %% [markdown]
# Wordcloud erstellen des Corpus vor Bearbeitung

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Extrahieren und zählen der Wörter aus den Nachrichten
text_data = [utterance.text for utterance in corpus.iter_utterances()]
word_counts = Counter(" ".join(text_data).split())

# Erstellen der Word Cloud
wordcloud = WordCloud(width=800, height=400, margin=5, background_color='white',
                      scale=3).generate_from_frequencies(word_counts)

# Anzeigen der Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud der häufigsten Wörter vor Entfernung der Stopwörter")
plt.show()

# %% [markdown]
# _________________________________________________________________________________________________

# %% [markdown]
# ### Entfernen von Stoppwörtern
# stopwords von nltk verwenden, um deutsche Stoppwörter aus dem Texten zu entfernen

# %%
import nltk
from nltk.corpus import stopwords

# Laden Sie die deutschen Stoppwörter
nltk.download('stopwords')
stop_words = set(stopwords.words('german'))

# %%
stop_words = set(stopwords.words('german'))

# Speichern der Stoppwörter in einer Datei
with open("german_stopwords.txt", "w", encoding="utf-8") as file:
    for word in stop_words:
        file.write(word + "\n")

# %%
# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_clean"
corpus = Corpus(filename=corpus_path)

# Funktion um Stoppwörter zu entfernen


def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return " ".join(filtered_words)


# Schleife über die Utterances im Corpus und Anwenden der Stoppwortentfernung
for utt in corpus.iter_utterances():
    utt.text = remove_stopwords(utt.text)

# Pfad zur neuen Datei für den angepassten Corpus
new_corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"

# Speichern des angepassten Corpus in der neuen Datei
corpus.dump(new_corpus_path)

# %%
# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

for utterance in corpus.iter_utterances():
    print(utterance.text)

# %%
# Pfad zur Textdatei, in der die Utterance-Texte gespeichert werden
text_file_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_text.txt"

# Öffnen der Textdatei im Schreibmodus
with open(text_file_path, 'w', encoding='utf-8') as text_file:
    # Schleife über die Utterances und Schreiben der Texte in die Datei
    for utt in corpus.iter_utterances():
        text_file.write(utt.text + '\n')

# %%
# Laden des ConvoKit Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Funktion zur Berechnung der Wortanzahl in einem Text


def count_words(text):
    words = text.split()
    return len(words)


# Initialisieren einer Variablen für die Gesamtzahl der Wörter
total_word_count = 0

# Durchlaufen aller Utterances im Corpus und Berechnen der Wortanzahl
for utterance in corpus.iter_utterances():
    total_word_count += count_words(utterance.text)

print(f"Direktnachrichten: Gesamtzahl der Wörter im Corpus nach Entfernung von deutschen Stoppwörtern: {total_word_count}")

# %% [markdown]
# Durchschnittliche Anzahl von Wörtern / Utterance nach Stopwort Entfernung

# %%
# Laden des ConvoKit Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Funktion zur Berechnung der Wortanzahl in einem Text


def count_words(text):
    # Trennen des Texts in Wörter (Worte sind durch Leerzeichen getrennt)
    words = text.split()
    # Rückgabe der Anzahl der Wörter im Text
    return len(words)


# Berechnung der durchschnittlichen Wortanzahl
word_count = [count_words(utterance.text)
              for utterance in corpus.iter_utterances()]
durchschnittliche_wortanzahl = sum(word_count) / len(word_count)

# Ausgabe der durchschnittlichen Wortanzahl
print("Durchschnittliche Wortanzahl pro Äußerung ohne Stopwörter: " +
      str(round(durchschnittliche_wortanzahl, 2)))

# %% [markdown]
# Scatterplot

# %%
import matplotlib.pyplot as plt
from convokit import Corpus

# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Listen zur Speicherung der Wortzahlen und der Konversations-IDs
word_counts = []
conversation_ids = []

# Durchlaufen aller Äußerungen im Corpus
for utterance in corpus.iter_utterances():
    words = utterance.text.split()  # Text in Wörter aufteilen
    word_count = len(words)

    word_counts.append(word_count)
    conversation_ids.append(utterance.conversation_id)

# Festlegen der Farben für jede Konversation
unique_conversation_ids = list(set(conversation_ids))
colors = plt.cm.Blues_r([i / len(unique_conversation_ids)
                        for i in range(len(unique_conversation_ids))])
conversation_colors = dict(zip(unique_conversation_ids, colors))

# Sortieren der Konversationen nach der Reihenfolge der eindeutigen Konversations-IDs
sorted_unique_conversation_ids = sorted(unique_conversation_ids)

# Erstellen des Scatterplots mit festen Farben für Konversationen in der sortierten Reihenfolge
plt.figure(figsize=(10, 6))
for conversation_id in sorted_unique_conversation_ids:
    indices = [i for i, cid in enumerate(
        conversation_ids) if cid == conversation_id]
    plt.scatter(indices, [word_counts[i] for i in indices],
                marker='o', c=[conversation_colors[conversation_id]], label=f'Konversation {conversation_id}')

plt.xlabel('Äußerungen')
plt.ylabel('Wortanzahl pro Äußerung')
plt.title('Scatterplot der Wortzahlen pro Äußerung nach Konversationen (sortierte Reihenfolge)')
plt.grid(True)

# Legende neben dem Scatterplot platzieren
#plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
from collections import Counter

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Extrahieren und zählen der Wörter aus den Nachrichten
text_data = [utterance.text for utterance in corpus.iter_utterances()]
word_counts = Counter(" ".join(text_data).split())

# Die 100 am häufigsten verwendeten Wörter
most_common_words = word_counts.most_common(20)
print("Die 20 am häufigsten verwendeten Wörter:", most_common_words)

# Speichern der 20 am häufigsten verwendeten Wörter in einer Textdatei
with open("most_common_words_nostop.txt", "w", encoding="utf-8") as file:
    for word, count in most_common_words:
        file.write(f"{word}: {count}\n")

print("Die 20 am häufigsten verwendeten Wörter wurden in 'most_common_words.txt' gespeichert.")

# %%
from collections import Counter

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Extrahieren und zählen der Wörter aus den Nachrichten
text_data = [utterance.text for utterance in corpus.iter_utterances()]
word_counts = Counter(" ".join(text_data).split())

# Die 100 am häufigsten verwendeten Wörter nach der Größe der Anzahl absteigend sortiert
most_common_words = word_counts.most_common(20)

# Aufteilen der Wörter und ihrer Häufigkeiten in Gruppen zu je drei Elementen
num_columns = 3
grouped_words = [most_common_words[i:i + num_columns]
                 for i in range(0, len(most_common_words), num_columns)]

# Ausgabe in drei Spalten
for group in grouped_words:
    for word, count in group:
        print(f"{word}: {count}".ljust(25), end="")
    print()  # Zeilenumbruch zwischen den Gruppen

# Speichern der 20 am häufigsten verwendeten Wörter in einer Textdatei
with open("most_common_words_nostop.txt", "w", encoding="utf-8") as file:
    for group in grouped_words:
        for word, count in group:
            file.write(f"{word}: {count}\n")
        file.write("\n")

print("Die 20 am häufigsten verwendeten Wörter wurden in 'most_common_words.txt' gespeichert.")

# %% [markdown]
# Kummulative Verteilungen der Wortzahlen pro Äußerung

# %%
import numpy as np
# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Liste zur Speicherung der Wortzahlen pro Äußerung
word_counts = []

# Durchlaufen aller Äußerungen im Corpus
for utterance in corpus.iter_utterances():
    words = utterance.text.split()  # Text in Wörter aufteilen
    word_count = len(words)
    word_counts.append(word_count)

# Sortieren der Wortzahlen
sorted_word_counts = sorted(word_counts)

# Berechnung der CDF
cdf = np.arange(1, len(sorted_word_counts) + 1) / len(sorted_word_counts)

# Erstellen des CDF-Diagramms
plt.plot(sorted_word_counts, cdf, marker='.', linestyle='none', c='#6080c0')
plt.xlabel('Wortanzahl pro Äußerung')
plt.ylabel('Kumulative Wahrscheinlichkeit')
plt.title('Kumulative Verteilung der Wortzahlen pro Äußerung')
plt.grid(True)

plt.show()

# %%
from convokit import Corpus

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Zähle die Fragen
question_count = sum(1 for utt in corpus.iter_utterances() if "?" in utt.text)

# Zähle die Gesamtanzahl der Äußerungen
total_utterances = sum(1 for _ in corpus.iter_utterances())

# Berechne das Verhältnis
question_ratio = question_count / total_utterances

print(f"Anzahl der Fragen im Korpus: {question_count}")
print(f"Gesamtanzahl der Äußerungen: {total_utterances}")
print(f"Verhältnis Fragen zu Gesamtzahl der Äußerungen: {question_ratio:.2%}")

# %%
from convokit import Corpus

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Definiere eine Liste von typischen Fragewörtern
question_words = ["wer", "was", "wo", "wann",
                  "warum", "wie", "welche", "wessen", "wem", "wen"]

# Finde Äußerungen, die eines der Fragewörter enthalten
questions_with_words = [utt for utt in corpus.iter_utterances() if any(
    word in utt.text.lower() for word in question_words)]

# Gib die Anzahl der gefundenen Fragen und optional die Fragen selbst aus
print(f"Anzahl der Fragen, die Fragewörter enthalten: {len(questions_with_words)}")

# Optional: Zeige die ersten 10 gefundenen Fragen an
for i, question in enumerate(questions_with_words[:20]):
    print(f"Frage {i+1}: {question.text}")

# %% [markdown]
# ## Wordcloud nach Entfernung deutscher Stopwörter

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Extrahieren und zählen der Wörter aus den Nachrichten
text_data = [utterance.text for utterance in corpus.iter_utterances()]
word_counts = Counter(" ".join(text_data).split())

# Erstellen der Word Cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis',
                      scale=5).generate_from_frequencies(word_counts)

# Anzeigen der Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

plt.show()

# %% [markdown]
# #### _______________________________________________________

# %% [markdown]
# ## Tokenisieren der Nachrichten

# %%
import spacy
from convokit import Utterance

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D_Corpus_nostop"
corpus = Corpus(filename=corpus_path)

# Laden des deutschen spaCy-Modells
nlp = spacy.load("de_core_news_sm")

# Funktion zur Tokenisierung und Lemmatisierung


def tokenize_and_lemmatize(text):
    doc = nlp(text)
    tokens = [
        token.lemma_ for token in doc if not token.is_punct and not token.is_space]
    return " ".join(tokens)


# Iterieren über alle Utterance-Objekte im Corpus und aktualisieren des Texts
for utt in corpus.iter_utterances():
    utt.text = tokenize_and_lemmatize(utt.text)

# speichern des Corpus
corpus.dump(r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D__Corpus_tok")

# %%
import spacy
from convokit import Corpus

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D__Corpus_tok"
corpus = Corpus(filename=corpus_path)

# Laden des deutschen spaCy-Modells
nlp = spacy.load("de_core_news_sm")

# Funktion zur Tokenisierung und Lemmatisierung
def tokenize_and_lemmatize(text):
    doc = nlp(text)
    tokens = [
        token.lemma_ for token in doc if not token.is_punct and not token.is_space]
    return " ".join(tokens)


# Zählvariable für die Token
total_tokens = 0

# Iterieren über alle Utterance-Objekte im Corpus, aktualisieren des Texts und Zählen der Token
for utt in corpus.iter_utterances():
    utt.text = tokenize_and_lemmatize(utt.text)
    tokens = utt.text.split()
    total_tokens += len(tokens)

# Ausgabe der Anzahl der Token
print("Die Gesamtanzahl der Token nach Stopwort Entfernung im Corpus beträgt:", total_tokens)

# %%
# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D__Corpus_tok"
corpus = Corpus(filename=corpus_path)

# Iterieren  über alle Utterance-Objekte im Corpus und geben Sie die tokenisierten Texte aus
for utt in corpus.iter_utterances():
    print(utt.text)

# %% [markdown]
# #### Bestimmung der Hauptwörter im Corpus

# %%
import spacy

# Lade das deutsche Sprachmodell
nlp = spacy.load("de_core_news_sm")

# Liste zur Speicherung der Hauptwörter
nouns = []

# Beispiel für die Verarbeitung des Korpus
for utterance in corpus.iter_utterances():
    doc = nlp(utterance.text)
    # Filter nur auf Nomen
    for token in doc:
        if token.pos_ == "NOUN":
            nouns.append(token.text)

# Ausgabe der gefundenen Hauptwörter
print("Liste der Hauptwörter:", nouns)

# %%
import pandas as pd
from collections import Counter

# Zähle die Nomen und sortiere sie nach Häufigkeit
noun_counts = Counter(nouns)
sorted_noun_counts = sorted(
    noun_counts.items(), key=lambda x: x[1], reverse=True)

    
# Erstelle einen DataFrame mit den Nomen, ihrer Häufigkeit und dem Rang
df_D_nouns = pd.DataFrame(sorted_noun_counts, columns=["Noun", "Frequency"])
df_D_nouns["Rank"] = df_D_nouns["Frequency"].rank(
    method="dense", ascending=False).astype(int)

print(df_D_nouns)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Filtere die Nomen mit einer Häufigkeit von maximal 20
filtered_df = df_D_nouns[df_D_nouns["Frequency"] >= 20]

# Erstelle ein Wörterbuch aus den gefilterten Daten für die Wortwolke
word_freq = dict(zip(filtered_df["Noun"], filtered_df["Frequency"]))

# Generiere die Wortwolke mit rot-gelben Farbtönen
wordcloud = WordCloud(width=800, height=400, max_words=100,
                      background_color='white', colormap='inferno').generate_from_frequencies(word_freq)

# Zeige die Wortwolke an
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")  
plt.axis("off")


plt.show()

# %% [markdown]
# Nomen Verben Paare

# %%
import spacy
from collections import Counter
import pandas as pd

# Lade das deutsche Sprachmodell
nlp = spacy.load("de_core_news_sm")

# Liste zur Speicherung von Nomen-Verb-Paaren
noun_verb_pairs = []

# Analysiere jede Äußerung im Korpus
for utterance in corpus.iter_utterances():
    doc = nlp(utterance.text)
    for sentence in doc.sents:
        for token in sentence:
            # Suche Nomen und das zugehörige Verb (Head)
            if token.pos_ == "NOUN":
                head_verb = token.head
                if head_verb.pos_ == "VERB":
                    # Speichere das Nomen-Verb-Paar
                    noun_verb_pairs.append((token.text, head_verb.text))

# Zähle die Häufigkeit der Nomen-Verb-Paare
pair_counts = Counter(noun_verb_pairs)

# Erstelle einen DataFrame mit den Nomen-Verb-Paaren und ihrer Häufigkeit
df_pairs = pd.DataFrame(pair_counts.items(), columns=[
                        "Noun-Verb Pair", "Frequency"])
df_pairs[['Noun', 'Verb']] = pd.DataFrame(
    df_pairs['Noun-Verb Pair'].tolist(), index=df_pairs.index)
df_pairs.drop(columns=["Noun-Verb Pair"], inplace=True)
df_pairs = df_pairs[['Noun', 'Verb', "Frequency"]]

print(df_pairs)

# %% [markdown]
# Zählen, wieviel Fragen gestellt wurden

# %%
from convokit import Corpus

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D__Corpus_tok"
corpus = Corpus(filename=corpus_path)


# Zähle die Fragen
question_count = sum(1 for utt in corpus.iter_utterances() if "?" in utt.text)

print(f"Anzahl der Fragen im Korpus: {question_count}")

# %%
# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D__Corpus_tok"
corpus = Corpus(filename=corpus_path)


def tokenize_and_lemmatize_and_save(text, output_file):
    doc = nlp(text)
    tokens = [
        token.lemma_ for token in doc if not token.is_punct and not token.is_space]
    tokenized_and_lemmatized_text = " ".join(tokens)

    # Öffnen Sie die Ausgabedatei im Schreibmodus (wenn die Datei nicht existiert, wird sie erstellt)
    with open(output_file, "w", encoding="utf-8") as file:
        # Schreiben Sie den bearbeiteten Text in die Datei
        file.write(tokenized_and_lemmatized_text)

# %% [markdown]
# # Themenmodulation

# %% [markdown]
# Die Themenmodellierung ist ein Verfahren, um verborgene Themen oder Muster in Textdaten zu identifizieren. In Convokit können Themenmodellierung auf Chat-Daten durchführt werden. Ein beliebter Ansatz für die Themenmodellierung ist das **Latent Dirichlet Allocation (LDA)-Verfahren**.

# %% [markdown]
# ## 1. TF-IDF

# %% [markdown]
# ## 2. LDA

# %%
# %pip install --upgrade gensim

# %% [markdown]
# gensim für Latent Dirichlet allocation (LDA)

# %%
from convokit import Corpus
from gensim import corpora
from gensim.models import LdaModel, TfidfModel
from gensim.corpora import Dictionary

# Pfad zur Datei des Corpus
corpus_path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\D__Corpus_tok"
corpus = Corpus(filename=corpus_path)

# Sammeln des tokenisierten und lemmatisierten Textes aus dem Corpus
tokenized_and_lemmatized_texts = [
    utterance.text.split() for utterance in corpus.iter_utterances()]

# 1. Erstellen eines Wörterbuchs aus dem Corpus
dictionary = Dictionary(tokenized_and_lemmatized_texts)

# 2. Bag-of-Words-Korpus erstellen
bow_corpus = [dictionary.doc2bow(text)
              for text in tokenized_and_lemmatized_texts]

# 3. TF-IDF-Modell erstellen und auf den Bag-of-Words-Korpus anwenden
tfidf_model = TfidfModel(bow_corpus)
tfidf_corpus = [tfidf_model[doc] for doc in bow_corpus]

# 4. LDA-Modell auf Basis des TF-IDF-gewogenen Korpus erstellen
num_topics = 10  # Anzahl der gewünschten Themen
lda_model = LdaModel(tfidf_corpus, num_topics=num_topics,
                     id2word=dictionary, random_state=42)

# Ausgabe der wichtigsten Wörter pro Thema
for idx, topic in lda_model.print_topics(-1):
    print(f"Topic {idx + 1}: {topic}")

# %% [markdown]
# Berechnung der Perplexität und des Kohärenzscore als Gütekriterium

# %%
from gensim.models import CoherenceModel
from gensim.models.coherencemodel import CoherenceModel

# Berechnen der Perplexität

log_perplexity = lda_model.log_perplexity(bow_corpus)

perplexity = np.exp(-log_perplexity)

print("Perplexität: ", perplexity)


# Berechnen des Kohärenzscore

coherence_model_lda = CoherenceModel(

    model=lda_model, texts=tokenized_and_lemmatized_texts, dictionary=dictionary, coherence='c_v')

coherence_lda = coherence_model_lda.get_coherence()

print('Kohärenzscore: ', coherence_lda)

# %%
# Überprüfen, ob das Wort "Agoraphobie" im Wörterbuch ist, unabhängig von der Groß-/Kleinschreibung
word_variants = ['Agoraphobie', 'agoraphobie']
word_id = None

for word in word_variants:
    if word in dictionary.token2id:
        word_id = dictionary.token2id[word]
        break

if word_id is None:
    print("Das Wort 'Agoraphobie' ist nicht im Wörterbuch enthalten.")
else:
    # Extrahieren der Themenverteilung des Wortes
    word_topics = lda_model.get_term_topics(word_id)

    # Ausgeben der Thema-ID und der Wahrscheinlichkeit (Relevanz) für das Wort
    print("Thema-Zuordnungen und Relevanz für 'Agoraphobie':")
    for topic_id, prob in word_topics:
        print(f"Thema {topic_id}: Relevanz = {prob}")

# %% [markdown]
# Schreiben der modulierten Themen und zugeordneten Wörter in einen DF

# %%
import pandas as pd

# Erstellen einer leeren DataFrame
topic_terms_df = pd.DataFrame()

# Iterieren Sie durch die Themen
for topic_id, topic_words in lda_model.show_topics(formatted=False, num_words=15):
    # Erstellen Sie eine Liste der Wörter und ihrer Gewichtungen
    words = [word for word, weight in topic_words]
    weights = [weight for word, weight in topic_words]

    # Fügen Sie die Wörter und Gewichtungen in die DataFrame hinzu
    topic_terms_df[f"Topic {topic_id}"] = words
    topic_terms_df[f"Weight {topic_id}"] = weights

# Zeigen Sie die Topic-Terms-Matrix an
print(topic_terms_df)

# %% [markdown]
# Das PyLDAvis-Paket in Python ist eine leistungsstarke Bibliothek zur Visualisierung von LDA-Modellen. Es bietet eine interaktive Visualisierung, die es ermöglicht, Themen und deren Wörter in einer 2D-Projektion darzustellen. Dies ist besonders nützlich, um die Themen ähnlich wie in einem Scatterplot anzuzeigen.

# %%
# %pip install pyLDAvis

# %%
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis

# Erstellen der PyLDAvis-Daten aus Ihrem LDA-Modell
vis_data = gensimvis.prepare(lda_model, bow_corpus, dictionary)


# Visualisieren der Themen
pyLDAvis.display(vis_data)

# %%
# Speichern der Visualisierung in eine HTML-Datei
pyLDAvis.save_html(vis_data, 'lda_visualization.html')

# %%
# Überprüfen, ob das Wort "Agoraphobie" im Wörterbuch ist, unabhängig von der Groß-/Kleinschreibung
word_variants = ['Agoraphobie', 'agoraphobie']
word_id = None

for word in word_variants:
    if word in dictionary.token2id:
        word_id = dictionary.token2id[word]
        break

if word_id is None:
    print("Das Wort 'Agoraphobie' ist nicht im Wörterbuch enthalten.")
else:
    # Extrahieren der Themenverteilung des Wortes
    word_topics = lda_model.get_term_topics(word_id)

    # Ausgeben der Thema-ID und der Wahrscheinlichkeit (Relevanz) für das Wort
    print("Thema-Zuordnungen und Relevanz für 'Agoraphobie':")
    for topic_id, prob in word_topics:
        print(f"Thema {topic_id}: Relevanz = {prob}")

# %% [markdown]
# # Konkretisierung der Themenmodulation anhand von Schlüsselwörtern
#
# gefundenen Schlüsselwörter werden in den Äußerungen verwenden, um Themenmodellierung oder Themenanalyse durchzuführen. <br>
# Die identifizierten Schlüsselwörter werden als Anker oder Hinweiswörter verwendet werden, um die Themen und Inhalte in den Texten besser zu verstehen oder zu extrahieren.

# %% [markdown]
# Schlüsselwörter werden als metadaten in den corpus geschrieben

# %%
import spacy
from convokit import Corpus

# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\Documents\Chat_Lokal\Ueberg_lokal\UG_Corpus_tok"
corpus = Corpus(filename=corpus_path)

# Initialisierung von spaCy mit dem gewünschten Sprachmodell (z.B. Deutsch)
nlp = spacy.load("de_core_news_sm")

# Liste von Schlüsselwörtern, die du markieren möchtest
schluesselwoerter = ["MT", "KT", "WE", "GT"]

# Durchlaufen aller Äußerungen im Corpus
for utterance in corpus.iter_utterances():
    # Verarbeite den Text der Äußerung mit spaCy
    doc = nlp(utterance.text)

    # Extrahiert die Schlüsselwörter aus dem Text
    gefunden_schluesselwoerter = [
        token.text for token in doc if token.text in schluesselwoerter]

    # Fügt die gefundenen Schlüsselwörter in die Metadaten der Äußerung hinzu
    utterance.meta['gefundene_schluesselwoerter'] = gefunden_schluesselwoerter

# Speichert den aktualisierten Corpus mit den Schlüsselwörtern in den Metadaten
corpus.dump(
    r"C:\Users\sayeghjs\Documents\Chat_Lokal\Ueberg_lokal\UG_schluessel_corpus")

# %% [markdown]
# Validieren

# %%
# Durchlaufen aller Äußerungen im Corpus
for utterance in corpus.iter_utterances():
    # Verarbeite den Text der Äußerung mit spaCy
    doc = nlp(utterance.text)

    # Extrahiere die Schlüsselwörter aus dem Text
    gefunden_schluesselwoerter = [
        token.text for token in doc if token.text in schluesselwoerter]

    # Ausgabe der Äußerung und der gefundenen Schlüsselwörter
    if gefunden_schluesselwoerter:
        print(f"Äußerung ID: {utterance.id}")
        print(f"Text: {utterance.text}")
        print(f"Gefundene Schlüsselwörter: {gefunden_schluesselwoerter}\n")

# %% [markdown]
# Anzahl der Utterances je Schlüsselwort

# %%
# Initialisierung eines Zählers für die Schlüsselwörter
schluesselwort_zaehler = {
    schluesselwort: 0 for schluesselwort in schluesselwoerter}

# Durchlaufen aller Äußerungen im Corpus
for utterance in corpus.iter_utterances():
    # Verarbeite den Text der Äußerung mit spaCy
    doc = nlp(utterance.text)

    # Zähle die Anzahl der gefundenen Schlüsselwörter
    gefunden_schluesselwoerter = [
        token.text for token in doc if token.text in schluesselwoerter]
    for wort in gefunden_schluesselwoerter:
        schluesselwort_zaehler[wort] += 1

# Ausgabe der Anzahl der gefundenen Schlüsselwörter
for schluesselwort, anzahl in schluesselwort_zaehler.items():
    print(f"Schlüsselwort '{schluesselwort}' wurde {anzahl} Mal erkannt.")

# %% [markdown]
# Visualisierung

# %%
import matplotlib.pyplot as plt

# Initialisierung eines Zählers für die Schlüsselwörter
schluesselwort_zaehler = {
    schluesselwort: 0 for schluesselwort in schluesselwoerter}

# Durchlaufen aller Äußerungen im Corpus
for utterance in corpus.iter_utterances():
    # Verarbeite den Text der Äußerung mit spaCy
    doc = nlp(utterance.text)

    # Zähle die Anzahl der gefundenen Schlüsselwörter
    gefunden_schluesselwoerter = [
        token.text for token in doc if token.text in schluesselwoerter]
    for wort in gefunden_schluesselwoerter:
        schluesselwort_zaehler[wort] += 1

# Visualisierung der Ergebnisse als Balkendiagramm
schluesselwoerter = list(schluesselwort_zaehler.keys())
anzahl_erkennungen = list(schluesselwort_zaehler.values())

plt.barh(schluesselwoerter, anzahl_erkennungen, color='#6080c0')
plt.xlabel('Anzahl der Erkennungen')
plt.ylabel('Schlüsselwörter')
plt.title('Anzahl der erkannten Äusserungen pro Schlüsselwort')

# Hinzufügen der exakten Zahlen am Ende der Balken
for i, anzahl in enumerate(anzahl_erkennungen):
    plt.text(anzahl, i, str(anzahl), va='center', fontsize=10, color='black')

plt.gca().invert_yaxis()  # Um die Schlüsselwörter von oben nach unten anzuzeigen
plt.show()

# %% [markdown]
# 20 wichtigsten Wörter für Utterances mit jeweiligem Schlüsselwort

# %%
from collections import Counter

# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\Documents\Chat_Lokal\Ueberg_lokal\UG_schluessel_corpus"
corpus = Corpus(filename=corpus_path)

# Schlüsselwörter
schluesselwoerter = ["MT", "KT", "WE", "GT"]

# Für jedes Schlüsselwort
for schluesselwort in schluesselwoerter:
    # Filtern Sie die Äußerungen, die das Schlüsselwort enthalten
    relevant_utterances = [utterance for utterance in corpus.iter_utterances(
    ) if schluesselwort in utterance.meta.get('gefundene_schluesselwoerter', [])]

    # Extrahieren Sie die Wörter aus den Äußerungen
    words = [
        word for utterance in relevant_utterances for word in utterance.text.lower().split()]

    # Zählen Sie die häufigsten Wörter
    word_counts = Counter(words)

    # Die 20 häufigsten Wörter
    top_20_words = word_counts.most_common(30)

    print(f"Häufigste Wörter für Schlüsselwort '{schluesselwort}':")
    for word, count in top_20_words:
        print(f"{word}: {count}")
    print("\n")

# %%
pip install --upgrade wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\Documents\Chat_Lokal\Ueberg_lokal\UG_schluessel_corpus"
corpus = Corpus(filename=corpus_path)

# Schlüsselwörter
schluesselwoerter = ["MT", "KT", "WE", "GT"]

# Für jedes Schlüsselwort
for schluesselwort in schluesselwoerter:
    # Filtern Sie die Äußerungen, die das Schlüsselwort enthalten
    relevant_utterances = [utterance for utterance in corpus.iter_utterances(
    ) if schluesselwort in utterance.meta.get('gefundene_schluesselwoerter', [])]

    # Extrahieren Sie die Wörter aus den Äußerungen
    words = [
        word for utterance in relevant_utterances for word in utterance.text.lower().split()]

    # Zählen Sie die häufigsten Wörter
    word_counts = Counter(words)

    # Die 25 häufigsten Wörter
    top_20_words = word_counts.most_common(25)

    # Erstellen eines WordCloud-Objekts, nur wenn top_20_words nicht leer ist
    if top_20_words:
        wordcloud = WordCloud(
            width=800, height=400, background_color='white', colormap='viridis').generate_from_frequencies(dict(top_20_words))

        # Anzeigen der WordCloud
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(f'WordCloud für Schlüsselwort "{schluesselwort}"')
        plt.show()

# %% [markdown]
# ### Themenmodulation je Schlüsselwort

# %%
import gensim
from gensim import corpora
from convokit import Corpus

# Laden des Convokit-Corpus
corpus_path = r"C:\Users\sayeghjs\Documents\Chat_Lokal\Ueberg_lokal\UG_schluessel_corpus"
corpus = Corpus(filename=corpus_path)

# Schlüsselwörter
schluesselwoerter = ["MT", "KT", "WE", "GT"]

# Für jedes Schlüsselwort
for schluesselwort in schluesselwoerter:
    # Filtern Sie die Äußerungen, die das Schlüsselwort enthalten
    relevant_utterances = [utterance for utterance in corpus.iter_utterances(
    ) if schluesselwort in utterance.meta.get('gefundene_schluesselwoerter', [])]

    # Extrahieren Sie die Wörter aus den relevanten Äußerungen
    words = [
        word for utterance in relevant_utterances for word in utterance.text.lower().split()]

    # Vorbereiten der Textdaten für die LDA
    dictionary = corpora.Dictionary([words])
    corpus_lda_2 = [dictionary.doc2bow(words)]

    # Durchführen der LDA für das Schlüsselwort
    lda_model_2 = gensim.models.LdaModel(
        corpus_lda_2, num_topics=5, id2word=dictionary, passes=30)

    # Anzeigen der Themen für das Schlüsselwort
    print(f"Themen für Schlüsselwort '{schluesselwort}':")
    for idx, topic in lda_model_2.print_topics(-1):
        print(f'Thema #{idx}: {topic}\n')

# %% [markdown]
# ### Visualisierung

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Für jedes Schlüsselwort
for schluesselwort in schluesselwoerter:
    # ... (Ihr vorhandener Code zum Durchführen der LDA)

    # Erstellen Sie die pyLDAvis-Darstellung
    vis_data_2 = gensimvis.prepare(lda_model_2, corpus_lda_2, dictionary)

    # Speichern Sie die Darstellung als HTML-Datei (optional)
    pyLDAvis.save_html(vis_data_2, f"lda_vis_{schluesselwort}.html")

    # Anzeigen der Darstellung (öffnet in Ihrem Webbrowser)
    pyLDAvis.display(vis_data_2)

# %% [markdown]
# # BERTopic

# %%
# %pip uninstall pandas
# %pip install pandas

# %%
import pandas as pd
import numpy as np

# Set display option for pandas
pd.set_option('display.max_colwidth', None)

# Define the path to the CSV file
path = r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten"

# Read the CSV file into a DataFrame
train = pd.read_csv(path + r"\Corpus_clean_texts.csv",
                    sep=';', encoding='utf-8')

# %%
# !pip install bertopic sentence_transformers

# %% [markdown]
# ## Model trainieren

# %% [markdown]
# ### Entscheidungsfindung für top_n_words <br> geht davon aus, dass nur ein Thema pro utterance besprochen wurde <br>
# Kategorie 1-5 Utterances: <br>
# Durchschnittliche Wörter: 21.12, Durchschnittliche Sätze: 1.88, Durchschnittliche Wörter pro Satz: 10.17<br>
# Kategorie 6-10 Utterances: <br>
# Durchschnittliche Wörter: 20.30, Durchschnittliche Sätze: 1.85, Durchschnittliche Wörter pro Satz: 10.35<br>
# Kategorie 11-20 Utterances: <br>
# Durchschnittliche Wörter: 18.78, Durchschnittliche Sätze: 1.80, Durchschnittliche Wörter pro Satz: 9.79<br>
# Kategorie 21-50 Utterances: <br>
# Durchschnittliche Wörter: 20.23, Durchschnittliche Sätze: 1.86, Durchschnittliche Wörter pro Satz: 10.43<br>
# Kategorie 51-100 Utterances: <br>
# Durchschnittliche Wörter: 19.70, Durchschnittliche Sätze: 1.81, Durchschnittliche Wörter pro Satz: 10.71<br>
# Kategorie 100+ Utterances: <br>
# Durchschnittliche Wörter: 12.13, Durchschnittliche Sätze: 1.32, Durchschnittliche Wörter pro Satz: 8.33

# %%
import pandas as pd
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# Lade ein vortrainiertes deutsches BERT-Modell
german_model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# Konvertiere alle Elemente in der Spalte 'message_text' zu Zeichenketten
train['message_text'] = train['message_text'].astype(str)

# Extrahiere die Dokumente
docs = train['message_text']

# Initialisiere und trainiere das BERTopic-Modell
model = BERTopic(language="multilingual", 
                 embedding_model=german_model,
                 nr_topics="auto", 
                 top_n_words=9,
                 min_topic_size=25)
topics, probs = model.fit_transform(docs)

# %%
model.save(path + "/D_Chat_bertopic")

# %% [markdown]
# ## Erste Übersicht

# %% [markdown]
# ### Stats

# %%
model.get_topic_freq()

# %% [markdown]
# ## Topic Info

# %%
model.get_topic_info()[0:20]

# %%
# Analyse der Keywords eines bestimmten Topics
model.get_topic(3)

# %% [markdown]
# ### Keyword in einen Dataframe schreiben

# %%
import pandas as pd

# Initialisiere ein leeres Dictionary, um die Keywords für jedes Thema zu speichern
topic_keywords = {}

# Schleife über alle Themen und extrahiere die Keywords
for topic_num in range(len(model.get_topics())):
    keywords = model.get_topic(topic_num)
    if keywords:  # Überprüfe, ob das Thema nicht leer ist
        # Speichere nur die Keywords (ohne Relevance Score) für das aktuelle Thema
        topic_keywords[f"Topic_{topic_num}"] = [
            word for word, score in keywords]

# Erstelle einen DataFrame aus dem Dictionary und transponiere ihn, um die gewünschte Struktur zu erhalten
df_topics = pd.DataFrame.from_dict(topic_keywords, orient="index").transpose()

# DataFrame anzeigen
print(df_topics)

# %%
# Inspection der Documente in einem bestimmten Topic
model.get_document_info(docs)

# %% [markdown]
# ### repräsentative Documente finden

# %%
model.get_representative_docs(2)

# %% [markdown]
# #### repräsentative documente in Df schreiben

# %%
import pandas as pd

# Initialisiere ein leeres Dictionary, um die Dokumente für jedes Thema zu speichern
topic_docs = {}

# Schleife über eine festgelegte Anzahl von Themen und sammle die repräsentativen Dokumente
num_topics = 11  # Anzahl der Themen, die du analysieren möchtest
for topic_num in range(num_topics):
    docs = model.get_representative_docs(topic_num)
    # Speichere die Dokumente für das aktuelle Thema
    topic_docs[f"Topic_{topic_num}"] = docs

# Erstelle einen DataFrame aus dem Dictionary, transponiere es für die gewünschte Struktur
df_representative_docs = pd.DataFrame.from_dict(
    topic_docs, orient="index").transpose()

# DataFrame anzeigen
print(df_representative_docs)

# %% [markdown]
# ## Visualisierung

# %% [markdown]
# ### Intertopic Distance Map

# %%
fig = model.visualize_topics()
fig.write_html("D_topics_visualization.html")

# %% [markdown]
# ### Hierarchical Clustering

# %%
import plotly.graph_objects as go

custom_labels = {
    0: "Information über Patient:innen",
    1: "Dankbare Rückmeldung",
    2: "Information ohne Patient:innennennung",
    3: "Abstimmungen ohne Bezug zu Patient:innen",
    4: "Informationen bezogen auf das Wort Klinik",
    5: "Frage zum DocTalk-Projekt",
    6: "Informationen bezogen auf das Wort Station",
    7: "Arztbriefe",
    8: "LogIn DocTalk-Projekt",
    9: "Telefonnummer",
    10:"Abstimmung zu Gruppen"
}

fig = model.visualize_hierarchy(custom_labels=custom_labels)

fig = model.visualize_hierarchy(
    top_n_topics=11,          # Anzahl der anzuzeigenden Topics
    width=1000,               # Breite der Visualisierung
    height=600,               # Höhe der Visualisierung
    orientation="left",       # Orientierung: "left", "right", "top", oder "bottom"
    custom_labels= True,       # Eigene Labels für die Topics
    title="Topic Hierarchy",  # Titel der Visualisierung
    color_threshold=1         # Schwellenwert für Farbänderungen im Dendrogramm
)

fig.write_html("D_hierarchy_visualization.html")

# %%
# Definieren der gewünschten Labels
topic_labels = [
    "Information über Patient:innen",
    "Dankbare Rückmeldung",
    "Information ohne Patient:innennennung",
    "Abstimmungen ohne Bezug zu Patient:innen",
    "Informationen bezogen auf das Wort Klinik",
    "Frage zum DocTalk-Projekt",
    "Informationen bezogen auf das Wort Station",
    "Arztbriefe",
    "LogIn DocTalk-Projekt",
    "Telefonnummer",
    "Abstimmung zu Gruppen"]

# Basis-Visualisierung erstellen
fig = model.visualize_hierarchy(
    top_n_topics=11,
    width=700,
    height=900,
    orientation="left",
    title="Thematische Cluster-Analyse DocTalk-Direktnachrichten",
    color_threshold=0.8
)

# Debugging: Struktur der Figur untersuchen
print("Figure structure:")
print(fig)

# Alternative Methode zur Label-Anpassung
if hasattr(fig, 'layout') and hasattr(fig.layout, 'yaxis'):
    if hasattr(fig.layout.yaxis, 'ticktext'):
        # Aktuelle ticktext ausgeben
        print("Current ticktext:", fig.layout.yaxis.ticktext)
        # Neue Labels setzen
        fig.layout.yaxis.ticktext = topic_labels

# Layout-Anpassungen
fig.update_layout(
    font=dict(
        family="Arial",
        size=14,
    ),
    title=dict(
        text="Thematische Cluster-Analyse DocTalk-Direktnachrichten",
        font=dict(size=18),
        x=0.5,
        y=0.95
    ),
    margin=dict(
        l=300,
        r=50,
        t=100,
        b=50,
        autoexpand=True
    ),
    plot_bgcolor='white',
    paper_bgcolor='white',
    hoverlabel=dict(
        bgcolor="white",
        font_size=14,
        font_family="Arial"
    )
)

# Linien und Marker anpassen
fig.update_traces(
    marker=dict(
        size=8,
        line=dict(width=2)
    ),
    line=dict(width=2),
    textfont=dict(size=12)
)

# Speichern
fig.write_html("hierarchy_visualization_custom.html")

# Debug-Ausgabe der finalen Figur-Struktur
print("\nFinal figure structure:")
print(fig)

# %%
# Debugging: Aktuelle Textinhalte ausgeben
for i, trace in enumerate(fig.data):
    if hasattr(trace, 'text'):
        print(f"Trace {i} text: {trace.text}")

# %% [markdown]
# ### Visualisierung der Top Word of topics

# %%
import plotly.graph_objects as go

# Visualisierung als HTML speichern
fig = model.visualize_barchart(top_n_topics=10)
fig.write_html("barchart_visualization.html")
fig = model.visualize_barchart(
    top_n_topics=11,
    n_words=10,
    width=400,
    height=400
)

fig.write_html("D_barchart_visualization.html")

# %% [markdown]
# ### Heatmap

# %%
# Methode 1: Labels direkt über Plotly anpassen
# Custom Labels definieren

topic_labels = [
    "Information über Patient:innen",
    "Dankbare Rückmeldung",
    "Information ohne Patient:innennennung",
    "Abstimmungen ohne Bezug zu Patient:innen",
    "Informationen bezogen auf das Wort Klinik",
    "Frage zum DocTalk-Projekt",
    "Informationen bezogen auf das Wort Station",
    "Arztbriefe",
    "LogIn DocTalk-Projekt",
    "Telefonnummer",
    "Abstimmung zu Gruppen"
]

# Basis-Heatmap erstellen
fig = model.visualize_heatmap(
    width=800,
    height=800
)

# Verschiedene Optionen für Farbschemata:
fig.update_traces(
    # colorscale="RdBu",     # Rot zu Blau
    # ODER
    colorscale="YlOrRd",   # Gelb über Orange zu Rot
    # colorscale="Blues",    # Verschiedene Blautöne
    # colorscale="Purples",  # Verschiedene Lilatöne
    # colorscale="BuPu",     # Blau zu Lila
    # colorscale="RdYlBu",   # Rot-Gelb-Blau
    # colorscale="Spectral", # Regenbogenfarben
    # colorscale="YlGnBu",   # Gelb-Grün-Blau
    showscale=True
)

# Labels direkt in der Figur anpassen
fig.update_layout(
    xaxis=dict(
        # Anpassen auf die tatsächliche Anzahl der Topics
        ticktext=topic_labels[:11],
        tickvals=list(range(11))
    ),
    yaxis=dict(
        # Anpassen auf die tatsächliche Anzahl der Topics
        ticktext=topic_labels[:11],
        tickvals=list(range(11))
    ),
    title=dict(
        text="Direktnachrichten: Thematische Ähnlichkeiten zwischen den Nachrichtenthemen",
        font=dict(size=18, family="Arial"),
        x=0.5,
        y=0.95
    ),
    margin=dict(
        l=200,  # Mehr Platz für Labels
        r=50,
        t=70,
        b=200
    )
)

# Achsenbeschriftungen rotieren für bessere Lesbarkeit
fig.update_xaxes(tickangle=45)

# Als HTML speichern
fig.write_html("heatmap_visualization.html")

# %% [markdown]
# # Differenzierung der Themen mit Patientenbezug

# %% [markdown]
# Einlesen der beiden bereinigten Text Datein für direktnachrichten und Gruppennnachrichten zum Clustern und analysieren der Patientenbezogenen Themen

# %%
import pandas as pd

# Hilfsfunktion zum Extrahieren der Sätze


def extract_sentences_with_keyword(df, column, keyword):
    contexts = []
    for text in df[column].fillna(''):  # Füllt NaN-Werte mit leeren Strings
        if isinstance(text, str):  # Sicherstellen, dass der Text ein String ist
            sentences = [sentence.strip()
                         for sentence in text.split('.') if keyword in sentence]
            contexts.extend(sentences)
    return contexts


# Laden der CSV-Dateien
df1 = pd.read_csv(r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_direktNachrichten\Corpus_clean_texts.csv", sep=';', encoding='utf-8')
#df2 = pd.read_csv(r"C:\Users\sayeghjs\OneDrive - Charité - Universitätsmedizin Berlin\1 DocTalk\ChatCorpus\Codieraufgaben\Analyse_gruppNachrichten\G_Corpus_clean_texts.csv", sep=';', encoding='utf-8')

# Extraktion der Sätze für jedes DataFrame
keyword = "PatName"
contexts1 = extract_sentences_with_keyword(df1, 'message_text', keyword)
#contexts2 = extract_sentences_with_keyword(df2, 'message_text', keyword)

# Kombinieren der Kontexte, wenn nötig
#combined_contexts = contexts1 + contexts2

# Ausgabe der Ergebnisse
#for context in combined_contexts:
    #print(context)
    
    
print(contexts1)

# %%
# Überprüfen, ob 'combined_contexts' eine flache Liste von Strings ist
if not isinstance(combined_contexts, list) or not all(isinstance(item, str) for item in combined_contexts):
    raise ValueError(
        "combined_contexts muss eine flache Liste von Strings sein")

# Überprüfen auf leere Strings oder ungültige Inhalte
combined_contexts = [text for text in combined_contexts if text]

# Anzeigen der Anzahl der gültigen Dokumente
print(f"Anzahl der verarbeiteten Dokumente: {len(combined_contexts)}")

# %%
# Überprüfen, ob 'contexts1' eine flache Liste von Strings ist
if not isinstance(contexts1, list) or not all(isinstance(item, str) for item in contexts1):
    raise ValueError(
        "contexts1 muss eine flache Liste von Strings sein")

# Überprüfen auf leere Strings oder ungültige Inhalte
contexts1 = [text for text in contexts1 if text]

# Anzeigen der Anzahl der gültigen Dokumente
print(f"Anzahl der verarbeiteten Dokumente: {len(contexts1)}")

# %% [markdown]
# ## TopicModelling mit BERtopic zur Differenzierung der Themen um PatName

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer


# Laden des spezifischen Modells für die Einbettungen
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# Initialisierung von BERTopic mit dem gewählten Modell
topic_model = BERTopic(embedding_model=model,
                       language="multilingual",  # Angabe der Sprache zur Optimierung der Stopwort-Entfernung
                       # Optionale Berechnung der Zuordnungswahrscheinlichkeiten
                       calculate_probabilities=True,
                       min_topic_size=15)  # Mindestgröße eines Themas

# Trainieren des Modells mit Ihren Daten

topics, probabilities = topic_model.fit_transform(contexts1)

# Anzeigen der Themen
for topic_num in set(topics):
    print("Topic Nummer:", topic_num)
    print(topic_model.get_topic(topic_num))

# Optional: Visualisierung der Themen
topic_model.visualize_topics()

# %% [markdown]
# ## Stats

# %%
topic_model.get_topic_freq()

# %% [markdown]
# ## Keywords in einen Dataframe schreiben

# %%
import pandas as pd

# Initialisiere ein leeres Dictionary, um die Keywords für jedes Thema zu speichern
topic_keywords = {}

# Schleife über alle Themen und extrahiere die Keywords
for topic_num in range(len(topic_model.get_topics())):
    keywords = topic_model.get_topic(topic_num)
    if keywords:  # Überprüfe, ob das Thema nicht leer ist
        # Speichere nur die Keywords (ohne Relevance Score) für das aktuelle Thema
        topic_keywords[f"Topic_{topic_num}"] = [
            word for word, score in keywords]

# Erstelle einen DataFrame aus dem Dictionary und transponiere ihn, um die gewünschte Struktur zu erhalten
df_topics = pd.DataFrame.from_dict(topic_keywords, orient="index").transpose()

# DataFrame anzeigen
print(df_topics)

# %% [markdown]
# # Differenzierter Ansatz

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN

# Laden des spezifischen Modells für die Einbettungen
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# Erstellen der UMAP- und HDBSCAN-Instanzen mit angepassten Parametern
umap_model = UMAP(n_neighbors=15, n_components=5,
                  min_dist=0.0, metric='cosine')
hdbscan_model = HDBSCAN(min_cluster_size=15,
                        metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# Initialisierung von BERTopic mit den angepassten Modellen
topic_model_diff = BERTopic(embedding_model=model,
                       language="multilingual",
                       calculate_probabilities=True,
                       min_topic_size=20,
                       umap_model=umap_model,
                       hdbscan_model=hdbscan_model)

# Trainieren des Modells mit Ihren Daten
topics, probabilities = topic_model_diff.fit_transform(combined_contexts)

# Anzeigen der Themen
for topic_num in set(topics):
    print("Topic Nummer:", topic_num)
    print(topic_model_diff.get_topic(topic_num))

# Optional: Visualisierung der Themen
topic_model_diff.visualize_topics()

# %%
topic_model_diff.get_topic_freq()

# %%
import pandas as pd

# Initialisiere ein leeres Dictionary, um die Keywords für jedes Thema zu speichern
topic_keywords = {}

# Schleife über alle Themen und extrahiere die Keywords
for topic_num in range(len(topic_model_diff.get_topics())):
    keywords = topic_model_diff.get_topic(topic_num)
    if keywords:  # Überprüfe, ob das Thema nicht leer ist
        # Speichere nur die Keywords (ohne Relevance Score) für das aktuelle Thema
        topic_keywords[f"Topic_{topic_num}"] = [
            word for word, score in keywords]

# Erstelle einen DataFrame aus dem Dictionary und transponiere ihn, um die gewünschte Struktur zu erhalten
df_topics = pd.DataFrame.from_dict(topic_keywords, orient="index").transpose()

# DataFrame anzeigen
print(df_topics)
